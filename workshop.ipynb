# %% [markdown]
# ## Setup Guide
#
# Welcome to the OSS Insight setup guide.
#
# This guide will help you setup your environment for OSS Insight.

# %% [markdown]
# ### Prerequisites
#
# Before you begin, you need to have the following installed:
#
# - TiDB Cluster - Database to store the data
# - MyCLI - Connect to the TiDB Cluster
# - Node.js 18.x and above - API server runtime
# - PNPM - Package manager for Node.js
# - Python 3.x and pip - For jupyter notebook
#
# #### 1. Startup TiDB Cluster
#
# First of all, you need to startup a TiDB cluster. You can startup a **serverless tier** cluster using TiDB Cloud, please click [here](https://docs.pingcap.com/tidbcloud/tidb-cloud-quickstart#step-1-create-a-tidb-cluster) to learn how to create a new serverless tier cluster.
#
# > **Note**
# >
# > If you already have a TiDB cluster that you can connect to, you can ignore this step.
# >
#
# After you created a TiDB cluster on TiDB Cloud, you can enter the cluster detail page.
#
# In this page, you can get the connection information in the connection panel.
#
# <center>
#   <img align="middle" width="800" alt="Serverless Tier Cluster Manage Interface" src="https://user-images.githubusercontent.com/5086433/204476069-0ddbdf6f-419c-4291-b929-ccfbd2f5ea5f.png">
#   <p><i>Serverless Tier Cluster Manage Interface</i></p>
# </center>
#
# You can enter to the cluster's security settings window by clicking on the modify menu in the upper right corner of the cluster details page and generate a root user password.
#
# <center>
#   <img width="480" alt="The Cluster Modify Menu" src="https://user-images.githubusercontent.com/85985765/204876779-3a4c6ac4-8814-47cd-b82a-40eb5e4d8f96.png">
#   <p><i>The Cluster Modify Menu</i></p>
# </center>
#
# <center>
#   <img width="720" alt="Security Settings" src="https://user-images.githubusercontent.com/85985765/204877348-5c3e9012-f7bf-42e9-8a03-fd9f14bfc826.png">
#   <p><i>Security Settings</i></p>
# </center>
#
# #### 3. Prepare Your GitHub Access Token
#
# You need to prepare a personal access token to allow the application to access the data through the GitHub API.
#
# > **Note**
# >
# > If you are viewing this document from GitHub codespace, you can skip this step because `GITHUB_TOKEN` is set by default in the codespace environment.
# >
#
# You can learn how to generate one by reading: [Creating a personal access token](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token). Or just click this [link](https://github.com/settings/personal-access-tokens/new) to generate your personal access token quickly.
#
# <center>
#   <img align="middle" width="800" alt="Create a New GitHub Personal Access Token" src="https://user-images.githubusercontent.com/5086433/204564273-93cccbe4-d10a-4d1b-a9d1-112a1144712a.png">
#   <p><i>Create a new GitHub personal access token</i></p>
# </center>

# %% [markdown]
# #### 4. Setup the Environment Variables
#
# Place your database connection information and personal access token in the corresponding location on the command line below, and then execute them **on a terminal in VSCode**.

# %%
import getpass
import os

api_server_dot_env="./packages/api-server/.env"
if os.path.exists(api_server_dot_env): 
    con = input(api_server_dot_env + " file already exists, do you want to overwrite it? (y/n) [y]")
    if con != 'y':
        exit();

# Config GitHub personal access token.
github_token = ""
if os.getenv('GITHUB_TOKEN') is None:
    github_token = getpass.getpass(prompt='Enter your personal access token of GitHub: ')
else:
    github_token = os.getenv('GITHUB_TOKEN')

# Config database connection.
db_endpoint = input("The endpoint of TiDB cluster: ")
db_port = int(input("The port of TiDB cluster [4000]: ")) or 4000
db_username = input("The username of TiDB cluster: ")
db_password = getpass.getpass(prompt='Enter the password of TiDB cluster: ')
db_name = "ossinsight"
db_enable_ssl = input("Enable ssl connection to the TiDB cluster? (y/n) [y]") or "y"
db_ssl_config='&ssl={"minVersion":"TLSv1.2"}'
if db_enable_ssl == "n":
    db_ssl_config = ""

# Write to ./packages/api-server/.env file.
with open(api_server_dot_env, "w") as file:
    file.write(
        "DATABASE_URL=mysql://{}:{}@{}:{}/{}?connectionLimit=100&queueLimit=10000{}\n".format(
            db_username, db_password, db_endpoint, db_port, db_name, db_ssl_config
        )
    )
    file.write("ENABLE_CACHE=false\n")
    file.write("GITHUB_ACCESS_TOKENS={}\n".format(github_token))

print("Setup successfully!")
# Out:
# Setup successfully!

# %% [markdown]
# #### 5. Check if You Can Connect Your TiDB Cluster
#
# Execute the following command on a VSCode terminal to verify if you can connect to the tidb cluster.
#
# ```bash
# mycli -h ${DB_ENDPOINT} -P ${DB_PORT} -u ${DB_USERNAME} -p ${DB_PASSWORD} -D test \
#     --ssl-ca=/etc/ssl/certs/ca-certificates.crt \
#     --ssl-verify-server-cert \
#      -e 'SELECT tidb_version()\G'
# ```
#
# If you can connect successfully, you will get the version information of the tidb cluster like follow:
#
# ```
# tidb_version()
# Release Version: v6.3.0-serverless
# Edition: Community
# Git Commit Hash: e87c16b215d518aed4921b8ef3b13e90e3ed6e2d
# Git Branch: release-6.3-serverless
# UTC Build Time: 2022-11-25 09:31:28
# GoVersion: go1.19
# Race Enabled: false
# TiKV Min Version: 6.1.0
# Check Table Before Drop: false
# Store: tikv
# ```

# %% [markdown]
# ### Load Data
#
# GitHub was launched in April 2008, and the `/events` api was published in Feb 2011, so there is a big amount of both historical and realtime data.
#
# > **GitHub API Docs**
# >
# > Link: https://docs.github.com/en/rest/activity/events
# >

# %% [markdown]
# #### Load Historical Data
#
# We can't fetch the historical data from GitHub `/events` api, but fortunately, they were archived by [GH Archive](https://gharchive.org).
#
# GitHub provides 20+ event types, which range from new commits and fork events, to opening new tickets, commenting, and adding members to a project. These events are aggregated into hourly archives, which you can access with any HTTP client:
#
# | Query | Downloadable Files |
# | ---- | ---- |
# | Activity for 1/1/2015 @ 3PM UTC |	`https://data.gharchive.org/2015-01-01-15.json.gz` |
# | Activity for 1/1/2015 | `https://data.gharchive.org/2015-01-01-{0..23}.json.gz` |
# | Activity for all of January 2015 | `https://data.gharchive.org/2015-01-{01..31}-{0..23}.json.gz` |
#
# For the convenience of the demo, we have prepared a sample data and store it in AWS S3:

# %% [markdown]
# #### Load Realtime Data
#
# According to [GitHub Events API Docs](https://docs.github.com/en/rest/activity/events), you can access fetch realtime events happneded on GitHub through `/events` API:

# %%
# %%!
# curl -s \
#   -H "Accept: application/vnd.github.v3+json" \
#   -H "Authorization: token $GITHUB_TOKEN" \
#   https://api.github.com/events
# Out:
# ['[',
#  '  {',
#  '    "id": "25584614669",',
#  '    "type": "IssueCommentEvent",',
#  '    "actor": {',
#  '      "id": 49699333,',
#  '      "login": "dependabot[bot]",',
#  '      "display_login": "dependabot",',
#  '      "gravatar_id": "",',
#  '      "url": "https://api.github.com/users/dependabot[bot]",',
#  '      "avatar_url": "https://avatars.githubusercontent.com/u/49699333?"',
#  '    },',
#  '    "repo": {',
#  '      "id": 280926365,',
#  '      "name": "daviseares/goweather-react-native",',
#  '      "url": "https://api.github.com/repos/daviseares/goweather-react-native"',
#  '    },',
#  '    "payload": {',
#  '      "action": "created",',
#  '      "issue": {',
#  '        "url": "https://api.github.com/repos/daviseares/goweather-react-native/issues/212",',
#  '        "repository_url": "https://api.github.com/repos/daviseares/goweather-react-native",',
#  '        "labels_url": "https://api.github.com/repos/daviseares/goweather-react-native/issues/212/labels{/name}",',
#  '        "comments_url": "https://api.github.com/repos/daviseares/goweather-react-native/issues/212/comments",',
#  '        "events_url": "https://api.github.com/repos/daviseares/goweather-react-native/issues/212/events",',
#  '        "html_url": "https://github.com/daviseares/goweather-react-native/pull/212",',
#  '        "id": 1431037389,',
#  '        "node_id": "PR_kwDOEL6Ync5B8kM-",',
#  '        "number": 212,',
#  '        "title": "chore(deps): bump react-native-reanimated from 2.2.3 to 2.12.0",',
#  '        "user": {',
#  '          "login": "dependabot[bot]",',
#  '          "id": 49699333,',
#  '          "node_id": "MDM6Qm90NDk2OTkzMzM=",',
#  '          "avatar_url": "https://avatars.githubusercontent.com/in/29110?v=4",',
#  '          "gravatar_id": "",',
#  '          "url": "https://api.github.com/users/dependabot%5Bbot%5D",',
#  '          "html_url": "https://github.com/apps/dependabot",',
#  '          "followers_url": "https://api.github.com/users/dependabot%5Bbot%5D/followers",',
#  '          "following_url": "https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}",',
#  '          "gists_url": "https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}",',
#  '          "starred_url": "https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}",',
#  '          "subscriptions_url": "https://api.github.com/users/dependabot%5Bbot%5D/subscriptions",',
#  '          "organizations_url": "https://api.github.com/users/dependabot%5Bbot%5D/orgs",',
#  '          "repos_url": "https://api.github.com/users/dependabot%5Bbot%5D/repos",',
#  '          "events_url": "https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}",',
#  '          "received_events_url": "https://api.github.com/users/dependabot%5Bbot%5D/received_events",',
#  '          "type": "Bot",',
#  '          "site_admin": false',
#  '        },',
#  '        "labels": [',
#  '          {',
#  '            "id": 2635964022,',
#  '            "node_id": "MDU6TGFiZWwyNjM1OTY0MDIy",',
#  '            "url": "https://api.github.com/repos/daviseares/goweather-react-native/labels/dependencies",',
#  '            "name": "dependencies",',
#  '            "color": "0366d6",',
#  '            "default": false,',
#  '            "description": "Pull requests that update a dependency file"',
#  '          }',
#  '        ],',
#  '        "state": "open",',
#  '        "locked": false,',
#  '        "assignee": null,',
#  '        "assignees": [',
#  '',
#  '        ],',
#  '        "milestone": null,',
#  '        "comments": 0,',
#  '        "created_at": "2022-11-01T08:05:01Z",',
#  '        "updated_at": "2022-12-01T08:19:43Z",',
#  '        "closed_at": null,',
#  '        "author_association": "CONTRIBUTOR",',
#  '        "active_lock_reason": null,',
#  '        "draft": false,',
#  '        "pull_request": {',
#  '          "url": "https://api.github.com/repos/daviseares/goweather-react-native/pulls/212",',
#  '          "html_url": "https://github.com/daviseares/goweather-react-native/pull/212",',
#  '          "diff_url": "https://github.com/daviseares/goweather-react-native/pull/212.diff",',
#  '          "patch_url": "https://github.com/daviseares/goweather-react-native/pull/212.patch",',
#  '          "merged_at": null',
#  '        },',
#  '        "body": "Bumps [react-native-reanimated](https://github.com/software-mansion/react-native-reanimated) from 2.2.3 to 2.12.0.\\n<details>\\n<summary>Release notes</summary>\\n<p><em>Sourced from <a href=\\"https://github.com/software-mansion/react-native-reanimated/releases\\">react-native-reanimated\'s releases</a>.</em></p>\\n<blockquote>\\n<h2>2.12.0</h2>\\n<h1>🚀 Main changes</h1>\\n<ul>\\n<li>Added measure and scrollTo for web <a href=\\"https://github-redirect.dependabot.com/software-mansion/react-native-reanimated/issues/3661\\">#3661</a></li>\\n<li>[Fix] Ignore layout animation props on the web <a href=\\"https://github-redirect.dependabot.com/software-mansion/react-native-reanimated/issues/3714\\">#3714</a></li>\\n<li>[Fix] Absolute path in Podflie.lock <a href=\\"https://github-redirect.dependabot.com/software-mansion/react-native-reanimated/issues/3701\\">#3701</a></li>\\n<li>[Fix] Fix require cycle in useScrollViewOffset <a href=\\"https://github-redirect.dependabot.com/software-mansion/react-native-reanimated/issues/3713\\">#3713</a></li>\\n</ul>\\n<p><strong>Full Changelog</strong>: <a href=\\"https://github.com/software-mansion/react-native-reanimated/compare/2.11.0...2.12.0\\">https://github.com/software-mansion/react-native-reanimated/compare/2.11.0...2.12.0</a></p>\\n<p>Build: <a href=\\"https://github.com/software-mansion/react-native-reanimated/actions/runs/3336425460\\">https://github.com/software-mansion/react-native-reanimated/actions/runs/3336425460</a></p>\\n<h2>🙌  Thank you for your contributions!</h2>\\n<h2>2.11.0</h2>\\n<h1>🚀 Main changes</h1>\\n<ul>\\n<li>Added new useScrollViewOffset hook <a href=\\"https://github-redirect.dependabot.com/software-mansion/react-native-reanimated/issues/3438\\">#3438</a></li>\\n<li>Added FrameTimings to the useFrameCallback hook</li>\\n<li>Fixes for building Reanimated in monorepo</li>\\n</ul>\\n<p><strong>Full Changelog</strong>: <a href=\\"https://github.com/software-mansion/react-native-reanimated/compare/2.10.0...2.11.0\\">https://github.com/software-mansion/react-native-reanimated/compare/2.10.0...2.11.0</a></p>\\n<p>Build: <a href=\\"https://github.com/software-mansion/react-native-reanimated/actions/runs/3105231111\\">https://github.com/software-mansion/react-native-reanimated/actions/runs/3105231111</a></p>\\n<h2>🙌  Thank you for your contributions!</h2>\\n<h2>2.10.0</h2>\\n<h1>🚀 Main changes</h1>\\n<ul>\\n<li>Added <a href=\\"https://docs.swmansion.com/react-native-reanimated/docs/next/api/hooks/useAnimatedKeyboard/\\"><code>useAnimatedKeyboard()</code></a> hook</li>\\n<li>Added <a href=\\"https://docs.swmansion.com/react-native-reanimated/docs/next/api/hooks/useFrameCallback/\\"><code>useFrameCallback()</code></a> hook</li>\\n<li>Added support for React Native 0.70</li>\\n<li>Added support for react-native-v8 (building from source only)</li>\\n<li>Detect multiple versions of Reanimated.</li>\\n<li>And many different fixes.</li>\\n</ul>\\n<p>Build: <a href=\\"https://github.com/software-mansion/react-native-reanimated/actions/runs/2889631689\\">https://github.com/software-mansion/react-native-reanimated/actions/runs/2889631689</a></p>\\n<p><strong>Full Changelog</strong>: <a href=\\"https://github.com/software-mansion/react-native-reanimated/compare/2.9.1...2.10.0\\">https://github.com/software-mansion/react-native-reanimated/compare/2.9.1...2.10.0</a></p>\\n<h2>2.9.1</h2>\\n<h2>What\'s Changed</h2>\\n<ul>\\n<li>Fix issue with duplicated <code>libfolly_runtime.so</code> - <a href=\\"https://github-redirect.dependabot.com/software-mansion/react-native-reanimated/issues/3342\\">software-mansion/react-native-reanimated#3342</a></li>\\n</ul>\\n<p>Build: <a href=\\"https://github.com/software-mansion/react-native-reanimated/actions/runs/2595830511\\">https://github.com/software-mansion/react-native-reanimated/actions/runs/2595830511</a></p>\\n<h2>🙌  Thank you for your contributions!</h2>\\n<h2>2.9.0</h2>\\n<h2>What\'s Changed</h2>\\n<ul>\\n<li>Support for ...
#  '        "reactions": {',
#  '          "url": "https://api.github.com/repos/daviseares/goweather-react-native/issues/212/reactions",',
#  '          "total_count": 0,',
#  '          "+1": 0,',
#  '          "-1": 0,',
#  '          "laugh": 0,',
#  '          "hooray": 0,',
#  '          "confused": 0,',
#  '          "heart": 0,',
#  '          "rocket": 0,',
#  '          "eyes": 0',
#  '        },',
#  '        "timeline_url": "https://api.github.com/repos/daviseares/goweather-react-native/issues/212/timeline",',
#  '        "performed_via_github_app": null,',
#  '        "state_reason": null',
#  '      },',
#  '      "comment": {',
#  '        "url": "https://api.github.com/repos/daviseares/goweather-react-native/issues/comments/1333383879",',
#  '        "html_url": "https://github.com/daviseares/goweather-react-native/pull/212#issuecomment-1333383879",',
#  '        "issue_url": "https://api.github.com/repos/daviseares/goweather-react-native/issues/212",',
#  '        "id": 1333383879,',
#  '        "node_id": "IC_kwDOEL6Ync5PedLH",',
#  '        "user": {',
#  '          "login": "dependabot[bot]",',
#  '          "id": 49699333,',
#  '          "node_id": "MDM6Qm90NDk2OTkzMzM=",',
#  '          "avatar_url": "https://avatars.githubusercontent.com/in/29110?v=4",',
#  '          "gravatar_id": "",',
#  '          "url": "https://api.github.com/users/dependabot%5Bbot%5D",',
#  '          "html_url": "https://github.com/apps/dependabot",',
#  '          "followers_url": "https://api.github.com/users/dependabot%5Bbot%5D/followers",',
#  '          "following_url": "https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}",',
#  '          "gists_url": "https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}",',
#  '          "starred_url": "https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}",',
#  '          "subscriptions_url": "https://api.github.com/users/dependabot%5Bbot%5D/subscriptions",',
#  '          "organizations_url": "https://api.github.com/users/dependabot%5Bbot%5D/orgs",',
#  '          "repos_url": "https://api.github.com/users/dependabot%5Bbot%5D/repos",',
#  '          "events_url": "https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}",',
#  '          "received_events_url": "https://api.github.com/users/dependabot%5Bbot%5D/received_events",',
#  '          "type": "Bot",',
#  '          "site_admin": false',
#  '        },',
#  '        "created_at": "2022-12-01T08:19:43Z",',
#  '        "updated_at": "2022-12-01T08:19:43Z",',
#  '        "author_association": "CONTRIBUTOR",',
#  '        "body": "Superseded by #229.",',
#  '        "reactions": {',
#  '          "url": "https://api.github.com/repos/daviseares/goweather-react-native/issues/comments/1333383879/reactions",',
#  '          "total_count": 0,',
#  '          "+1": 0,',
#  '          "-1": 0,',
#  '          "laugh": 0,',
#  '          "hooray": 0,',
#  '          "confused": 0,',
#  '          "heart": 0,',
#  '          "rocket": 0,',
#  '          "eyes": 0',
#  '        },',
#  '        "performed_via_github_app": null',
#  '      }',
#  '    },',
#  '    "public": true,',
#  '    "created_at": "2022-12-01T08:19:43Z"',
#  '  },',
#  '  {',
#  '    "id": "25584614635",',
#  '    "type": "PushEvent",',
#  '    "actor": {',
#  '      "id": 118170454,',
#  '      "login": "DongGyuJang",',
#  '      "display_login": "DongGyuJang",',
#  '      "gravatar_id": "",',
#  '      "url": "https://api.github.com/users/DongGyuJang",',
#  '      "avatar_url": "https://avatars.githubusercontent.com/u/118170454?"',
#  '    },',
#  '    "repo": {',
#  '      "id": 572776245,',
#  '      "name": "node10test/re_test",',
#  '      "url": "https://api.github.com/repos/node10test/re_test"',
#  '    },',
#  '    "payload": {',
#  '      "push_id": 11844899266,',
#  '      "size": 9,',
#  '      "distinct_size": 1,',
#  '      "ref": "refs/heads/DG-2",',
#  '      "head": "8ae78990f4acfa227463a9489ef9333af4369418",',
#  '      "before": "97388a7199a94a23070d7187afade19e22b14981",',
#  '      "commits": [',
#  '        {',
#  '          "sha": "f6f324df7ab2cabcecaaf42a1174a25fa7d738db",',
#  '          "author": {',
#  '            "email": "greenteapig6@gmail.com",',
#  '            "name": "Hwang Minju"',
#  '          },',
#  '          "message": "<li>민주입니당</li> 추가",',
#  '          "distinct": false,',
#  '          "url": "https://api.github.com/repos/node10test/re_test/commits/f6f324df7ab2cabcecaaf42a1174a25fa7d738db"',
#  '        },',
#  '        {',
#  '          "sha": "22b1c7e36273d035279f8cc0c1a9d6eef7efdac3",',
#  '          "author": {',
#  '            "email": "greenteapig6@gmail.com",',
#  '            "name": "Hwang Minju"',
#  '          },',
#  '          "message": "Merge branch \'minju\' of github.com:node10test/re_test into dev\\n\\n* \'minju\' of github.com:node10test/re_test:\\n  <li>민주입니당</li> 추가",',
#  '          "distinct": false,',
#  '          "url": "https://api.github.com/repos/node10test/re_test/commits/22b1c7e36273d035279f8cc0c1a9d6eef7efdac3"',
#  '        },',
#  '        {',
#  '          "sha": "62a0ac46c67666fab4c55ea564f54304c7614939",',
#  '          "author": {',
#  '            "email": "ehdrb1210@gmail.com",',
#  '            "name": "DongGyu"',
#  '          },',
#  '          "message": "동규입니다 ㅎ",',
#  '          "distinct": false,',
#  '          "url": "https://api.github.com/repos/node10test/re_test/commits/62a0ac46c67666fab4c55ea564f54304c7614939"',
#  '        },',
#  '        {',
#  '          "sha": "8947c2771223e9aa01bbc0c1ef3424031451e716",',
#  '          "author": {',
#  '            "email": "tkiu21@icloud.com",',
#  '            "name": "taekhwankim21"',
#  '          },',
#  '          "message": "택환 텍스트 수정",',
#  '          "distinct": false,',
#  '          "url": "https://api.github.com/repos/node10test/re_test/commits/8947c2771223e9aa01bbc0c1ef3424031451e716"',
#  '        },',
#  '        {',
#  '          "sha": "bd80570f5013800f240181f1f8881135dad5104f",',
#  '          "author": {',
#  '            "email": "haebin1622@naver.com",',
#  '            "name": "Jo haebeen"',
#  '          },',
#  '          "message": "Merge branch \'dev\' of https://github.com/node10test/re_test into haebeen\\n\\n* \'dev\' of https://github.com/node10test/re_test:\\n  택환 텍스트 수정\\n  동규입니다 ㅎ\\n  <li>민주입니당</li> 추가",',
#  '          "distinct": false,',
#  '          "url": "https://api.github.com/repos/node10test/re_test/commits/bd80570f5013800f240181f1f8881135dad5104f"',
#  '        },',
#  '        {',
#  '          "sha": "b0b390776a844c696691bf82ccd8db237409ec6a",',
#  '          "author": {',
#  '            "email": "haebin1622@naver.com",',
#  '            "name": "Jo haebeen"',
#  '          },',
#  '          "message": "해빈 추가",',
#  '          "distinct": false,',
#  '          "url": "https://api.github.com/repos/node10test/re_test/commits/b0b390776a844c696691bf82ccd8db237409ec6a"',
#  '        },',
#  '        {',
#  '          "sha": "190c265115ba3d001d96769ad568a3c2e7440778",',
#  '          "author": {',
#  '            "email": "wth2052@gmail.com",',
#  '            "name": "“Woo"',
#  '          },',
#  '          "message": "Merge branch \'dev\' of github.com:node10test/re_test into wth\\n\\n* \'dev\' of github.com:node10test/re_test:\\n  해빈 추가\\n  택환 텍스트 수정\\n  동규입니다 ㅎ\\n  <li>민주입니당</li> 추가",',
#  '          "distinct": false,',
#  '          "url": "https://api.github.com/repos/node10test/re_test/commits/190c265115ba3d001d96769ad568a3c2e7440778"',
#  '        },',
#  '        {',
#  '          "sha": "8a8fabddba071a5930bc8da0accb95373d488a60",',
#  '          "author": {',
#  '            "email": "wth2052@gmail.com",',
#  '            "name": "“Woo"',
#  '          },',
#  '          "message": "Merge branch \'dev\' of github.com:node10test/re_test into taehyeon\\n\\n* \'dev\' of github.com:node10test/re_test:\\n  해빈 추가\\n  택환 텍스트 수정\\n  동규입니다 ㅎ\\n  <li>민주입니당</li> 추가\\n\\n# Conflicts:\\n#\\tmain.html",',
#  '          "distinct": false,',
#  '          "url": "https://api.github.com/repos/node10test/re_test/commits/8a8fabddba071a5930bc8da0accb95373d488a60"',
#  '        },',
#  '        {',
#  '          "sha": "8ae78990f4acfa227463a9489ef9333af4369418",',
#  '          "author": {',
#  '            "email": "ehdrb1210@gmail.com",',
#  '            "name": "DongGyu"',
#  '          },',
#  '          "message": "ㅎㅎㅎ 장동규 ㅎㅎㅎ 추가",',
#  '          "distinct": true,',
#  '          "url": "https://api.github.com/repos/node10test/re_test/commits/8ae78990f4acfa227463a9489ef9333af4369418"',
#  '        }',
#  '      ]',
#  '    },',
#  '    "public": true,',
#  '    "created_at": "2022-12-01T08:19:43Z",',
#  '    "org": {',
#  '      "id": 118980719,',
#  '      "login": "node10test",',
#  '      "gravatar_id": "",',
#  '      "url": "https://api.github.com/orgs/node10test",',
#  '      "avatar_url": "https://avatars.githubusercontent.com/u/118980719?"',
#  '    }',
#  '  },',
#  '  {',
#  '    "id": "25584614621",',
#  '    "type": "PushEvent",',
#  '    "actor": {',
#  '      "id": 35676858,',
#  '      "login": "siddsuresh97",',
#  '      "display_login": "siddsuresh97",',
#  '      "gravatar_id": "",',
#  '      "url": "https://api.github.com/users/siddsuresh97",',
#  '      "avatar_url": "https://avatars.githubusercontent.com/u/35676858?"',
#  '    },',
#  '    "repo": {',
#  '      "id": 561479667,',
#  '      "name": "siddsuresh97/vision_robustness_using_semantic_norms",',
#  '      "url": "https://api.github.com/repos/siddsuresh97/vision_robustness_using_semantic_norms"',
#  '    },',
#  '    "payload": {',
#  '      "push_id": 11844899247,',
#  '      "size": 1,',
#  '      "distinct_size": 1,',
#  '      "ref": "refs/heads/main",',
#  '      "head": "24571c4680a7e32205b1550e22bd55108d8f3610",',
#  '      "before": "c038c160ee0101dc4ebc180e2a978c3fa568f174",',
#  '      "commits": [',
#  '        {',
#  '          "sha": "24571c4680a7e32205b1550e22bd55108d8f3610",',
#  '          "author": {',
#  '            "email": "sidd.suresh97@gmail.com",',
#  '            "name": "siddsuresh97"',
#  '          },',
#  '          "message": "fixed resuming training bug",',
#  '          "distinct": true,',
#  '          "url": "https://api.github.com/repos/siddsuresh97/vision_robustness_using_semantic_norms/commits/24571c4680a7e32205b1550e22bd55108d8f3610"',
#  '        }',
#  '      ]',
#  '    },',
#  '    "public": true,',
#  '    "created_at": "2022-12-01T08:19:43Z"',
#  '  },',
#  '  {',
#  '    "id": "25584614655",',
#  '    "type": "WatchEvent",',
#  '    "actor": {',
#  '      "id": 79323179,',
#  '      "login": "GUNDAMXX",',
#  '      "display_login": "GUNDAMXX",',
#  '      "gravatar_id": "",',
#  '      "url": "https://api.github.com/users/GUNDAMXX",',
#  '      "avatar_url": "https://avatars.githubusercontent.com/u/79323179?"',
#  '    },',
#  '    "repo": {',
#  '      "id": 448146826,',
#  '      "name": "tanshuai/alphabiz",',
#  '      "url": "https://api.github.com/repos/tanshuai/alphabiz"',
#  '    },',
#  '    "payload": {',
#  '      "action": "started"',
#  '    },',
#  '    "public": true,',
#  '    "created_at": "2022-12-01T08:19:43Z"',
#  '  },',
#  '  {',
#  '    "id": "25584614647",',
#  '    "type": "CreateEvent",',
#  '    "actor": {',
#  '      "id": 49699333,',
#  '      "login": "dependabot[bot]",',
#  '      "display_login": "dependabot",',
#  '      "gravatar_id": "",',
#  '      "url": "https://api.github.com/users/dependabot[bot]",',
#  '      "avatar_url": "https://avatars.githubusercontent.com/u/49699333?"',
#  '    },',
#  '    "repo": {',
#  '      "id": 447339794,',
#  '      "name": "cpellot/docs",',
#  '      "url": "https://api.github.com/repos/cpellot/docs"',
#  '    },',
#  '    "payload": {',
#  '      "ref": "dependabot/npm_and_yarn/minimatch-5.1.1",',
#  '      "ref_type": "branch",',
#  '      "master_branch": "main",',
#  '      "description": "The open-source repo for docs.github.com",',
#  '      "pusher_type": "user"',
#  '    },',
#  '    "public": true,',
#  '    "created_at": "2022-12-01T08:19:43Z"',
#  '  },',
#  '  {',
#  '    "id": "25584614636",',
#  '    "type": "PushEvent",',
#  '    "actor": {',
#  '      "id": 9808326,',
#  '      "login": "fxmarty",',
#  '      "display_login": "fxmarty",',
#  '      "gravatar_id": "",',
#  '      "url": "https://api.github.com/users/fxmarty",',
#  '      "avatar_url": "https://avatars.githubusercontent.com/u/9808326?"',
#  '    },',
#  '    "repo": {',
#  '      "id": 387786881,',
#  '      "name": "huggingface/optimum",',
#  '      "url": "https://api.github.com/repos/huggingface/optimum"',
#  '    },',
#  '    "payload": {',
#  '      "push_id": 11844899260,',
#  '      "size": 1,',
#  '      "distinct_size": 1,',
#  '      "ref": "refs/heads/main",',
#  '      "head": "4ad66e8e54d19c067532412ca87d1be04c865657",',
#  '      "before": "3d0a39c9c955d18989209fa24d30187850cab856",',
#  '      "commits": [',
#  '        {',
#  '          "sha": "4ad66e8e54d19c067532412ca87d1be04c865657",',
#  '          "author": {',
#  '            "email": "9808326+fxmarty@users.noreply.github.com",',
#  '            "name": "fxmarty"',
#  '          },',
#  '          "message": "Add Swin support in exporters.onnx (#528)\\n\\n* add swin to onnx exporters\\r\\n\\r\\n* add masked image\\r\\n\\r\\n* remove opset 12",',
#  '          "distinct": true,',
#  '          "url": "https://api.github.com/repos/huggingface/optimum/commits/4ad66e8e54d19c067532412ca87d1be04c865657"',
#  '        }',
#  '      ]',
#  '    },',
#  '    "public": true,',
#  '    "created_at": "2022-12-01T08:19:43Z",',
#  '    "org": {',
#  '      "id": 25720743,',
#  '      "login": "huggingface",',
#  '      "gravatar_id": "",',
#  '      "url": "https://api.github.com/orgs/huggingface",',
#  '      "avatar_url": "https://avatars.githubusercontent.com/u/25720743?"',
#  '    }',
#  '  },',
#  '  {',
#  '    "id": "25584614587",',
#  '    "type": "PushEvent",',
#  '    "actor": {',
#  '      "id": 118938892,',
#  '      "login": "ANIEBIERE",',
#  '      "display_login": "ANIEBIERE",',
#  '      "gravatar_id": "",',
#  '      "url": "https://api.github.com/users/ANIEBIERE",',
#  '      "avatar_url": "https://avatars.githubusercontent.com/u/118938892?"',
#  '    },',
#  '    "repo": {',
#  '      "id": 572461514,',
#  '      "name": "ANIEBIERE/alx-system_engineering-devops",',
#  '      "url": "https://api.github.com/repos/ANIEBIERE/alx-system_engineering-devops"',
#  '    },',
#  '    "payload": {',
#  '      "push_id": 11844899243,',
#  '      "size": 1,',
#  '      "distinct_size": 1,',
#  '      "ref": "refs/heads/master",',
#  '      "head": "567de27b2e25d4520ade8062426a7487d853fa1d",',
#  '      "before": "ccd9336e2b84921412ad35426f3e816ef0667ad9",',
#  '      "commits": [',
#  '        {',
#  '          "sha": "567de27b2e25d4520ade8062426a7487d853fa1d",',
#  '          "author": {',
#  '            "email": "justinaumoh2@gmail.com",',
#  '            "name": "ANIEBIERE"',
#  '          },',
#  '          "message": "magic files",',
#  '          "distinct": true,',
#  '          "url": "https://api.github.com/repos/ANIEBIERE/alx-system_engineering-devops/commits/567de27b2e25d4520ade8062426a7487d853fa1d"',
#  '        }',
#  '      ]',
#  '    },',
#  '    "public": true,',
#  '    "created_at": "2022-12-01T08:19:43Z"',
#  '  },',
#  '  {',
#  '    "id": "25584614588",',
#  '    "type": "IssueCommentEvent",',
#  '    "actor": {',
#  '      "id": 39514782,',
#  '      "login": "sonarcloud[bot]",',
#  '      "display_login": "sonarcloud",',
#  '      "gravatar_id": "",',
#  '      "url": "https://api.github.com/users/sonarcloud[bot]",',
#  '      "avatar_url": "https://avatars.githubusercontent.com/u/39514782?"',
#  '    },',
#  '    "repo": {',
#  '      "id": 165096411,',
#  '      "name": "Informatievlaanderen/public-api",',
#  '      "url": "https://api.github.com/repos/Informatievlaanderen/public-api"',
#  '    },',
#  '    "payload": {',
#  '      "action": "created",',
#  '      "issue": {',
#  '        "url": "https://api.github.com/repos/Informatievlaanderen/public-api/issues/537",',
#  '        "repository_url": "https://api.github.com/repos/Informatievlaanderen/public-api",',
#  '        "labels_url": "https://api.github.com/repos/Informatievlaanderen/public-api/issues/537/labels{/name}",',
#  '        "comments_url": "https://api.github.com/repos/Informatievlaanderen/public-api/issues/537/comments",',
#  '        "events_url": "https://api.github.com/repos/Informatievlaanderen/public-api/issues/537/events",',
#  '        "html_url": "https://github.com/Informatievlaanderen/public-api/pull/537",',
#  '        "id": 1408147351,',
#  '        "node_id": "PR_kwDOCdcr285AwRyn",',
#  '        "number": 537,',
#  '        "title": "chore(deps): bump actions/setup-dotnet from 2 to 3.0.2",',
#  '        "user": {',
#  '          "login": "dependabot[bot]",',
#  '          "id": 49699333,',
#  '          "node_id": "MDM6Qm90NDk2OTkzMzM=",',
#  '          "avatar_url": "https://avatars.githubusercontent.com/in/29110?v=4",',
#  '          "gravatar_id": "",',
#  '          "url": "https://api.github.com/users/dependabot%5Bbot%5D",',
#  '          "html_url": "https://github.com/apps/dependabot",',
#  '          "followers_url": "https://api.github.com/users/dependabot%5Bbot%5D/followers",',
#  '          "following_url": "https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}",',
#  '          "gists_url": "https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}",',
#  '          "starred_url": "https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}",',
#  '          "subscriptions_url": "https://api.github.com/users/dependabot%5Bbot%5D/subscriptions",',
#  '          "organizations_url": "https://api.github.com/users/dependabot%5Bbot%5D/orgs",',
#  '          "repos_url": "https://api.github.com/users/dependabot%5Bbot%5D/repos",',
#  '          "events_url": "https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}",',
#  '          "received_events_url": "https://api.github.com/users/dependabot%5Bbot%5D/received_events",',
#  '          "type": "Bot",',
#  '          "site_admin": false',
#  '        },',
#  '        "labels": [',
#  '          {',
#  '            "id": 1732875059,',
#  '            "node_id": "MDU6TGFiZWwxNzMyODc1MDU5",',
#  '            "url": "https://api.github.com/repos/Informatievlaanderen/public-api/labels/dependencies",',
#  '            "name": "dependencies",',
#  '            "color": "0366d6",',
#  '            "default": false,',
#  '            "description": "Pull requests that update a dependency file"',
#  '          },',
#  '          {',
#  '            "id": 2370951164,',
#  '            "node_id": "MDU6TGFiZWwyMzcwOTUxMTY0",',
#  '            "url": "https://api.github.com/repos/Informatievlaanderen/public-api/labels/github_actions",',
#  '            "name": "github_actions",',
#  '            "color": "000000",',
#  '            "default": false,',
#  '            "description": "Pull requests that update Github_actions code"',
#  '          }',
#  '        ],',
#  '        "state": "open",',
#  '        "locked": false,',
#  '        "assignee": null,',
#  '        "assignees": [',
#  '',
#  '        ],',
#  '        "milestone": null,',
#  '        "comments": 1,',
#  '        "created_at": "2022-10-13T17:04:37Z",',
#  '        "updated_at": "2022-12-01T08:19:43Z",',
#  '        "closed_at": null,',
#  '        "author_association": "CONTRIBUTOR",',
#  '        "active_lock_reason": null,',
#  '        "draft": false,',
#  '        "pull_request": {',
#  '          "url": "https://api.github.com/repos/Informatievlaanderen/public-api/pulls/537",',
#  '          "html_url": "https://github.com/Informatievlaanderen/public-api/pull/537",',
#  '          "diff_url": "https://github.com/Informatievlaanderen/public-api/pull/537.diff",',
#  '          "patch_url": "https://github.com/Informatievlaanderen/public-api/pull/537.patch",',
#  '          "merged_at": null',
#  '        },',
#  '        "body": "Bumps [actions/setup-dotnet](https://github.com/actions/setup-dotnet) from 2 to 3.0.2.\\n<details>\\n<summary>Release notes</summary>\\n<p><em>Sourced from <a href=\\"https://github.com/actions/setup-dotnet/releases\\">actions/setup-dotnet\'s releases</a>.</em></p>\\n<blockquote>\\n<h2>Updating <code>@\u200baction/core</code>, adding logic for processing the DOTNET_INSTALL_DIR environment variable.</h2>\\n<p>In the scope of this release such changes were made:</p>\\n<ol>\\n<li>The logic for processing the <code>DOTNET_INSTALL_DIR</code> environment variable was added to support relative paths and paths containing <code>~</code> <a href=\\"https://github-redirect.dependabot.com/actions/setup-dotnet/pull/332\\">#332</a></li>\\n<li>The version of <code>@actions/core</code> was bumped to 1.10.0 <a href=\\"https://github-redirect.dependabot.com/actions/setup-dotnet/pull/331\\">#331</a></li>\\n</ol>\\n<h2>Enable DOTNET_INSTALL_DIR environment variable</h2>\\n<p>In scope of this release the <code>DOTNET_INSTALL_DIR</code> environment variable was enabled to add the ability to change the installation directory for .NET SDK <a href=\\"https://github-redirect.dependabot.com/actions/setup-dotnet/pull/329\\">#329</a>. The <code>DOTNET_INSTALL_DIR</code> can be helpful when access to the default installation directory, for instance, on self-hosted runners, is denied.</p>\\n<p>Example of usage:</p>\\n<pre lang=\\"yml\\"><code>build:\\n  runs-on: self-hosted\\n  env:\\n    DOTNET_INSTALL_DIR: &quot;path/to/directory&quot;\\n  steps:\\n    - uses: actions/setup-dotnet@v3\\n      with:\\n        dotnet-version: \'3.1.x\'\\n<h2>v3.0.0</h2>\\n<p>This major release includes the following <strong>changes:</strong></p>\\n<ul>\\n<li><a href=\\"https://github-redirect.dependabot.com/actions/setup-dotnet/issues/219\\">#219</a> New input <code>dotnet-quality</code> was added in <a href=\\"https://github-redirect.dependabot.com/actions/setup-dotnet/pull/315\\">#315</a>:</li>\\n</ul>\\n<pre lang=\\"yaml\\"><code>    - uses: actions/setup-dotnet@v3\\n      with:\\n        dotnet-version: \'6.0.x\'\\n        dotnet-quality: \'preview\'\\n    - run: dotnet build &amp;lt;my project&amp;gt;\\n&lt;/code&gt;&lt;/pre&gt;\\n&lt;p&gt;More in detail &lt;a href=&quot;https://github.com/actions/setup-dotnet#using-the-dotnet-quality-input&quot;&gt;here&lt;/a&gt;.&lt;/p&gt;\\n&lt;ul&gt;\\n&lt;li&gt;&lt;a href=&quot;https://github-redirect.dependabot.com/actions/setup-dotnet/issues/241&quot;&gt;#241&lt;/a&gt; The output variable &lt;code&gt;dotnet-version&lt;/code&gt; which contains the installed by the action SDK version was added in &lt;a href=&quot;https://github-redirect.dependabot.com/actions/setup-dotnet/pull/324&quot;&gt;#324&lt;/a&gt;:&lt;/li&gt;\\n&lt;/ul&gt;\\n&lt;pre lang=&quot;yaml&quot;&gt;&lt;code&gt;    - uses: actions/setup-dotnet@v3\\n      id: cp310\\n      with:\\n        dotnet-version: \'3.1.422\'\\n    - run: echo \'${{ steps.cp310.outputs.dotnet-version }}\' # outputs 3.1.422\\n&lt;/code&gt;&lt;/pre&gt;\\n&lt;p&gt;More in detail &lt;a href=&quot;https://github.com/actions/setup-dotnet/tree/main#dotnet-version&quot;&gt;here&lt;/a&gt;.&lt;/p&gt;\\n&lt;ul&gt;\\n&lt;li&gt;The &lt;code&gt;dotnet-version&lt;/code&gt; syntax was updated and now it allows to specify the prerelease version without using &lt;code&gt;include-prerelease&lt;/code&gt; input. The &lt;code&gt;include-prerelease&lt;/code&gt; input was cut out:&lt;/li&gt;\\n&lt;/ul&gt;\\n&lt;pre lang=&quot;yaml&quot;&gt;&lt;code&gt;    - uses: actions/setup-dotnet@v3\\n      with:\\n        dotnet-version: \'5.0.0-preview.6\'\\n&lt;/code&gt;&lt;/pre&gt;\\n&lt;p&gt;More in detail &lt;a href=&quot;https://github.com/actions/setup-dotnet#supported-version-syntax&quot;&gt;here&lt;/a&gt;.&lt;/p&gt;\\n&lt;!-- raw HTML omitted --&gt;\\n&lt;/blockquote&gt;\\n&lt;p&gt;... (truncated)&lt;/p&gt;\\n&lt;/details&gt;\\n&lt;details&gt;\\n&lt;summary&gt;Commits&lt;/summary&gt;\\n\\n&lt;ul&gt;\\n ...
#  '        "reactions": {',
#  '          "url": "https://api.github.com/repos/Informatievlaanderen/public-api/issues/537/reactions",',
#  '          "total_count": 0,',
#  '          "+1": 0,',
#  '          "-1": 0,',
#  '          "laugh": 0,',
#  '          "hooray": 0,',
#  '          "confused": 0,',
#  '          "heart": 0,',
#  '          "rocket": 0,',
#  '          "eyes": 0',
#  '        },',
#  '        "timeline_url": "https://api.github.com/repos/Informatievlaanderen/public-api/issues/537/timeline",',
#  '        "performed_via_github_app": null,',
#  '        "state_reason": null',
#  '      },',
#  '      "comment": {',
#  '        "url": "https://api.github.com/repos/Informatievlaanderen/public-api/issues/comments/1333383873",',
#  '        "html_url": "https://github.com/Informatievlaanderen/public-api/pull/537#issuecomment-1333383873",',
#  '        "issue_url": "https://api.github.com/repos/Informatievlaanderen/public-api/issues/537",',
#  '        "id": 1333383873,',
#  '        "node_id": "IC_kwDOCdcr285PedLB",',
#  '        "user": {',
#  '          "login": "sonarcloud[bot]",',
#  '          "id": 39514782,',
#  '          "node_id": "MDM6Qm90Mzk1MTQ3ODI=",',
#  '          "avatar_url": "https://avatars.githubusercontent.com/in/12526?v=4",',
#  '          "gravatar_id": "",',
#  '          "url": "https://api.github.com/users/sonarcloud%5Bbot%5D",',
#  '          "html_url": "https://github.com/apps/sonarcloud",',
#  '          "followers_url": "https://api.github.com/users/sonarcloud%5Bbot%5D/followers",',
#  '          "following_url": "https://api.github.com/users/sonarcloud%5Bbot%5D/following{/other_user}",',
#  '          "gists_url": "https://api.github.com/users/sonarcloud%5Bbot%5D/gists{/gist_id}",',
#  '          "starred_url": "https://api.github.com/users/sonarcloud%5Bbot%5D/starred{/owner}{/repo}",',
#  '          "subscriptions_url": "https://api.github.com/users/sonarcloud%5Bbot%5D/subscriptions",',
#  '          "organizations_url": "https://api.github.com/users/sonarcloud%5Bbot%5D/orgs",',
#  '          "repos_url": "https://api.github.com/users/sonarcloud%5Bbot%5D/repos",',
#  '          "events_url": "https://api.github.com/users/sonarcloud%5Bbot%5D/events{/privacy}",',
#  '          "received_events_url": "https://api.github.com/users/sonarcloud%5Bbot%5D/received_events",',
#  '          "type": "Bot",',
#  '          "site_admin": false',
#  '        },',
#  '        "created_at": "2022-12-01T08:19:43Z",',
#  '        "updated_at": "2022-12-01T08:19:43Z",',
#  '        "author_association": "NONE",',
#  '        "body": "Kudos, SonarCloud Quality Gate passed!&nbsp; &nbsp; [![Quality Gate passed](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/QualityGateBadge/passed-16px.png \'Quality Gate passed\')](https://sonarcloud.io/dashboard?id=Informatievlaanderen_public-api&pullRequest=537)\\n\\n[![Bug](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/common/bug-16px.png \'Bug\')](https://sonarcloud.io/project/issues?id=Informatievlaanderen_public-api&pullRequest=537&resolved=false&types=BUG) [![A](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/RatingBadge/A-16px.png \'A\')](https://sonarcloud.io/project/issues?id=Informatievlaanderen_public-api&pullRequest=537&resolved=false&types=BUG) [0 Bugs](https://sonarcloud.io/project/issues?id=Informatievlaanderen_public-api&pullRequest=537&resolved=false&types=BUG)  \\n[![Vulnerability](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/common/vulnerability-16px.png \'Vulnerability\')](https://sonarcloud.io/project/issues?id=Informatievlaanderen_public-api&pullRequest=537&resolved=false&types=VULNERABILITY) [![A](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/RatingBadge/A-16px.png \'A\')](https://sonarcloud.io/project/issues?id=Informatievlaanderen_public-api&pullRequest=537&resolved=false&types=VULNERABILITY) [0 Vulnerabilities](https://sonarcloud.io/project/issues?id=Informatievlaanderen_public-api&pullRequest=537&resolved=false&types=VULNERABILITY)  \\n[![Security Hotspot](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/common/security_hotspot-16px.png \'Security Hotspot\')](https://sonarcloud.io/project/security_hotspots?id=Informatievlaanderen_public-api&pullRequest=537&resolved=false&types=SECURITY_HOTSPOT) [![A](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/RatingBadge/A-16px.png \'A\')](https://sonarcloud.io/project/security_hotspots?id=Informatievlaanderen_public-api&pullRequest=537&resolved=false&types=SECURITY_HOTSPOT) [0 Security Hotspots](https://sonarcloud.io/project/security_hotspots?id=Informatievlaanderen_public-api&pullRequest=537&resolved=false&types=SECURITY_HOTSPOT)  \\n[![Code Smell](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/common/code_smell-16px.png \'Code Smell\')](https://sonarcloud.io/project/issues?id=Informatievlaanderen_public-api&pullRequest=537&resolved=false&types=CODE_SMELL) [![A](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/RatingBadge/A-16px.png \'A\')](https://sonarcloud.io/project/issues?id=Informatievlaanderen_public-api&pullRequest=537&resolved=false&types=CODE_SMELL) [0 Code Smells](https://sonarcloud.io/project/issues?id=Informatievlaanderen_public-api&pullRequest=537&resolved=false&types=CODE_SMELL)\\n\\n[![No Coverage information](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/CoverageChart/NoCoverageInfo-16px.png \'No Coverage information\')](https://sonarcloud.io/component_measures?id=Informatievlaanderen_public-api&pullRequest=537&metric=coverage&view=list) No Coverage information  \\n[![No Duplication information](https://sonarsource.github.io/sonarcloud-github-static-resources/v2/checks/Duplications/NoDuplicationInfo-16px.png \'No Duplication information\')](https://sonarcloud.io/component_measures?id=Informatievlaanderen_public-api&pullRequest=537&metric=duplicated_lines_density&view=list) No Duplication information\\n\\n",',
#  '        "reactions": {',
#  '          "url": "https://api.github.com/repos/Informatievlaanderen/public-api/issues/comments/1333383873/reactions",',
#  '          "total_count": 0,',
#  '          "+1": 0,',
#  '          "-1": 0,',
#  '          "laugh": 0,',
#  '          "hooray": 0,',
#  '          "confused": 0,',
#  '          "heart": 0,',
#  '          "rocket": 0,',
#  '          "eyes": 0',
#  '        },',
#  '        "performed_via_github_app": null',
#  '      }',
#  '    },',
#  '    "public": true,',
#  '    "created_at": "2022-12-01T08:19:43Z",',
#  '    "org": {',
#  '      "id": 15910637,',
#  '      "login": "Informatievlaanderen",',
#  '      "gravatar_id": "",',
#  '      "url": "https://api.github.com/orgs/Informatievlaanderen",',
#  '      "avatar_url": "https://avatars.githubusercontent.com/u/15910637?"',
#  '    }',
#  '  },',
#  '  {',
#  '    "id": "25584614607",',
#  '    "type": "CreateEvent",',
#  '    "actor": {',
#  '      "id": 49305252,',
#  '      "login": "eng-mohamedalmahdy",',
#  '      "display_login": "eng-mohamedalmahdy",',
#  '      "gravatar_id": "",',
#  '      "url": "https://api.github.com/users/eng-mohamedalmahdy",',
#  '      "avatar_url": "https://avatars.githubusercontent.com/u/49305252?"',
#  '    },',
#  '    "repo": {',
#  '      "id": 572878703,',
#  '      "name": "eng-mohamedalmahdy/MostafaSaadInterviewsWarmupSheet-V2KotlinSolutions",',
#  '      "url": "https://api.github.com/repos/eng-mohamedalmahdy/MostafaSaadInterviewsWarmupSheet-V2KotlinSolutions"',
#  '    },',
#  '    "payload": {',
#  '      "ref": "master",',
#  '      "ref_type": "branch",',
#  '      "master_branch": "master",',
#  '      "description": null,',
#  '      "pusher_type": "user"',
#  '    },',
#  '    "public": true,',
#  '    "created_at": "2022-12-01T08:19:43Z"',
#  '  },',
#  '  {',
#  '    "id": "25584614615",',
#  '    "type": "PullRequestEvent",',
#  '    "actor": {',
#  '      "id": 102157839,',
#  '      "login": "bmm522",',
#  '      "display_login": "bmm522",',
#  '      "gravatar_id": "",',
#  '      "url": "https://api.github.com/users/bmm522",',
#  '      "avatar_url": "https://avatars.githubusercontent.com/u/102157839?"',
#  '    },',
#  '    "repo": {',
#  '      "id": 567761819,',
#  '      "name": "bmm522/Y2K",',
#  '      "url": "https://api.github.com/repos/bmm522/Y2K"',
#  '    },',
#  '    "payload": {',
#  '      "action": "opened",',
#  '      "number": 93,',
#  '      "pull_request": {',
#  '        "url": "https://api.github.com/repos/bmm522/Y2K/pulls/93",',
#  '        "id": 1141467362,',
#  '        "node_id": "PR_kwDOIddbm85ECWji",',
#  '        "html_url": "https://github.com/bmm522/Y2K/pull/93",',
#  '        "diff_url": "https://github.com/bmm522/Y2K/pull/93.diff",',
#  '        "patch_url": "https://github.com/bmm522/Y2K/pull/93.patch",',
#  '        "issue_url": "https://api.github.com/repos/bmm522/Y2K/issues/93",',
#  '        "number": 93,',
#  '        "state": "open",',
#  '        "locked": false,',
#  '        "title": "Jiin",',
#  '        "user": {',
#  '          "login": "bmm522",',
#  '          "id": 102157839,',
#  '          "node_id": "U_kgDOBhbODw",',
#  '          "avatar_url": "https://avatars.githubusercontent.com/u/102157839?v=4",',
#  '          "gravatar_id": "",',
#  '          "url": "https://api.github.com/users/bmm522",',
#  '          "html_url": "https://github.com/bmm522",',
#  '          "followers_url": "https://api.github.com/users/bmm522/followers",',
#  '          "following_url": "https://api.github.com/users/bmm522/following{/other_user}",',
#  '          "gists_url": "https://api.github.com/users/bmm522/gists{/gist_id}",',
#  '          "starred_url": "https://api.github.com/users/bmm522/starred{/owner}{/repo}",',
#  '          "subscriptions_url": "https://api.github.com/users/bmm522/subscriptions",',
#  '          "organizations_url": "https://api.github.com/users/bmm522/orgs",',
#  '          "repos_url": "https://api.github.com/users/bmm522/repos",',
#  '          "events_url": "https://api.github.com/users/bmm522/events{/privacy}",',
#  '          "received_events_url": "https://api.github.com/users/bmm522/received_events",',
#  '          "type": "User",',
#  '          "site_admin": false',
#  '        },',
#  '        "body": null,',
#  '        "created_at": "2022-12-01T08:19:42Z",',
#  '        "updated_at": "2022-12-01T08:19:42Z",',
#  '        "closed_at": null,',
#  '        "merged_at": null,',
#  '        "merge_commit_sha": null,',
#  '        "assignee": null,',
#  '        "assignees": [',
#  '',
#  '        ],',
#  '        "requested_reviewers": [',
#  '',
#  '        ],',
#  '        "requested_teams": [',
#  '',
#  '        ],',
#  '        "labels": [',
#  '',
#  '        ],',
#  '        "milestone": null,',
#  '        "draft": false,',
#  '        "commits_url": "https://api.github.com/repos/bmm522/Y2K/pulls/93/commits",',
#  '        "review_comments_url": "https://api.github.com/repos/bmm522/Y2K/pulls/93/comments",',
#  '        "review_comment_url": "https://api.github.com/repos/bmm522/Y2K/pulls/comments{/number}",',
#  '        "comments_url": "https://api.github.com/repos/bmm522/Y2K/issues/93/comments",',
#  '        "statuses_url": "https://api.github.com/repos/bmm522/Y2K/statuses/f06dd82fb1d7860d99de3a80d9d7bccae10dd9ac",',
#  '        "head": {',
#  '          "label": "bmm522:jiin",',
#  '          "ref": "jiin",',
#  '          "sha": "f06dd82fb1d7860d99de3a80d9d7bccae10dd9ac",',
#  '          "user": {',
#  '            "login": "bmm522",',
#  '            "id": 102157839,',
#  '            "node_id": "U_kgDOBhbODw",',
#  '            "avatar_url": "https://avatars.githubusercontent.com/u/102157839?v=4",',
#  '            "gravatar_id": "",',
#  '            "url": "https://api.github.com/users/bmm522",',
#  '            "html_url": "https://github.com/bmm522",',
#  '            "followers_url": "https://api.github.com/users/bmm522/followers",',
#  '            "following_url": "https://api.github.com/users/bmm522/following{/other_user}",',
#  '            "gists_url": "https://api.github.com/users/bmm522/gists{/gist_id}",',
#  '            "starred_url": "https://api.github.com/users/bmm522/starred{/owner}{/repo}",',
#  '            "subscriptions_url": "https://api.github.com/users/bmm522/subscriptions",',
#  '            "organizations_url": "https://api.github.com/users/bmm522/orgs",',
#  '            "repos_url": "https://api.github.com/users/bmm522/repos",',
#  '            "events_url": "https://api.github.com/users/bmm522/events{/privacy}",',
#  '            "received_events_url": "https://api.github.com/users/bmm522/received_events",',
#  '            "type": "User",',
#  '            "site_admin": false',
#  '          },',
#  '          "repo": {',
#  '            "id": 567761819,',
#  '            "node_id": "R_kgDOIddbmw",',
#  '            "name": "Y2K",',
#  '            "full_name": "bmm522/Y2K",',
#  '            "private": false,',
#  '            "owner": {',
#  '              "login": "bmm522",',
#  '              "id": 102157839,',
#  '              "node_id": "U_kgDOBhbODw",',
#  '              "avatar_url": "https://avatars.githubusercontent.com/u/102157839?v=4",',
#  '              "gravatar_id": "",',
#  '              "url": "https://api.github.com/users/bmm522",',
#  '              "html_url": "https://github.com/bmm522",',
#  '              "followers_url": "https://api.github.com/users/bmm522/followers",',
#  '              "following_url": "https://api.github.com/users/bmm522/following{/other_user}",',
#  '              "gists_url": "https://api.github.com/users/bmm522/gists{/gist_id}",',
#  '              "starred_url": "https://api.github.com/users/bmm522/starred{/owner}{/repo}",',
#  '              "subscriptions_url": "https://api.github.com/users/bmm522/subscriptions",',
#  '              "organizations_url": "https://api.github.com/users/bmm522/orgs",',
#  '              "repos_url": "https://api.github.com/users/bmm522/repos",',
#  '              "events_url": "https://api.github.com/users/bmm522/events{/privacy}",',
#  '              "received_events_url": "https://api.github.com/users/bmm522/received_events",',
#  '              "type": "User",',
#  '              "site_admin": false',
#  '            },',
#  '            "html_url": "https://github.com/bmm522/Y2K",',
#  '            "description": null,',
#  '            "fork": false,',
#  '            "url": "https://api.github.com/repos/bmm522/Y2K",',
#  '            "forks_url": "https://api.github.com/repos/bmm522/Y2K/forks",',
#  '            "keys_url": "https://api.github.com/repos/bmm522/Y2K/keys{/key_id}",',
#  '            "collaborators_url": "https://api.github.com/repos/bmm522/Y2K/collaborators{/collaborator}",',
#  '            "teams_url": "https://api.github.com/repos/bmm522/Y2K/teams",',
#  '            "hooks_url": "https://api.github.com/repos/bmm522/Y2K/hooks",',
#  '            "issue_events_url": "https://api.github.com/repos/bmm522/Y2K/issues/events{/number}",',
#  '            "events_url": "https://api.github.com/repos/bmm522/Y2K/events",',
#  '            "assignees_url": "https://api.github.com/repos/bmm522/Y2K/assignees{/user}",',
#  '            "branches_url": "https://api.github.com/repos/bmm522/Y2K/branches{/branch}",',
#  '            "tags_url": "https://api.github.com/repos/bmm522/Y2K/tags",',
#  '            "blobs_url": "https://api.github.com/repos/bmm522/Y2K/git/blobs{/sha}",',
#  '            "git_tags_url": "https://api.github.com/repos/bmm522/Y2K/git/tags{/sha}",',
#  '            "git_refs_url": "https://api.github.com/repos/bmm522/Y2K/git/refs{/sha}",',
#  '            "trees_url": "https://api.github.com/repos/bmm522/Y2K/git/trees{/sha}",',
#  '            "statuses_url": "https://api.github.com/repos/bmm522/Y2K/statuses/{sha}",',
#  '            "languages_url": "https://api.github.com/repos/bmm522/Y2K/languages",',
#  '            "stargazers_url": "https://api.github.com/repos/bmm522/Y2K/stargazers",',
#  '            "contributors_url": "https://api.github.com/repos/bmm522/Y2K/contributors",',
#  '            "subscribers_url": "https://api.github.com/repos/bmm522/Y2K/subscribers",',
#  '            "subscription_url": "https://api.github.com/repos/bmm522/Y2K/subscription",',
#  '            "commits_url": "https://api.github.com/repos/bmm522/Y2K/commits{/sha}",',
#  '            "git_commits_url": "https://api.github.com/repos/bmm522/Y2K/git/commits{/sha}",',
#  '            "comments_url": "https://api.github.com/repos/bmm522/Y2K/comments{/number}",',
#  '            "issue_comment_url": "https://api.github.com/repos/bmm522/Y2K/issues/comments{/number}",',
#  '            "contents_url": "https://api.github.com/repos/bmm522/Y2K/contents/{+path}",',
#  '            "compare_url": "https://api.github.com/repos/bmm522/Y2K/compare/{base}...{head}",',
#  '            "merges_url": "https://api.github.com/repos/bmm522/Y2K/merges",',
#  '            "archive_url": "https://api.github.com/repos/bmm522/Y2K/{archive_format}{/ref}",',
#  '            "downloads_url": "https://api.github.com/repos/bmm522/Y2K/downloads",',
#  '            "issues_url": "https://api.github.com/repos/bmm522/Y2K/issues{/number}",',
#  '            "pulls_url": "https://api.github.com/repos/bmm522/Y2K/pulls{/number}",',
#  '            "milestones_url": "https://api.github.com/repos/bmm522/Y2K/milestones{/number}",',
#  '            "notifications_url": "https://api.github.com/repos/bmm522/Y2K/notifications{?since,all,participating}",',
#  '            "labels_url": "https://api.github.com/repos/bmm522/Y2K/labels{/name}",',
#  '            "releases_url": "https://api.github.com/repos/bmm522/Y2K/releases{/id}",',
#  '            "deployments_url": "https://api.github.com/repos/bmm522/Y2K/deployments",',
#  '            "created_at": "2022-11-18T14:15:08Z",',
#  '            "updated_at": "2022-11-18T14:21:00Z",',
#  '            "pushed_at": "2022-12-01T08:19:43Z",',
#  '            "git_url": "git://github.com/bmm522/Y2K.git",',
#  '            "ssh_url": "git@github.com:bmm522/Y2K.git",',
#  '            "clone_url": "https://github.com/bmm522/Y2K.git",',
#  '            "svn_url": "https://github.com/bmm522/Y2K",',
#  '            "homepage": null,',
#  '            "size": 5307,',
#  '            "stargazers_count": 0,',
#  '            "watchers_count": 0,',
#  '            "language": "Java",',
#  '            "has_issues": true,',
#  '            "has_projects": true,',
#  '            "has_downloads": true,',
#  '            "has_wiki": true,',
#  '            "has_pages": false,',
#  '            "has_discussions": false,',
#  '            "forks_count": 0,',
#  '            "mirror_url": null,',
#  '            "archived": false,',
#  '            "disabled": false,',
#  '            "open_issues_count": 2,',
#  '            "license": null,',
#  '            "allow_forking": true,',
#  '            "is_template": false,',
#  '            "web_commit_signoff_required": false,',
#  '            "topics": [',
#  '',
#  '            ],',
#  '            "visibility": "public",',
#  '            "forks": 0,',
#  '            "open_issues": 2,',
#  '            "watchers": 0,',
#  '            "default_branch": "master"',
#  '          }',
#  '        },',
#  '        "base": {',
#  '          "label": "bmm522:master",',
#  '          "ref": "master",',
#  '          "sha": "0c5fd93bb244b1479f83e2ab867445f89d1c3326",',
#  '          "user": {',
#  '            "login": "bmm522",',
#  '            "id": 102157839,',
#  '            "node_id": "U_kgDOBhbODw",',
#  '            "avatar_url": "https://avatars.githubusercontent.com/u/102157839?v=4",',
#  '            "gravatar_id": "",',
#  '            "url": "https://api.github.com/users/bmm522",',
#  '            "html_url": "https://github.com/bmm522",',
#  '            "followers_url": "https://api.github.com/users/bmm522/followers",',
#  '            "following_url": "https://api.github.com/users/bmm522/following{/other_user}",',
#  '            "gists_url": "https://api.github.com/users/bmm522/gists{/gist_id}",',
#  '            "starred_url": "https://api.github.com/users/bmm522/starred{/owner}{/repo}",',
#  '            "subscriptions_url": "https://api.github.com/users/bmm522/subscriptions",',
#  '            "organizations_url": "https://api.github.com/users/bmm522/orgs",',
#  '            "repos_url": "https://api.github.com/users/bmm522/repos",',
#  '            "events_url": "https://api.github.com/users/bmm522/events{/privacy}",',
#  '            "received_events_url": "https://api.github.com/users/bmm522/received_events",',
#  '            "type": "User",',
#  '            "site_admin": false',
#  '          },',
#  '          "repo": {',
#  '            "id": 567761819,',
#  '            "node_id": "R_kgDOIddbmw",',
#  '            "name": "Y2K",',
#  '            "full_name": "bmm522/Y2K",',
#  '            "private": false,',
#  '            "owner": {',
#  '              "login": "bmm522",',
#  '              "id": 102157839,',
#  '              "node_id": "U_kgDOBhbODw",',
#  '              "avatar_url": "https://avatars.githubusercontent.com/u/102157839?v=4",',
#  '              "gravatar_id": "",',
#  '              "url": "https://api.github.com/users/bmm522",',
#  '              "html_url": "https://github.com/bmm522",',
#  '              "followers_url": "https://api.github.com/users/bmm522/followers",',
#  '              "following_url": "https://api.github.com/users/bmm522/following{/other_user}",',
#  '              "gists_url": "https://api.github.com/users/bmm522/gists{/gist_id}",',
#  '              "starred_url": "https://api.github.com/users/bmm522/starred{/owner}{/repo}",',
#  '              "subscriptions_url": "https://api.github.com/users/bmm522/subscriptions",',
#  '              "organizations_url": "https://api.github.com/users/bmm522/orgs",',
#  '              "repos_url": "https://api.github.com/users/bmm522/repos",',
#  '              "events_url": "https://api.github.com/users/bmm522/events{/privacy}",',
#  '              "received_events_url": "https://api.github.com/users/bmm522/received_events",',
#  '              "type": "User",',
#  '              "site_admin": false',
#  '            },',
#  '            "html_url": "https://github.com/bmm522/Y2K",',
#  '            "description": null,',
#  '            "fork": false,',
#  '            "url": "https://api.github.com/repos/bmm522/Y2K",',
#  '            "forks_url": "https://api.github.com/repos/bmm522/Y2K/forks",',
#  '            "keys_url": "https://api.github.com/repos/bmm522/Y2K/keys{/key_id}",',
#  '            "collaborators_url": "https://api.github.com/repos/bmm522/Y2K/collaborators{/collaborator}",',
#  '            "teams_url": "https://api.github.com/repos/bmm522/Y2K/teams",',
#  '            "hooks_url": "https://api.github.com/repos/bmm522/Y2K/hooks",',
#  '            "issue_events_url": "https://api.github.com/repos/bmm522/Y2K/issues/events{/number}",',
#  '            "events_url": "https://api.github.com/repos/bmm522/Y2K/events",',
#  '            "assignees_url": "https://api.github.com/repos/bmm522/Y2K/assignees{/user}",',
#  '            "branches_url": "https://api.github.com/repos/bmm522/Y2K/branches{/branch}",',
#  '            "tags_url": "https://api.github.com/repos/bmm522/Y2K/tags",',
#  '            "blobs_url": "https://api.github.com/repos/bmm522/Y2K/git/blobs{/sha}",',
#  '            "git_tags_url": "https://api.github.com/repos/bmm522/Y2K/git/tags{/sha}",',
#  '            "git_refs_url": "https://api.github.com/repos/bmm522/Y2K/git/refs{/sha}",',
#  '            "trees_url": "https://api.github.com/repos/bmm522/Y2K/git/trees{/sha}",',
#  '            "statuses_url": "https://api.github.com/repos/bmm522/Y2K/statuses/{sha}",',
#  '            "languages_url": "https://api.github.com/repos/bmm522/Y2K/languages",',
#  '            "stargazers_url": "https://api.github.com/repos/bmm522/Y2K/stargazers",',
#  '            "contributors_url": "https://api.github.com/repos/bmm522/Y2K/contributors",',
#  '            "subscribers_url": "https://api.github.com/repos/bmm522/Y2K/subscribers",',
#  '            "subscription_url": "https://api.github.com/repos/bmm522/Y2K/subscription",',
#  '            "commits_url": "https://api.github.com/repos/bmm522/Y2K/commits{/sha}",',
#  '            "git_commits_url": "https://api.github.com/repos/bmm522/Y2K/git/commits{/sha}",',
#  '            "comments_url": "https://api.github.com/repos/bmm522/Y2K/comments{/number}",',
#  '            "issue_comment_url": "https://api.github.com/repos/bmm522/Y2K/issues/comments{/number}",',
#  '            "contents_url": "https://api.github.com/repos/bmm522/Y2K/contents/{+path}",',
#  '            "compare_url": "https://api.github.com/repos/bmm522/Y2K/compare/{base}...{head}",',
#  '            "merges_url": "https://api.github.com/repos/bmm522/Y2K/merges",',
#  '            "archive_url": "https://api.github.com/repos/bmm522/Y2K/{archive_format}{/ref}",',
#  '            "downloads_url": "https://api.github.com/repos/bmm522/Y2K/downloads",',
#  '            "issues_url": "https://api.github.com/repos/bmm522/Y2K/issues{/number}",',
#  '            "pulls_url": "https://api.github.com/repos/bmm522/Y2K/pulls{/number}",',
#  '            "milestones_url": "https://api.github.com/repos/bmm522/Y2K/milestones{/number}",',
#  '            "notifications_url": "https://api.github.com/repos/bmm522/Y2K/notifications{?since,all,participating}",',
#  '            "labels_url": "https://api.github.com/repos/bmm522/Y2K/labels{/name}",',
#  '            "releases_url": "https://api.github.com/repos/bmm522/Y2K/releases{/id}",',
#  '            "deployments_url": "https://api.github.com/repos/bmm522/Y2K/deployments",',
#  '            "created_at": "2022-11-18T14:15:08Z",',
#  '            "updated_at": "2022-11-18T14:21:00Z",',
#  '            "pushed_at": "2022-12-01T08:19:43Z",',
#  '            "git_url": "git://github.com/bmm522/Y2K.git",',
#  '            "ssh_url": "git@github.com:bmm522/Y2K.git",',
#  '            "clone_url": "https://github.com/bmm522/Y2K.git",',
#  '            "svn_url": "https://github.com/bmm522/Y2K",',
#  '            "homepage": null,',
#  '            "size": 5307,',
#  '            "stargazers_count": 0,',
#  '            "watchers_count": 0,',
#  '            "language": "Java",',
#  '            "has_issues": true,',
#  '            "has_projects": true,',
#  '            "has_downloads": true,',
#  '            "has_wiki": true,',
#  '            "has_pages": false,',
#  '            "has_discussions": false,',
#  '            "forks_count": 0,',
#  '            "mirror_url": null,',
#  '            "archived": false,',
#  '            "disabled": false,',
#  '            "open_issues_count": 2,',
#  '            "license": null,',
#  '            "allow_forking": true,',
#  '            "is_template": false,',
#  '            "web_commit_signoff_required": false,',
#  '            "topics": [',
#  '',
#  '            ],',
#  '            "visibility": "public",',
#  '            "forks": 0,',
#  '            "open_issues": 2,',
#  '            "watchers": 0,',
#  '            "default_branch": "master"',
#  '          }',
#  '        },',
#  '        "_links": {',
#  '          "self": {',
#  '            "href": "https://api.github.com/repos/bmm522/Y2K/pulls/93"',
#  '          },',
#  '          "html": {',
#  '            "href": "https://github.com/bmm522/Y2K/pull/93"',
#  '          },',
#  '          "issue": {',
#  '            "href": "https://api.github.com/repos/bmm522/Y2K/issues/93"',
#  '          },',
#  '          "comments": {',
#  '            "href": "https://api.github.com/repos/bmm522/Y2K/issues/93/comments"',
#  '          },',
#  '          "review_comments": {',
#  '            "href": "https://api.github.com/repos/bmm522/Y2K/pulls/93/comments"',
#  '          },',
#  '          "review_comment": {',
#  '            "href": "https://api.github.com/repos/bmm522/Y2K/pulls/comments{/number}"',
#  '          },',
#  '          "commits": {',
#  '            "href": "https://api.github.com/repos/bmm522/Y2K/pulls/93/commits"',
#  '          },',
#  '          "statuses": {',
#  '            "href": "https://api.github.com/repos/bmm522/Y2K/statuses/f06dd82fb1d7860d99de3a80d9d7bccae10dd9ac"',
#  '          }',
#  '        },',
#  '        "author_association": "OWNER",',
#  '        "auto_merge": null,',
#  '        "active_lock_reason": null,',
#  '        "merged": false,',
#  '        "mergeable": null,',
#  '        "rebaseable": null,',
#  '        "mergeable_state": "unknown",',
#  '        "merged_by": null,',
#  '        "comments": 0,',
#  '        "review_comments": 0,',
#  ...]

# %% [markdown]
# ## Get Insight With SQL

# %% [markdown]
# #### Example 1
#
# ```sql
# SELECT * FROM github_events LIMIT 1;
# ```
#
# ```sql
# EXPLAIN SELECT * FROM github_events LIMIT 1;
# ```
