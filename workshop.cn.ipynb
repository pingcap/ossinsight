# %% [markdown]
# # Mini OSS Insight Workshop
#
# 👏 欢迎来到 Mini OSS Insight 的 Workshop!
#
# 这是关于 Workshop 的完整指南，你可以通过阅读该指南一步一步地搭建起一个 Mini 版的 OSS Insight，并在过程掌握一些使用 TiDB / TiDB Cloud 进行数据分析的技巧。

# %% [markdown]
# ## 准备
#
# 在开始之前，你需要确保在你的开发环境中已经安装了以下软件/工具：
#
# - GitHub 账号 - 用于访问 GitHub API 获取 events 数据
# - GitHub Codespaces 开发环境 - 本教程通过 [GitHub Codespaces](https://github.com/codespaces) 准备开发环境
# - 可供连接的 TiDB 集群 - 用于存储 events 数据以及通过 SQL 语句进行数据分析
# - MyCLI - 连接到 TiDB 集群
# - Python 3.x and pip - Jupyter Notebook 需要的运行时环境
#
# > **注意**
# >
# > 在开始后续步骤之前，请在 [pingcap/ossinsight](https://github.com/pingcap/ossinsight) 仓库页面的右上角点击 Fork 按钮来创建你的 Fork 仓库，然后点击 “Code” > “New with Options” 按钮来创建你的 Codespaces 开发环境，以便在后续的步骤当中你有足够的权限修改 Github Codespaces Secrets。
# >

# %% [markdown]
# ### 1. 创建 Personal Access Token
#
# > **Note**
# >
# > 如果你使用 GitHub Codespaces 来操作该指南, 你可以跳过下面的步骤，因为在 Codespaces [默认的环境变量](https://docs.github.com/en/codespaces/developing-in-codespaces/default-environment-variables-for-your-codespace)当中已经包含了 `GITHUB_TOKEN` 变量。
# >
#
# 在登录到你的 GitHub 账号之后，你可以在个人设置页面[创建一个新的 Personal Access Token](https://github.com/settings/personal-access-tokens/new)，在后续步骤当中将使用该 Token 来访问 GitHub API。
#
# <center>
#   <img align="middle" width="800" alt="Create a New GitHub Personal Access Token" src="https://user-images.githubusercontent.com/5086433/204564273-93cccbe4-d10a-4d1b-a9d1-112a1144712a.png">
#   <p><i>创建一个新的 Personal Access Token</i></p>
# </center>

# %% [markdown]
# ### 2. 准备 TiDB 集群
#
# 你需要开启一个 TiDB 集群。你可以通过查看文档 [TiDB Cloud Quick Start](https://docs.pingcap.com/tidbcloud/tidb-cloud-quickstart#step-1-create-a-tidb-cluster) 文档学习如何创建一个 **Serverless tier** 集群，这可能会需要 20～25s 的时间。
#
# 在你创建完集群之后，可以进入到集群的详情页。在这个页面，你可以在 **Connection** 面板中找到数据库集群的连接信息。
#
# <center>
#   <img align="middle" width="800" alt="Serverless Tier Cluster Manage Interface" src="https://user-images.githubusercontent.com/5086433/204476069-0ddbdf6f-419c-4291-b929-ccfbd2f5ea5f.png">
#   <p><i>Serverless Tier 集群管理界面</i></p>
# </center>
#
# 你可以通过点开集群详情页右上角的集群修改菜单，点击其中的 “Security Settings” 按钮进入到安全设置窗口。
#
# <center>
#   <img width="480" alt="The Cluster Modify Menu" src="https://user-images.githubusercontent.com/85985765/204876779-3a4c6ac4-8814-47cd-b82a-40eb5e4d8f96.png">
#   <p><i>TiDB Cloud 集群修改菜单</i></p>
# </center>
#
# 在该窗口上点击 “Generate” 按钮来生成 root 用户密码，保存以便后续使用，
#
# <center>
#   <img width="720" alt="Security Settings" src="https://user-images.githubusercontent.com/85985765/204877348-5c3e9012-f7bf-42e9-8a03-fd9f14bfc826.png">
#   <p><i>TiDB Cloud 集群安全设置窗口</i></p>
# </center>

# %% [markdown]
# ### 3. 设置环境变量
#
# 点击代码块左侧的执行按钮，运行下面的 Python 代码块。这段代码块将会一步一步引导你将上面准备的数据库连接信息配置到环境变量当中，以便后续步骤使用。

# %%
# ← Execute the follwoing script to load environment variable.
import getpass
import os

github_user = os.getenv("GITHUB_USER")
github_repo = os.getenv("GITHUB_REPOSITORY")
if (github_user in github_repo) is False:
    print("You must run the script in your fork repository.")
    exit();

api_server_dot_env="./packages/api-server/.env"
if os.path.exists(api_server_dot_env): 
    con = input(api_server_dot_env + " file already exists, do you want to overwrite it? (y/n) [y]")
    if con != 'y':
        exit();

# Config GitHub personal access token.
github_token = ""
if os.getenv('GITHUB_TOKEN') is None:
    github_token = getpass.getpass(prompt='Enter your personal access token of GitHub: ')
else:
    github_token = os.getenv('GITHUB_TOKEN')

# Config database connection.
db_endpoint = input("The endpoint of TiDB cluster: ")
db_port = input("The port of TiDB cluster [4000]: ")

if db_port == "":
    db_port = "4000"

db_username = input("The username of TiDB cluster: ")
db_password = getpass.getpass(prompt='Enter the password of TiDB cluster: ')
db_name = "ossinsight"
db_enable_ssl = input("Enable ssl connection to the TiDB cluster? (y/n) [y]") or "y"
db_ssl_config='&ssl={"minVersion":"TLSv1.2"}'
if db_enable_ssl == "n":
    db_ssl_config = ""

api_database_url = "mysql://{}:{}@{}:{}/{}?connectionLimit=100&queueLimit=10000{}\n".format(
    db_username, db_password, db_endpoint, db_port, db_name, db_ssl_config
)

etl_database_url = "tidb://{}:{}@{}:{}/{}".format(
    db_username, db_password, db_endpoint, db_port, db_name
)

os.system(f"gh secret set DB_ENDPOINT --body {db_endpoint} -a codespaces --repo {github_repo}")
os.system(f"gh secret set DB_PORT --body {db_port} -a codespaces --repo {github_repo}")
os.system(f"gh secret set DB_USERNAME --body {db_username} -a codespaces --repo {github_repo}")
os.system(f"gh secret set DB_PASSWORD --body {db_password} -a codespaces --repo {github_repo}")
os.system(f"gh secret set DB_NAME --body {db_name} -a codespaces --repo {github_repo}")
os.system(f"gh secret set DB_ENABLE_SSL --body {db_enable_ssl} -a codespaces --repo {github_repo}")
os.system(f"gh secret set API_DATABASE_URL --body '{api_database_url}' -a codespaces --repo {github_repo}")
os.system(f"gh secret set ETL_DATABASE_URL --body '{etl_database_url}' -a codespaces --repo {github_repo}")

# Write to ./packages/api-server/.env file.
with open(api_server_dot_env, "w") as file:
    file.write(
        "DATABASE_URL={}".format(api_database_url)
    )
    file.write("ENABLE_CACHE=false\n")
    file.write("GITHUB_ACCESS_TOKENS={}\n".format(github_token))

print("Setup successfully!")
# Out:
# Setup successfully!

# %% [markdown]
# 上面的程序会将你输入的配置自动添加到 [GitHub Codespaces Secrets](https://docs.github.com/en/codespaces/managing-your-codespaces/managing-encrypted-secrets-for-your-codespaces) 的设置当中，待程序执行完成后点击右下角的 “Reload to apply” 按钮将环境变量加载到 Codespaces 环境。
#
# <center>
#     <img width="467" alt="image" src="https://user-images.githubusercontent.com/88522432/206100583-518b0465-79b0-46c0-bedb-c5aef3657cee.png">
#     <p><i>Reload to apply the GitHub Codepsace Secrets</i></p>
# </center>

# %% [markdown]
# ### 4. 验证是否能够连接到 TiDB 集群
#
# 上执行下面的 SQL 语句验证是否能够连接到 TiDB 集群:

# %%
# !mycli -h ${DB_ENDPOINT} -P ${DB_PORT} -u ${DB_USERNAME} -p ${DB_PASSWORD} -D test \
    --ssl-ca=/etc/ssl/certs/ca-certificates.crt \
    --ssl-verify-server-cert \
     -e 'SELECT tidb_version()\G'
# Out:
# tidb_version()
# Release Version: v6.3.0-serverless\nEdition: Community\nGit Commit Hash: e87c16b215d518aed4921b8ef3b13e90e3ed6e2d\nGit Branch: release-6.3-serverless\nUTC Build Time: 2022-11-25 09:31:28\nGoVersion: go1.19\nRace Enabled: false\nTiKV Min Version: 6.1.0\nCheck Table Before Drop: false\nStore: tikv

# %% [markdown]
# 如果成功执行，你会看到 TiDB 集群的版本信息。

# %% [markdown]
# ## 导入数据
#
# 通过 [GitHub 的 API 文档](https://docs.github.com/en/rest/activity/events), 我们知道可以通过请求 `/events` API 来 GitHub 上所有公开仓库的公开事件数据，这个数据的推送是准实时的，GitHub 设定的 5 分钟的延迟。
#
# 你可以执行下面的命令查看这个接口返回数据的结构：

# %%
# !curl -s \
  -H "Accept: application/vnd.github.v3+json" \
  -H "Authorization: token $GITHUB_TOKEN" \
  https://api.github.com/events?per_page=5
# Out:
# [
#   {
#     "id": "25710628254",
#     "type": "PullRequestEvent",
#     "actor": {
#       "id": 49699333,
#       "login": "dependabot[bot]",
#       "display_login": "dependabot",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/dependabot[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/49699333?"
#     },
#     "repo": {
#       "id": 232528370,
#       "name": "BlueForeverI/fifa-tournament-graph-api",
#       "url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api"
#     },
#     "payload": {
#       "action": "opened",
#       "number": 2,
#       "pull_request": {
#         "url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/pulls/2",
#         "id": 1150780004,
#         "node_id": "PR_kwDODdwZ8s5El4Jk",
#         "html_url": "https://github.com/BlueForeverI/fifa-tournament-graph-api/pull/2",
#         "diff_url": "https://github.com/BlueForeverI/fifa-tournament-graph-api/pull/2.diff",
#         "patch_url": "https://github.com/BlueForeverI/fifa-tournament-graph-api/pull/2.patch",
#         "issue_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/issues/2",
#         "number": 2,
#         "state": "open",
#         "locked": false,
#         "title": "Bump qs, body-parser and express",
#         "user": {
#           "login": "dependabot[bot]",
#           "id": 49699333,
#           "node_id": "MDM6Qm90NDk2OTkzMzM=",
#           "avatar_url": "https://avatars.githubusercontent.com/in/29110?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/dependabot%5Bbot%5D",
#           "html_url": "https://github.com/apps/dependabot",
#           "followers_url": "https://api.github.com/users/dependabot%5Bbot%5D/followers",
#           "following_url": "https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}",
#           "gists_url": "https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/dependabot%5Bbot%5D/subscriptions",
#           "organizations_url": "https://api.github.com/users/dependabot%5Bbot%5D/orgs",
#           "repos_url": "https://api.github.com/users/dependabot%5Bbot%5D/repos",
#           "events_url": "https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/dependabot%5Bbot%5D/received_events",
#           "type": "Bot",
#           "site_admin": false
#         },
#         "body": "Bumps [qs](https://github.com/ljharb/qs), [body-parser](https://github.com/expressjs/body-parser) and [express](https://github.com/expressjs/express). These dependencies needed to be updated together.\nUpdates `qs` from 6.7.0 to 6.11.0\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href=\"https://github.com/ljharb/qs/blob/main/CHANGELOG.md\">qs's changelog</a>.</em></p>\n<blockquote>\n<h2><strong>6.11.0</strong></h2>\n<ul>\n<li>[New] [Fix] <code>stringify</code>: revert 0e903c0; add <code>commaRoundTrip</code> option (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/442\">#442</a>)</li>\n<li>[readme] fix version badge</li>\n</ul>\n<h2><strong>6.10.5</strong></h2>\n<ul>\n<li>[Fix] <code>stringify</code>: with <code>arrayFormat: comma</code>, properly include an explicit <code>[]</code> on a single-item array (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/434\">#434</a>)</li>\n</ul>\n<h2><strong>6.10.4</strong></h2>\n<ul>\n<li>[Fix] <code>stringify</code>: with <code>arrayFormat: comma</code>, include an explicit <code>[]</code> on a single-item array (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/441\">#441</a>)</li>\n<li>[meta] use <code>npmignore</code> to autogenerate an npmignore file</li>\n<li>[Dev Deps] update <code>eslint</code>, <code>@ljharb/eslint-config</code>, <code>aud</code>, <code>has-symbol</code>, <code>object-inspect</code>, <code>tape</code></li>\n</ul>\n<h2><strong>6.10.3</strong></h2>\n<ul>\n<li>[Fix] <code>parse</code>: ignore <code>__proto__</code> keys (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/428\">#428</a>)</li>\n<li>[Robustness] <code>stringify</code>: avoid relying on a global <code>undefined</code> (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/427\">#427</a>)</li>\n<li>[actions] reuse common workflows</li>\n<li>[Dev Deps] update <code>eslint</code>, <code>@ljharb/eslint-config</code>, <code>object-inspect</code>, <code>tape</code></li>\n</ul>\n<h2><strong>6.10.2</strong></h2>\n<ul>\n<li>[Fix] <code>stringify</code>: actually fix cyclic references (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/426\">#426</a>)</li>\n<li>[Fix] <code>stringify</code>: avoid encoding arrayformat comma when <code>encodeValuesOnly = true</code> (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/424\">#424</a>)</li>\n<li>[readme] remove travis badge; add github actions/codecov badges; update URLs</li>\n<li>[Docs] add note and links for coercing primitive values (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/408\">#408</a>)</li>\n<li>[actions] update codecov uploader</li>\n<li>[actions] update workflows</li>\n<li>[Tests] clean up stringify tests slightly</li>\n<li>[Dev Deps] update <code>eslint</code>, <code>@ljharb/eslint-config</code>, <code>aud</code>, <code>object-inspect</code>, <code>safe-publish-latest</code>, <code>tape</code></li>\n</ul>\n<h2><strong>6.10.1</strong></h2>\n<ul>\n<li>[Fix] <code>stringify</code>: avoid exception on repeated object values (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/402\">#402</a>)</li>\n</ul>\n<h2><strong>6.10.0</strong></h2>\n<ul>\n<li>[New] <code>stringify</code>: throw on cycles, instead of an infinite loop (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/395\">#395</a>, <a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/394\">#394</a>, <a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/393\">#393</a>)</li>\n<li>[New] <code>parse</code>: add <code>allowSparse</code> option for collapsing arrays with missing indices (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/312\">#312</a>)</li>\n<li>[meta] fix README.md (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/399\">#399</a>)</li>\n<li>[meta] only run <code>npm run dist</code> in publish, not install</li>\n<li>[Dev Deps] update <code>eslint ...
#         "created_at": "2022-12-07T06:13:33Z",
#         "updated_at": "2022-12-07T06:13:33Z",
#         "closed_at": null,
#         "merged_at": null,
#         "merge_commit_sha": null,
#         "assignee": null,
#         "assignees": [
#
#         ],
#         "requested_reviewers": [
#
#         ],
#         "requested_teams": [
#
#         ],
#         "labels": [
#
#         ],
#         "milestone": null,
#         "draft": false,
#         "commits_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/pulls/2/commits",
#         "review_comments_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/pulls/2/comments",
#         "review_comment_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/pulls/comments{/number}",
#         "comments_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/issues/2/comments",
#         "statuses_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/statuses/c838a33aa0e6f315a9b12fd7d0e239a3a6b6ac72",
#         "head": {
#           "label": "BlueForeverI:dependabot/npm_and_yarn/qs-and-body-parser-and-express-6.11.0",
#           "ref": "dependabot/npm_and_yarn/qs-and-body-parser-and-express-6.11.0",
#           "sha": "c838a33aa0e6f315a9b12fd7d0e239a3a6b6ac72",
#           "user": {
#             "login": "BlueForeverI",
#             "id": 1979715,
#             "node_id": "MDQ6VXNlcjE5Nzk3MTU=",
#             "avatar_url": "https://avatars.githubusercontent.com/u/1979715?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/BlueForeverI",
#             "html_url": "https://github.com/BlueForeverI",
#             "followers_url": "https://api.github.com/users/BlueForeverI/followers",
#             "following_url": "https://api.github.com/users/BlueForeverI/following{/other_user}",
#             "gists_url": "https://api.github.com/users/BlueForeverI/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/BlueForeverI/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/BlueForeverI/subscriptions",
#             "organizations_url": "https://api.github.com/users/BlueForeverI/orgs",
#             "repos_url": "https://api.github.com/users/BlueForeverI/repos",
#             "events_url": "https://api.github.com/users/BlueForeverI/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/BlueForeverI/received_events",
#             "type": "User",
#             "site_admin": false
#           },
#           "repo": {
#             "id": 232528370,
#             "node_id": "MDEwOlJlcG9zaXRvcnkyMzI1MjgzNzA=",
#             "name": "fifa-tournament-graph-api",
#             "full_name": "BlueForeverI/fifa-tournament-graph-api",
#             "private": false,
#             "owner": {
#               "login": "BlueForeverI",
#               "id": 1979715,
#               "node_id": "MDQ6VXNlcjE5Nzk3MTU=",
#               "avatar_url": "https://avatars.githubusercontent.com/u/1979715?v=4",
#               "gravatar_id": "",
#               "url": "https://api.github.com/users/BlueForeverI",
#               "html_url": "https://github.com/BlueForeverI",
#               "followers_url": "https://api.github.com/users/BlueForeverI/followers",
#               "following_url": "https://api.github.com/users/BlueForeverI/following{/other_user}",
#               "gists_url": "https://api.github.com/users/BlueForeverI/gists{/gist_id}",
#               "starred_url": "https://api.github.com/users/BlueForeverI/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/BlueForeverI/subscriptions",
#               "organizations_url": "https://api.github.com/users/BlueForeverI/orgs",
#               "repos_url": "https://api.github.com/users/BlueForeverI/repos",
#               "events_url": "https://api.github.com/users/BlueForeverI/events{/privacy}",
#               "received_events_url": "https://api.github.com/users/BlueForeverI/received_events",
#               "type": "User",
#               "site_admin": false
#             },
#             "html_url": "https://github.com/BlueForeverI/fifa-tournament-graph-api",
#             "description": "GraphQL API for the FIFA Tournament application",
#             "fork": false,
#             "url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api",
#             "forks_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/forks",
#             "keys_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/keys{/key_id}",
#             "collaborators_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/collaborators{/collaborator}",
#             "teams_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/teams",
#             "hooks_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/hooks",
#             "issue_events_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/issues/events{/number}",
#             "events_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/events",
#             "assignees_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/assignees{/user}",
#             "branches_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/branches{/branch}",
#             "tags_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/tags",
#             "blobs_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/git/blobs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/git/tags{/sha}",
#             "git_refs_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/git/refs{/sha}",
#             "trees_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/git/trees{/sha}",
#             "statuses_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/statuses/{sha}",
#             "languages_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/languages",
#             "stargazers_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/stargazers",
#             "contributors_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/contributors",
#             "subscribers_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/subscribers",
#             "subscription_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/subscription",
#             "commits_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/commits{/sha}",
#             "git_commits_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/git/commits{/sha}",
#             "comments_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/comments{/number}",
#             "issue_comment_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/issues/comments{/number}",
#             "contents_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/contents/{+path}",
#             "compare_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/compare/{base}...{head}",
#             "merges_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/merges",
#             "archive_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/{archive_format}{/ref}",
#             "downloads_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/downloads",
#             "issues_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/issues{/number}",
#             "pulls_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/pulls{/number}",
#             "milestones_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/milestones{/number}",
#             "notifications_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/notifications{?since,all,participating}",
#             "labels_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/labels{/name}",
#             "releases_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/releases{/id}",
#             "deployments_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/deployments",
#             "created_at": "2020-01-08T09:36:07Z",
#             "updated_at": "2020-03-22T11:10:56Z",
#             "pushed_at": "2022-12-07T06:13:34Z",
#             "git_url": "git://github.com/BlueForeverI/fifa-tournament-graph-api.git",
#             "ssh_url": "git@github.com:BlueForeverI/fifa-tournament-graph-api.git",
#             "clone_url": "https://github.com/BlueForeverI/fifa-tournament-graph-api.git",
#             "svn_url": "https://github.com/BlueForeverI/fifa-tournament-graph-api",
#             "homepage": null,
#             "size": 55,
#             "stargazers_count": 0,
#             "watchers_count": 0,
#             "language": "TypeScript",
#             "has_issues": true,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": true,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 0,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 2,
#             "license": {
#               "key": "mit",
#               "name": "MIT License",
#               "spdx_id": "MIT",
#               "url": "https://api.github.com/licenses/mit",
#               "node_id": "MDc6TGljZW5zZTEz"
#             },
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [
#
#             ],
#             "visibility": "public",
#             "forks": 0,
#             "open_issues": 2,
#             "watchers": 0,
#             "default_branch": "master"
#           }
#         },
#         "base": {
#           "label": "BlueForeverI:master",
#           "ref": "master",
#           "sha": "3490da6d31ad82f0b720a0c7a1a611659660e4dd",
#           "user": {
#             "login": "BlueForeverI",
#             "id": 1979715,
#             "node_id": "MDQ6VXNlcjE5Nzk3MTU=",
#             "avatar_url": "https://avatars.githubusercontent.com/u/1979715?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/BlueForeverI",
#             "html_url": "https://github.com/BlueForeverI",
#             "followers_url": "https://api.github.com/users/BlueForeverI/followers",
#             "following_url": "https://api.github.com/users/BlueForeverI/following{/other_user}",
#             "gists_url": "https://api.github.com/users/BlueForeverI/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/BlueForeverI/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/BlueForeverI/subscriptions",
#             "organizations_url": "https://api.github.com/users/BlueForeverI/orgs",
#             "repos_url": "https://api.github.com/users/BlueForeverI/repos",
#             "events_url": "https://api.github.com/users/BlueForeverI/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/BlueForeverI/received_events",
#             "type": "User",
#             "site_admin": false
#           },
#           "repo": {
#             "id": 232528370,
#             "node_id": "MDEwOlJlcG9zaXRvcnkyMzI1MjgzNzA=",
#             "name": "fifa-tournament-graph-api",
#             "full_name": "BlueForeverI/fifa-tournament-graph-api",
#             "private": false,
#             "owner": {
#               "login": "BlueForeverI",
#               "id": 1979715,
#               "node_id": "MDQ6VXNlcjE5Nzk3MTU=",
#               "avatar_url": "https://avatars.githubusercontent.com/u/1979715?v=4",
#               "gravatar_id": "",
#               "url": "https://api.github.com/users/BlueForeverI",
#               "html_url": "https://github.com/BlueForeverI",
#               "followers_url": "https://api.github.com/users/BlueForeverI/followers",
#               "following_url": "https://api.github.com/users/BlueForeverI/following{/other_user}",
#               "gists_url": "https://api.github.com/users/BlueForeverI/gists{/gist_id}",
#               "starred_url": "https://api.github.com/users/BlueForeverI/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/BlueForeverI/subscriptions",
#               "organizations_url": "https://api.github.com/users/BlueForeverI/orgs",
#               "repos_url": "https://api.github.com/users/BlueForeverI/repos",
#               "events_url": "https://api.github.com/users/BlueForeverI/events{/privacy}",
#               "received_events_url": "https://api.github.com/users/BlueForeverI/received_events",
#               "type": "User",
#               "site_admin": false
#             },
#             "html_url": "https://github.com/BlueForeverI/fifa-tournament-graph-api",
#             "description": "GraphQL API for the FIFA Tournament application",
#             "fork": false,
#             "url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api",
#             "forks_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/forks",
#             "keys_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/keys{/key_id}",
#             "collaborators_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/collaborators{/collaborator}",
#             "teams_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/teams",
#             "hooks_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/hooks",
#             "issue_events_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/issues/events{/number}",
#             "events_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/events",
#             "assignees_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/assignees{/user}",
#             "branches_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/branches{/branch}",
#             "tags_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/tags",
#             "blobs_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/git/blobs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/git/tags{/sha}",
#             "git_refs_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/git/refs{/sha}",
#             "trees_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/git/trees{/sha}",
#             "statuses_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/statuses/{sha}",
#             "languages_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/languages",
#             "stargazers_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/stargazers",
#             "contributors_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/contributors",
#             "subscribers_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/subscribers",
#             "subscription_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/subscription",
#             "commits_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/commits{/sha}",
#             "git_commits_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/git/commits{/sha}",
#             "comments_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/comments{/number}",
#             "issue_comment_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/issues/comments{/number}",
#             "contents_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/contents/{+path}",
#             "compare_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/compare/{base}...{head}",
#             "merges_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/merges",
#             "archive_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/{archive_format}{/ref}",
#             "downloads_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/downloads",
#             "issues_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/issues{/number}",
#             "pulls_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/pulls{/number}",
#             "milestones_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/milestones{/number}",
#             "notifications_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/notifications{?since,all,participating}",
#             "labels_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/labels{/name}",
#             "releases_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/releases{/id}",
#             "deployments_url": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/deployments",
#             "created_at": "2020-01-08T09:36:07Z",
#             "updated_at": "2020-03-22T11:10:56Z",
#             "pushed_at": "2022-12-07T06:13:34Z",
#             "git_url": "git://github.com/BlueForeverI/fifa-tournament-graph-api.git",
#             "ssh_url": "git@github.com:BlueForeverI/fifa-tournament-graph-api.git",
#             "clone_url": "https://github.com/BlueForeverI/fifa-tournament-graph-api.git",
#             "svn_url": "https://github.com/BlueForeverI/fifa-tournament-graph-api",
#             "homepage": null,
#             "size": 55,
#             "stargazers_count": 0,
#             "watchers_count": 0,
#             "language": "TypeScript",
#             "has_issues": true,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": true,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 0,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 2,
#             "license": {
#               "key": "mit",
#               "name": "MIT License",
#               "spdx_id": "MIT",
#               "url": "https://api.github.com/licenses/mit",
#               "node_id": "MDc6TGljZW5zZTEz"
#             },
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [
#
#             ],
#             "visibility": "public",
#             "forks": 0,
#             "open_issues": 2,
#             "watchers": 0,
#             "default_branch": "master"
#           }
#         },
#         "_links": {
#           "self": {
#             "href": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/pulls/2"
#           },
#           "html": {
#             "href": "https://github.com/BlueForeverI/fifa-tournament-graph-api/pull/2"
#           },
#           "issue": {
#             "href": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/issues/2"
#           },
#           "comments": {
#             "href": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/issues/2/comments"
#           },
#           "review_comments": {
#             "href": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/pulls/2/comments"
#           },
#           "review_comment": {
#             "href": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/pulls/comments{/number}"
#           },
#           "commits": {
#             "href": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/pulls/2/commits"
#           },
#           "statuses": {
#             "href": "https://api.github.com/repos/BlueForeverI/fifa-tournament-graph-api/statuses/c838a33aa0e6f315a9b12fd7d0e239a3a6b6ac72"
#           }
#         },
#         "author_association": "NONE",
#         "auto_merge": null,
#         "active_lock_reason": null,
#         "merged": false,
#         "mergeable": null,
#         "rebaseable": null,
#         "mergeable_state": "unknown",
#         "merged_by": null,
#         "comments": 0,
#         "review_comments": 0,
#         "maintainer_can_modify": false,
#         "commits": 1,
#         "additions": 22,
#         "deletions": 22,
#         "changed_files": 1
#       }
#     },
#     "public": true,
#     "created_at": "2022-12-07T06:13:34Z"
#   },
#   {
#     "id": "25710628275",
#     "type": "PushEvent",
#     "actor": {
#       "id": 41898282,
#       "login": "github-actions[bot]",
#       "display_login": "github-actions",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/github-actions[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/41898282?"
#     },
#     "repo": {
#       "id": 336861719,
#       "name": "Anton-Latukha/Anton-Latukha",
#       "url": "https://api.github.com/repos/Anton-Latukha/Anton-Latukha"
#     },
#     "payload": {
#       "push_id": 11909553059,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "5d81ebb19d911e3092d475986ab41e015a052638",
#       "before": "b217f7fdb37edef4d8c58418665544b8bcfdf06c",
#       "commits": [
#         {
#           "sha": "5d81ebb19d911e3092d475986ab41e015a052638",
#           "author": {
#             "email": "41898282+github-actions[bot]@users.noreply.github.com",
#             "name": "github-actions[bot]"
#           },
#           "message": "Update metadata.svg - [Skip GitHub Action]",
#           "distinct": true,
#           "url": "https://api.github.com/repos/Anton-Latukha/Anton-Latukha/commits/5d81ebb19d911e3092d475986ab41e015a052638"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-07T06:13:34Z"
#   },
#   {
#     "id": "25710628241",
#     "type": "PullRequestEvent",
#     "actor": {
#       "id": 49699333,
#       "login": "dependabot[bot]",
#       "display_login": "dependabot",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/dependabot[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/49699333?"
#     },
#     "repo": {
#       "id": 232494503,
#       "name": "chanurholis/face-api.js",
#       "url": "https://api.github.com/repos/chanurholis/face-api.js"
#     },
#     "payload": {
#       "action": "opened",
#       "number": 21,
#       "pull_request": {
#         "url": "https://api.github.com/repos/chanurholis/face-api.js/pulls/21",
#         "id": 1150780009,
#         "node_id": "PR_kwDODduVp85El4Jp",
#         "html_url": "https://github.com/chanurholis/face-api.js/pull/21",
#         "diff_url": "https://github.com/chanurholis/face-api.js/pull/21.diff",
#         "patch_url": "https://github.com/chanurholis/face-api.js/pull/21.patch",
#         "issue_url": "https://api.github.com/repos/chanurholis/face-api.js/issues/21",
#         "number": 21,
#         "state": "open",
#         "locked": false,
#         "title": "Bump qs and body-parser",
#         "user": {
#           "login": "dependabot[bot]",
#           "id": 49699333,
#           "node_id": "MDM6Qm90NDk2OTkzMzM=",
#           "avatar_url": "https://avatars.githubusercontent.com/in/29110?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/dependabot%5Bbot%5D",
#           "html_url": "https://github.com/apps/dependabot",
#           "followers_url": "https://api.github.com/users/dependabot%5Bbot%5D/followers",
#           "following_url": "https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}",
#           "gists_url": "https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/dependabot%5Bbot%5D/subscriptions",
#           "organizations_url": "https://api.github.com/users/dependabot%5Bbot%5D/orgs",
#           "repos_url": "https://api.github.com/users/dependabot%5Bbot%5D/repos",
#           "events_url": "https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/dependabot%5Bbot%5D/received_events",
#           "type": "Bot",
#           "site_admin": false
#         },
#         "body": "Bumps [qs](https://github.com/ljharb/qs) and [body-parser](https://github.com/expressjs/body-parser). These dependencies needed to be updated together.\nUpdates `qs` from 6.7.0 to 6.11.0\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href=\"https://github.com/ljharb/qs/blob/main/CHANGELOG.md\">qs's changelog</a>.</em></p>\n<blockquote>\n<h2><strong>6.11.0</strong></h2>\n<ul>\n<li>[New] [Fix] <code>stringify</code>: revert 0e903c0; add <code>commaRoundTrip</code> option (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/442\">#442</a>)</li>\n<li>[readme] fix version badge</li>\n</ul>\n<h2><strong>6.10.5</strong></h2>\n<ul>\n<li>[Fix] <code>stringify</code>: with <code>arrayFormat: comma</code>, properly include an explicit <code>[]</code> on a single-item array (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/434\">#434</a>)</li>\n</ul>\n<h2><strong>6.10.4</strong></h2>\n<ul>\n<li>[Fix] <code>stringify</code>: with <code>arrayFormat: comma</code>, include an explicit <code>[]</code> on a single-item array (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/441\">#441</a>)</li>\n<li>[meta] use <code>npmignore</code> to autogenerate an npmignore file</li>\n<li>[Dev Deps] update <code>eslint</code>, <code>@ljharb/eslint-config</code>, <code>aud</code>, <code>has-symbol</code>, <code>object-inspect</code>, <code>tape</code></li>\n</ul>\n<h2><strong>6.10.3</strong></h2>\n<ul>\n<li>[Fix] <code>parse</code>: ignore <code>__proto__</code> keys (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/428\">#428</a>)</li>\n<li>[Robustness] <code>stringify</code>: avoid relying on a global <code>undefined</code> (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/427\">#427</a>)</li>\n<li>[actions] reuse common workflows</li>\n<li>[Dev Deps] update <code>eslint</code>, <code>@ljharb/eslint-config</code>, <code>object-inspect</code>, <code>tape</code></li>\n</ul>\n<h2><strong>6.10.2</strong></h2>\n<ul>\n<li>[Fix] <code>stringify</code>: actually fix cyclic references (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/426\">#426</a>)</li>\n<li>[Fix] <code>stringify</code>: avoid encoding arrayformat comma when <code>encodeValuesOnly = true</code> (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/424\">#424</a>)</li>\n<li>[readme] remove travis badge; add github actions/codecov badges; update URLs</li>\n<li>[Docs] add note and links for coercing primitive values (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/408\">#408</a>)</li>\n<li>[actions] update codecov uploader</li>\n<li>[actions] update workflows</li>\n<li>[Tests] clean up stringify tests slightly</li>\n<li>[Dev Deps] update <code>eslint</code>, <code>@ljharb/eslint-config</code>, <code>aud</code>, <code>object-inspect</code>, <code>safe-publish-latest</code>, <code>tape</code></li>\n</ul>\n<h2><strong>6.10.1</strong></h2>\n<ul>\n<li>[Fix] <code>stringify</code>: avoid exception on repeated object values (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/402\">#402</a>)</li>\n</ul>\n<h2><strong>6.10.0</strong></h2>\n<ul>\n<li>[New] <code>stringify</code>: throw on cycles, instead of an infinite loop (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/395\">#395</a>, <a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/394\">#394</a>, <a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/393\">#393</a>)</li>\n<li>[New] <code>parse</code>: add <code>allowSparse</code> option for collapsing arrays with missing indices (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/312\">#312</a>)</li>\n<li>[meta] fix README.md (<a href=\"https://github-redirect.dependabot.com/ljharb/qs/issues/399\">#399</a>)</li>\n<li>[meta] only run <code>npm run dist</code> in publish, not install</li>\n<li>[Dev Deps] update <code>eslint</code>, <code>@ljharb/eslint-config</code>, <cod ...
#         "created_at": "2022-12-07T06:13:33Z",
#         "updated_at": "2022-12-07T06:13:33Z",
#         "closed_at": null,
#         "merged_at": null,
#         "merge_commit_sha": null,
#         "assignee": null,
#         "assignees": [
#
#         ],
#         "requested_reviewers": [
#
#         ],
#         "requested_teams": [
#
#         ],
#         "labels": [
#
#         ],
#         "milestone": null,
#         "draft": false,
#         "commits_url": "https://api.github.com/repos/chanurholis/face-api.js/pulls/21/commits",
#         "review_comments_url": "https://api.github.com/repos/chanurholis/face-api.js/pulls/21/comments",
#         "review_comment_url": "https://api.github.com/repos/chanurholis/face-api.js/pulls/comments{/number}",
#         "comments_url": "https://api.github.com/repos/chanurholis/face-api.js/issues/21/comments",
#         "statuses_url": "https://api.github.com/repos/chanurholis/face-api.js/statuses/b25ea8f44d423cd77cdec7ac24e9587ee1a66f13",
#         "head": {
#           "label": "chanurholis:dependabot/npm_and_yarn/qs-and-body-parser-6.11.0",
#           "ref": "dependabot/npm_and_yarn/qs-and-body-parser-6.11.0",
#           "sha": "b25ea8f44d423cd77cdec7ac24e9587ee1a66f13",
#           "user": {
#             "login": "chanurholis",
#             "id": 55186337,
#             "node_id": "MDQ6VXNlcjU1MTg2MzM3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/55186337?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/chanurholis",
#             "html_url": "https://github.com/chanurholis",
#             "followers_url": "https://api.github.com/users/chanurholis/followers",
#             "following_url": "https://api.github.com/users/chanurholis/following{/other_user}",
#             "gists_url": "https://api.github.com/users/chanurholis/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/chanurholis/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/chanurholis/subscriptions",
#             "organizations_url": "https://api.github.com/users/chanurholis/orgs",
#             "repos_url": "https://api.github.com/users/chanurholis/repos",
#             "events_url": "https://api.github.com/users/chanurholis/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/chanurholis/received_events",
#             "type": "User",
#             "site_admin": false
#           },
#           "repo": {
#             "id": 232494503,
#             "node_id": "MDEwOlJlcG9zaXRvcnkyMzI0OTQ1MDM=",
#             "name": "face-api.js",
#             "full_name": "chanurholis/face-api.js",
#             "private": false,
#             "owner": {
#               "login": "chanurholis",
#               "id": 55186337,
#               "node_id": "MDQ6VXNlcjU1MTg2MzM3",
#               "avatar_url": "https://avatars.githubusercontent.com/u/55186337?v=4",
#               "gravatar_id": "",
#               "url": "https://api.github.com/users/chanurholis",
#               "html_url": "https://github.com/chanurholis",
#               "followers_url": "https://api.github.com/users/chanurholis/followers",
#               "following_url": "https://api.github.com/users/chanurholis/following{/other_user}",
#               "gists_url": "https://api.github.com/users/chanurholis/gists{/gist_id}",
#               "starred_url": "https://api.github.com/users/chanurholis/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/chanurholis/subscriptions",
#               "organizations_url": "https://api.github.com/users/chanurholis/orgs",
#               "repos_url": "https://api.github.com/users/chanurholis/repos",
#               "events_url": "https://api.github.com/users/chanurholis/events{/privacy}",
#               "received_events_url": "https://api.github.com/users/chanurholis/received_events",
#               "type": "User",
#               "site_admin": false
#             },
#             "html_url": "https://github.com/chanurholis/face-api.js",
#             "description": null,
#             "fork": false,
#             "url": "https://api.github.com/repos/chanurholis/face-api.js",
#             "forks_url": "https://api.github.com/repos/chanurholis/face-api.js/forks",
#             "keys_url": "https://api.github.com/repos/chanurholis/face-api.js/keys{/key_id}",
#             "collaborators_url": "https://api.github.com/repos/chanurholis/face-api.js/collaborators{/collaborator}",
#             "teams_url": "https://api.github.com/repos/chanurholis/face-api.js/teams",
#             "hooks_url": "https://api.github.com/repos/chanurholis/face-api.js/hooks",
#             "issue_events_url": "https://api.github.com/repos/chanurholis/face-api.js/issues/events{/number}",
#             "events_url": "https://api.github.com/repos/chanurholis/face-api.js/events",
#             "assignees_url": "https://api.github.com/repos/chanurholis/face-api.js/assignees{/user}",
#             "branches_url": "https://api.github.com/repos/chanurholis/face-api.js/branches{/branch}",
#             "tags_url": "https://api.github.com/repos/chanurholis/face-api.js/tags",
#             "blobs_url": "https://api.github.com/repos/chanurholis/face-api.js/git/blobs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/chanurholis/face-api.js/git/tags{/sha}",
#             "git_refs_url": "https://api.github.com/repos/chanurholis/face-api.js/git/refs{/sha}",
#             "trees_url": "https://api.github.com/repos/chanurholis/face-api.js/git/trees{/sha}",
#             "statuses_url": "https://api.github.com/repos/chanurholis/face-api.js/statuses/{sha}",
#             "languages_url": "https://api.github.com/repos/chanurholis/face-api.js/languages",
#             "stargazers_url": "https://api.github.com/repos/chanurholis/face-api.js/stargazers",
#             "contributors_url": "https://api.github.com/repos/chanurholis/face-api.js/contributors",
#             "subscribers_url": "https://api.github.com/repos/chanurholis/face-api.js/subscribers",
#             "subscription_url": "https://api.github.com/repos/chanurholis/face-api.js/subscription",
#             "commits_url": "https://api.github.com/repos/chanurholis/face-api.js/commits{/sha}",
#             "git_commits_url": "https://api.github.com/repos/chanurholis/face-api.js/git/commits{/sha}",
#             "comments_url": "https://api.github.com/repos/chanurholis/face-api.js/comments{/number}",
#             "issue_comment_url": "https://api.github.com/repos/chanurholis/face-api.js/issues/comments{/number}",
#             "contents_url": "https://api.github.com/repos/chanurholis/face-api.js/contents/{+path}",
#             "compare_url": "https://api.github.com/repos/chanurholis/face-api.js/compare/{base}...{head}",
#             "merges_url": "https://api.github.com/repos/chanurholis/face-api.js/merges",
#             "archive_url": "https://api.github.com/repos/chanurholis/face-api.js/{archive_format}{/ref}",
#             "downloads_url": "https://api.github.com/repos/chanurholis/face-api.js/downloads",
#             "issues_url": "https://api.github.com/repos/chanurholis/face-api.js/issues{/number}",
#             "pulls_url": "https://api.github.com/repos/chanurholis/face-api.js/pulls{/number}",
#             "milestones_url": "https://api.github.com/repos/chanurholis/face-api.js/milestones{/number}",
#             "notifications_url": "https://api.github.com/repos/chanurholis/face-api.js/notifications{?since,all,participating}",
#             "labels_url": "https://api.github.com/repos/chanurholis/face-api.js/labels{/name}",
#             "releases_url": "https://api.github.com/repos/chanurholis/face-api.js/releases{/id}",
#             "deployments_url": "https://api.github.com/repos/chanurholis/face-api.js/deployments",
#             "created_at": "2020-01-08T06:28:54Z",
#             "updated_at": "2020-01-18T13:34:19Z",
#             "pushed_at": "2022-12-07T06:13:34Z",
#             "git_url": "git://github.com/chanurholis/face-api.js.git",
#             "ssh_url": "git@github.com:chanurholis/face-api.js.git",
#             "clone_url": "https://github.com/chanurholis/face-api.js.git",
#             "svn_url": "https://github.com/chanurholis/face-api.js",
#             "homepage": null,
#             "size": 199901,
#             "stargazers_count": 1,
#             "watchers_count": 1,
#             "language": "TypeScript",
#             "has_issues": true,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": true,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 0,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 13,
#             "license": {
#               "key": "mit",
#               "name": "MIT License",
#               "spdx_id": "MIT",
#               "url": "https://api.github.com/licenses/mit",
#               "node_id": "MDc6TGljZW5zZTEz"
#             },
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [
#
#             ],
#             "visibility": "public",
#             "forks": 0,
#             "open_issues": 13,
#             "watchers": 1,
#             "default_branch": "master"
#           }
#         },
#         "base": {
#           "label": "chanurholis:master",
#           "ref": "master",
#           "sha": "082f6b50dcea28585ca8a83d7ef724b79a542ef5",
#           "user": {
#             "login": "chanurholis",
#             "id": 55186337,
#             "node_id": "MDQ6VXNlcjU1MTg2MzM3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/55186337?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/chanurholis",
#             "html_url": "https://github.com/chanurholis",
#             "followers_url": "https://api.github.com/users/chanurholis/followers",
#             "following_url": "https://api.github.com/users/chanurholis/following{/other_user}",
#             "gists_url": "https://api.github.com/users/chanurholis/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/chanurholis/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/chanurholis/subscriptions",
#             "organizations_url": "https://api.github.com/users/chanurholis/orgs",
#             "repos_url": "https://api.github.com/users/chanurholis/repos",
#             "events_url": "https://api.github.com/users/chanurholis/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/chanurholis/received_events",
#             "type": "User",
#             "site_admin": false
#           },
#           "repo": {
#             "id": 232494503,
#             "node_id": "MDEwOlJlcG9zaXRvcnkyMzI0OTQ1MDM=",
#             "name": "face-api.js",
#             "full_name": "chanurholis/face-api.js",
#             "private": false,
#             "owner": {
#               "login": "chanurholis",
#               "id": 55186337,
#               "node_id": "MDQ6VXNlcjU1MTg2MzM3",
#               "avatar_url": "https://avatars.githubusercontent.com/u/55186337?v=4",
#               "gravatar_id": "",
#               "url": "https://api.github.com/users/chanurholis",
#               "html_url": "https://github.com/chanurholis",
#               "followers_url": "https://api.github.com/users/chanurholis/followers",
#               "following_url": "https://api.github.com/users/chanurholis/following{/other_user}",
#               "gists_url": "https://api.github.com/users/chanurholis/gists{/gist_id}",
#               "starred_url": "https://api.github.com/users/chanurholis/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/chanurholis/subscriptions",
#               "organizations_url": "https://api.github.com/users/chanurholis/orgs",
#               "repos_url": "https://api.github.com/users/chanurholis/repos",
#               "events_url": "https://api.github.com/users/chanurholis/events{/privacy}",
#               "received_events_url": "https://api.github.com/users/chanurholis/received_events",
#               "type": "User",
#               "site_admin": false
#             },
#             "html_url": "https://github.com/chanurholis/face-api.js",
#             "description": null,
#             "fork": false,
#             "url": "https://api.github.com/repos/chanurholis/face-api.js",
#             "forks_url": "https://api.github.com/repos/chanurholis/face-api.js/forks",
#             "keys_url": "https://api.github.com/repos/chanurholis/face-api.js/keys{/key_id}",
#             "collaborators_url": "https://api.github.com/repos/chanurholis/face-api.js/collaborators{/collaborator}",
#             "teams_url": "https://api.github.com/repos/chanurholis/face-api.js/teams",
#             "hooks_url": "https://api.github.com/repos/chanurholis/face-api.js/hooks",
#             "issue_events_url": "https://api.github.com/repos/chanurholis/face-api.js/issues/events{/number}",
#             "events_url": "https://api.github.com/repos/chanurholis/face-api.js/events",
#             "assignees_url": "https://api.github.com/repos/chanurholis/face-api.js/assignees{/user}",
#             "branches_url": "https://api.github.com/repos/chanurholis/face-api.js/branches{/branch}",
#             "tags_url": "https://api.github.com/repos/chanurholis/face-api.js/tags",
#             "blobs_url": "https://api.github.com/repos/chanurholis/face-api.js/git/blobs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/chanurholis/face-api.js/git/tags{/sha}",
#             "git_refs_url": "https://api.github.com/repos/chanurholis/face-api.js/git/refs{/sha}",
#             "trees_url": "https://api.github.com/repos/chanurholis/face-api.js/git/trees{/sha}",
#             "statuses_url": "https://api.github.com/repos/chanurholis/face-api.js/statuses/{sha}",
#             "languages_url": "https://api.github.com/repos/chanurholis/face-api.js/languages",
#             "stargazers_url": "https://api.github.com/repos/chanurholis/face-api.js/stargazers",
#             "contributors_url": "https://api.github.com/repos/chanurholis/face-api.js/contributors",
#             "subscribers_url": "https://api.github.com/repos/chanurholis/face-api.js/subscribers",
#             "subscription_url": "https://api.github.com/repos/chanurholis/face-api.js/subscription",
#             "commits_url": "https://api.github.com/repos/chanurholis/face-api.js/commits{/sha}",
#             "git_commits_url": "https://api.github.com/repos/chanurholis/face-api.js/git/commits{/sha}",
#             "comments_url": "https://api.github.com/repos/chanurholis/face-api.js/comments{/number}",
#             "issue_comment_url": "https://api.github.com/repos/chanurholis/face-api.js/issues/comments{/number}",
#             "contents_url": "https://api.github.com/repos/chanurholis/face-api.js/contents/{+path}",
#             "compare_url": "https://api.github.com/repos/chanurholis/face-api.js/compare/{base}...{head}",
#             "merges_url": "https://api.github.com/repos/chanurholis/face-api.js/merges",
#             "archive_url": "https://api.github.com/repos/chanurholis/face-api.js/{archive_format}{/ref}",
#             "downloads_url": "https://api.github.com/repos/chanurholis/face-api.js/downloads",
#             "issues_url": "https://api.github.com/repos/chanurholis/face-api.js/issues{/number}",
#             "pulls_url": "https://api.github.com/repos/chanurholis/face-api.js/pulls{/number}",
#             "milestones_url": "https://api.github.com/repos/chanurholis/face-api.js/milestones{/number}",
#             "notifications_url": "https://api.github.com/repos/chanurholis/face-api.js/notifications{?since,all,participating}",
#             "labels_url": "https://api.github.com/repos/chanurholis/face-api.js/labels{/name}",
#             "releases_url": "https://api.github.com/repos/chanurholis/face-api.js/releases{/id}",
#             "deployments_url": "https://api.github.com/repos/chanurholis/face-api.js/deployments",
#             "created_at": "2020-01-08T06:28:54Z",
#             "updated_at": "2020-01-18T13:34:19Z",
#             "pushed_at": "2022-12-07T06:13:34Z",
#             "git_url": "git://github.com/chanurholis/face-api.js.git",
#             "ssh_url": "git@github.com:chanurholis/face-api.js.git",
#             "clone_url": "https://github.com/chanurholis/face-api.js.git",
#             "svn_url": "https://github.com/chanurholis/face-api.js",
#             "homepage": null,
#             "size": 199901,
#             "stargazers_count": 1,
#             "watchers_count": 1,
#             "language": "TypeScript",
#             "has_issues": true,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": true,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 0,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 13,
#             "license": {
#               "key": "mit",
#               "name": "MIT License",
#               "spdx_id": "MIT",
#               "url": "https://api.github.com/licenses/mit",
#               "node_id": "MDc6TGljZW5zZTEz"
#             },
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [
#
#             ],
#             "visibility": "public",
#             "forks": 0,
#             "open_issues": 13,
#             "watchers": 1,
#             "default_branch": "master"
#           }
#         },
#         "_links": {
#           "self": {
#             "href": "https://api.github.com/repos/chanurholis/face-api.js/pulls/21"
#           },
#           "html": {
#             "href": "https://github.com/chanurholis/face-api.js/pull/21"
#           },
#           "issue": {
#             "href": "https://api.github.com/repos/chanurholis/face-api.js/issues/21"
#           },
#           "comments": {
#             "href": "https://api.github.com/repos/chanurholis/face-api.js/issues/21/comments"
#           },
#           "review_comments": {
#             "href": "https://api.github.com/repos/chanurholis/face-api.js/pulls/21/comments"
#           },
#           "review_comment": {
#             "href": "https://api.github.com/repos/chanurholis/face-api.js/pulls/comments{/number}"
#           },
#           "commits": {
#             "href": "https://api.github.com/repos/chanurholis/face-api.js/pulls/21/commits"
#           },
#           "statuses": {
#             "href": "https://api.github.com/repos/chanurholis/face-api.js/statuses/b25ea8f44d423cd77cdec7ac24e9587ee1a66f13"
#           }
#         },
#         "author_association": "NONE",
#         "auto_merge": null,
#         "active_lock_reason": null,
#         "merged": false,
#         "mergeable": null,
#         "rebaseable": null,
#         "mergeable_state": "unknown",
#         "merged_by": null,
#         "comments": 0,
#         "review_comments": 0,
#         "maintainer_can_modify": false,
#         "commits": 1,
#         "additions": 145,
#         "deletions": 65,
#         "changed_files": 1
#       }
#     },
#     "public": true,
#     "created_at": "2022-12-07T06:13:34Z"
#   },
#   {
#     "id": "25710628273",
#     "type": "PushEvent",
#     "actor": {
#       "id": 22233835,
#       "login": "hookzof",
#       "display_login": "hookzof",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/hookzof",
#       "avatar_url": "https://avatars.githubusercontent.com/u/22233835?"
#     },
#     "repo": {
#       "id": 200941132,
#       "name": "hookzof/socks5_list",
#       "url": "https://api.github.com/repos/hookzof/socks5_list"
#     },
#     "payload": {
#       "push_id": 11909553034,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/master",
#       "head": "cef55bcb8780b6027bea6ebf893485a373ac7050",
#       "before": "f46b601cc28d46da0a9739079e7672d02e62b36c",
#       "commits": [
#         {
#           "sha": "cef55bcb8780b6027bea6ebf893485a373ac7050",
#           "author": {
#             "email": "vit110188@gmail.com",
#             "name": "Vitaly Kryukov"
#           },
#           "message": "2022-12-07 07:13:33 +0100 CET",
#           "distinct": true,
#           "url": "https://api.github.com/repos/hookzof/socks5_list/commits/cef55bcb8780b6027bea6ebf893485a373ac7050"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-07T06:13:34Z"
#   },
#   {
#     "id": "25710628276",
#     "type": "PushEvent",
#     "actor": {
#       "id": 1970283,
#       "login": "aggre",
#       "display_login": "aggre",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/aggre",
#       "avatar_url": "https://avatars.githubusercontent.com/u/1970283?"
#     },
#     "repo": {
#       "id": 442914993,
#       "name": "dev-protocol/dev-elements",
#       "url": "https://api.github.com/repos/dev-protocol/dev-elements"
#     },
#     "payload": {
#       "push_id": 11909553044,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "f2c123e120eff2005c3fa6da5fbcdb82ccfb84ab",
#       "before": "befa09f1ecd402ef5f6c4ff2bddb86ed3fe40ede",
#       "commits": [
#         {
#           "sha": "f2c123e120eff2005c3fa6da5fbcdb82ccfb84ab",
#           "author": {
#             "email": "hiroyuki.aggre@gmail.com",
#             "name": "aggre"
#           },
#           "message": "0.2.0",
#           "distinct": true,
#           "url": "https://api.github.com/repos/dev-protocol/dev-elements/commits/f2c123e120eff2005c3fa6da5fbcdb82ccfb84ab"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-07T06:13:34Z",
#     "org": {
#       "id": 49816297,
#       "login": "dev-protocol",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/dev-protocol",
#       "avatar_url": "https://avatars.githubusercontent.com/u/49816297?"
#     }
#   }
# ]

# %% [markdown]
# ### 导入历史数据
#
# #### GhArchive
#
# 由于 `/events` API 的限制，我们无法获取到历史的所有事件数据，于是我们找寻了该 API 的归档数据。通过 [GhArchive](https://www.gharchive.org/) 项目，我们可以下载以天或小时为粒度的归档数据。
#
# | Query | Downloadable Files |
# | ---- | ---- |
# | Activity for 1/1/2015 @ 3PM UTC |	`https://data.gharchive.org/2015-01-01-15.json.gz` |
# | Activity for 1/1/2015 | `https://data.gharchive.org/2015-01-01-{0..23}.json.gz` |
# | Activity for all of January 2015 | `https://data.gharchive.org/2015-01-{01..31}-{0..23}.json.gz` |

# %% [markdown]
# #### OSS Insight 数据总量
#
# 截止目前（2022-12-06），OSS Insight 已经收集了超过 53 亿条公开事件数据，你可以通过访问 API 或在网站上查看当前收集的事件总数：

# %%
# !curl -s https://api.ossinsight.io/q/events-total | jq -r ".data[0]"
# Out:
# {
#   "cnt": 5343816396,
#   "latest_created_at": "2022-12-07T06:13:00.000Z",
#   "latest_timestamp": 1670393580
# }

# %% [markdown]
# #### 导出示例数据
#
# 为了方便演示，我们从中筛选出了部分数据，使用 [Dumpling](https://docs.pingcap.com/zh/tidb/stable/dumpling-overview) 工具导出到 AWS S3 文件存储当中，你可以使用 TiDB Cloud 的 Import 功能将其导入数据库当中：
#
# `github_events` 表:
#
# ```bash
# tiup dumpling --host <endpoint> --port 4000 --user <uername> --password <password> --filetype sql --filter "gharchive_dev.github_events" --where="type in ('WatchEvent', 'IssuesEvent', 'PullRequestEvent', 'PushEvent') and repo_id in (507775,41986369,16563587,60246359,108110,11008207,6358188,48833910,114187903,105944401,50874442,44781140,166515022,20089857,19816070,206444,31006158,99919302,28738447,402945349,30753733,372536760,302827809,196353673,393235957,417731747,417726876,453068084,5349565,422821402,496505424,927442,138754790,49876476,208728772)" -o "s3://ossinsight/workshop/oss_database_sample" --s3.region "us-west-2"
# ```
#
# `github_users` 表:
#
# ```bash
# tiup dumpling --host <endpoint>  --port 4000 --user <uername> --password <password> --filetype sql --filter "gharchive_dev.github_users" --where="login IN (SELECT ge.actor_login FROM gharchive_dev.github_events ge WHERE ge.type IN ('WatchEvent', 'IssuesEvent', 'PullRequestEvent', 'PushEvent') AND ge.repo_id IN (507775,41986369,16563587,60246359,108110,11008207,6358188,48833910,114187903,105944401,50874442,44781140,166515022,20089857,19816070,206444,31006158,99919302,28738447,402945349,30753733,372536760,302827809,196353673,393235957,417731747,417726876,453068084,5349565,422821402,496505424,927442,138754790,49876476,208728772))" -o "s3://ossinsight/workshop/oss_database_sample" --s3.region "us-west-2"
# ```

# %% [markdown]
# #### 导入示例数据
#
# 你可以使用 TiDB Cloud 的 Import 功能将示例数据导入到你的 Severless Tier 集群。
#
# S3 URI:

# %% [raw]
# s3://ossinsight/workshop/oss_database_sample/

# %% [markdown]
# Role ARN:

# %% [raw]
# arn:aws:iam::494090988690:role/tidb-cloud-reader

# %% [markdown]
# 将上面的 `S3 URI` 和 `Role ARN` 添加到导入配置当中，根据页面提示开启导入任务：
#
# <center>
#     <img width="700" alt="image" src="https://user-images.githubusercontent.com/85985765/205849289-de1203f7-80dd-4520-8e40-fc91f0a76631.png">
#     <p><i>TiDB Cloud 导入功能 - 准备页面</i></p>
# </center>
#
# <center>
#     <img width="700" alt="TiDB Cloud - Importing" src="https://user-images.githubusercontent.com/85985765/205808913-9c32d61f-f9aa-43fa-ad4d-1bba4201b41d.png">
#     <p><i>TiDB Cloud 导入功能 - 状态页面</i></p>
# </center>

# %% [markdown]
# ### 导入实时数据
#
# 执行下面的 Docker Compose 命令启动 ETL 脚本，该脚本负责将 Github Events API 返回结果中的 JSON 数据导入到数据库当中。

# %%
# !docker compose pull etl
# !docker compose up -d etl

# %% [markdown]
# 通过下面的命令查看 etl 容器的运行状态：

# %%
# !docker compose logs etl --tail 10
# Out:
# ossinsight-etl-1  | == 20221120144415 CreateMentionLogs: migrating ================================
# ossinsight-etl-1  | -- create_table(:mention_logs)
# ossinsight-etl-1  |    -> 0.1764s
# ossinsight-etl-1  | == 20221120144415 CreateMentionLogs: migrated (0.5898s) =======================
# ossinsight-etl-1  |
# ossinsight-etl-1  | Annotated (7): app/models/github_event.rb, test/models/github_event_test.rb, test/fixtures/github_events.yml, app/models/mention_log.rb, test/models/mention_log_test.rb, test/fixtures/mention_logs.yml, test/fixtures/mention_logs.yml
# ossinsight-etl-1  | + bundle exec rake db:seed
# ossinsight-etl-1  | mysql: unknown variable 'ssl-mode=VERIFY_IDENTITY'
# ossinsight-etl-1  | + bundle exec rake gh:set_tiflash_replica
# ossinsight-etl-1  | + bundle exec rails runner 'Realtime.new(ENV["GITHUB_TOKEN"].to_s.split(","), 100).run'

# %% [markdown]
# ## 背景知识

# %% [markdown]
# #### 优化器
#
# SQL 是一种声明式语言，而非过程性的语言。也就是说，它描述的是最终结果应该如何，而非按顺序执行的步骤。因此在 TiDB 在处理 SQL 语句的过程中，除了要确保能够正确返回语句所描述的最终结果，还要确定 SQL 语句的执行过程，并且尽可能的对 SQL 语句进行性能优化，从而得到最佳的执行计划。
#
# SQL 性能优化的过程，可以理解为 GPS 导航的过程。你提供地址后，GPS 软件利用各种统计信息（例如以前的行程、速度限制等元数据，以及实时交通信息）规划出一条最省时的路线。这与 TiDB 中的 SQL 性能优化过程相对应。
#
# 我们通常会把负责这部分 SQL 优化工作的组件成为**优化器（Optimizer）**。
#
# 如下图所示，一条 SQL 语句在经过语法解析和校验之后，经过优化器的逻辑优化和物理优化来制定最终的执行计划，交给执行器（Executor）去执行。和 GPS 软件一样，优化器在进行执行计划规划的时候也会利用到一些统计信息来进行评估。
#
# <center>
#   <img width="640" alt="The Cluster Modify Menu" src="https://user-images.githubusercontent.com/85985765/205136445-3d9dd676-56bc-4f75-bf6d-cdb1af8c1b79.png">
#   <p><i>SQL 优化流程图</i></p>
# </center>
#
# 上图其实是一个简化的示意图，因为它只描述了以 TiKV 为存储引擎的情况。但是在 TiDB 支持 HTAP 能力后，引进了负责分析负载的 TiFlash 存储引擎。这给优化器带来了新的挑战，优化器需要在制定执行计划和进行物理
# 优化时需要考虑：
#
# > 这条 SQL 应该使用哪个存储引擎执行性能会更好，选 TiKV 还是 TiFlash？

# %% [markdown]
# #### Optimizer Hints
#
# > 如果优化器难以抉择，那我们不妨给它一点提示，告诉它我们希望使用哪种存储引擎执行?
#
# TiDB 的优化器提供了 `READ_FROM_STORAGE` Hint 来允许开发者在 SQL 语句级别来控制哪一张表应该使用哪个执行引擎去执行。例如，下在面这条 SQL 语句当中，TiDB 从 TiFlash 上读取 t1 表的数据，在 TiKV 上读取 t2 的数据。
#
# ```sql
# SELECT /*+ READ_FROM_STORAGE(TIFLASH[t1], TIKV[t2]) */ t1.a FROM t t1, t t2 WHERE t1.a = t2.a;
# ```

# %% [markdown]
# #### 代价模型
#
# > 使用 Optimizer Hints 很简单，但是有没有更智能的方法，特别是在做临时查询时，优化器能否智能的选择应该使用哪种引擎查询效率最高？
#
# <center>
#   <img width="640" alt="物理优化中的代码模型" src="https://user-images.githubusercontent.com/85985765/205192450-c23f2199-1ab1-41d2-90f3-c17c5d6e252e.png">
#   <p><i>SQL 优化流程图</i></p>
# </center>
#
# TiDB v6.2.0 引入了新的代价模型 Cost Model Version 2。
#
# Cost Model Version 2 对代价公式进行了更精确的回归校准，调整了部分代价公式，比此前版本的代价公式更加准确。
#
# OSS Insight 使用了该版本的 Cost Model, 但是因为目前 Cost Model Version 2 还处于实验阶段，需要通过执行以下 SQL 语句进行启用：

# %%
SET GLOBAL tidb_enable_new_cost_interface = 'ON';
SET GLOBAL tidb_cost_model_version = 2;

# %% [markdown]
# 在后续版本当中，Cost Model Version 2 会替代掉原有的 Cost Model 作为默认的代码模型。

# %% [markdown]
# ## Example SQL
#
# 下面，我们会以 OSS Insight 为示例，讲解如何使用 TiDB 进行数据分析以及在数据分析时如何更好的通过优化器来发挥行存 TiKV 和列存 TiFlash 各自的优势。

# %% [markdown]
# ### 准备
#
# #### 定义 query 和 execute 工具方法：
#
# 首先，请执行下面的 Python 代码，初始化一个 `query` 函数和一个 `execute` 函数用于后续的 SQL 查询：

# %%
import mysql.connector as connection
import pandas as pd

db_host = os.getenv('DB_ENDPOINT')
db_port = os.getenv("DB_PORT")
db_username = os.getenv('DB_USERNAME')
db_password = os.getenv('DB_PASSWORD')
db_name = os.getenv('DB_NAME')

mydb = connection.connect(
  host=db_host,
  port=db_port,
  user=db_username,
  password=db_password,
  database=db_name
)

def execute(sql):
  try:
    mycursor = mydb.cursor()
    mycursor.execute(sql)
    mydb.commit()
    return  "{} record(s) affected".format(mycursor.rowcount)
  except Exception as e:
    print(str(e))

def query(sql):
  try:

    df = pd.read_sql(sql, mydb)
    return df.style.set_properties(**{'text-align': 'left'})
  except Exception as e:
    print(str(e))

# %% [markdown]
# #### 开启 Cost Model V2

# %%
execute("""
SET GLOBAL tidb_enable_new_cost_interface = 'ON';
""")
# Out:
# '0 record(s) affected'

# %%
execute("""
SET GLOBAL tidb_cost_model_version = 2;
""")
# Out:
# '0 record(s) affected'

# %% [markdown]
# #### 检查健康度

# %% [markdown]
# 因为在 OSS Insight 当中 `github_events` 表使用了[分区表](https://docs.pingcap.com/zh/tidb/dev/partitioned-table)的功能，并且开启了[动态分区裁剪模式](https://docs.pingcap.com/zh/tidb/dev/partitioned-table#%E5%8A%A8%E6%80%81%E8%A3%81%E5%89%AA%E6%A8%A1%E5%BC%8F)。

# %%
query("""
SELECT @@tidb_partition_prune_mode;
""")
# Out:
# <style type="text/css">
# #T_62c60_row0_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_62c60_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >@@tidb_partition_prune_mode;
# </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62c60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_62c60_row0_col0" class="data row0 col0" >dynamic</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 因为优化器需要根据统计信息来制定执行计划，我们需要留意统计信息是否过期。我们可以通过 `SHOW STATS_HEALTHY` 命令来查看表的健康度，通过表的[健康度](https://docs.pingcap.com/zh/tidb/dev/statistics#%E8%A1%A8%E7%9A%84%E5%81%A5%E5%BA%B7%E5%BA%A6%E4%BF%A1%E6%81%AF)，可以粗略估计表上统计信息的准确度。
#
# 特别是在你使用分区表时，动态分区裁剪模式需要依赖 `global` 的统计信息。
#
# 为保证开启全局 dynamic 动态裁剪模式时，SQL 可以用上正确的统计信息，此时需要手动触发一次 analyze 来更新汇总统计信息.

# %%
query("""
SHOW STATS_HEALTHY WHERE db_name = 'ossinsight' AND table_name = 'github_events';
""")
# Out:
# <style type="text/css">
# #T_eec4c_row0_col0, #T_eec4c_row0_col1, #T_eec4c_row0_col2, #T_eec4c_row0_col3, #T_eec4c_row1_col0, #T_eec4c_row1_col1, #T_eec4c_row1_col2, #T_eec4c_row1_col3, #T_eec4c_row2_col0, #T_eec4c_row2_col1, #T_eec4c_row2_col2, #T_eec4c_row2_col3, #T_eec4c_row3_col0, #T_eec4c_row3_col1, #T_eec4c_row3_col2, #T_eec4c_row3_col3, #T_eec4c_row4_col0, #T_eec4c_row4_col1, #T_eec4c_row4_col2, #T_eec4c_row4_col3, #T_eec4c_row5_col0, #T_eec4c_row5_col1, #T_eec4c_row5_col2, #T_eec4c_row5_col3, #T_eec4c_row6_col0, #T_eec4c_row6_col1, #T_eec4c_row6_col2, #T_eec4c_row6_col3, #T_eec4c_row7_col0, #T_eec4c_row7_col1, #T_eec4c_row7_col2, #T_eec4c_row7_col3, #T_eec4c_row8_col0, #T_eec4c_row8_col1, #T_eec4c_row8_col2, #T_eec4c_row8_col3, #T_eec4c_row9_col0, #T_eec4c_row9_col1, #T_eec4c_row9_col2, #T_eec4c_row9_col3, #T_eec4c_row10_col0, #T_eec4c_row10_col1, #T_eec4c_row10_col2, #T_eec4c_row10_col3, #T_eec4c_row11_col0, #T_eec4c_row11_col1, #T_eec4c_row11_col2, #T_eec4c_row11_col3, #T_eec4c_row12_col0, #T_eec4c_row12_col1, #T_eec4c_row12_col2, #T_eec4c_row12_col3, #T_eec4c_row13_col0, #T_eec4c_row13_col1, #T_eec4c_row13_col2, #T_eec4c_row13_col3, #T_eec4c_row14_col0, #T_eec4c_row14_col1, #T_eec4c_row14_col2, #T_eec4c_row14_col3, #T_eec4c_row15_col0, #T_eec4c_row15_col1, #T_eec4c_row15_col2, #T_eec4c_row15_col3, #T_eec4c_row16_col0, #T_eec4c_row16_col1, #T_eec4c_row16_col2, #T_eec4c_row16_col3, #T_eec4c_row17_col0, #T_eec4c_row17_col1, #T_eec4c_row17_col2, #T_eec4c_row17_col3, #T_eec4c_row18_col0, #T_eec4c_row18_col1, #T_eec4c_row18_col2, #T_eec4c_row18_col3, #T_eec4c_row19_col0, #T_eec4c_row19_col1, #T_eec4c_row19_col2, #T_eec4c_row19_col3, #T_eec4c_row20_col0, #T_eec4c_row20_col1, #T_eec4c_row20_col2, #T_eec4c_row20_col3, #T_eec4c_row21_col0, #T_eec4c_row21_col1, #T_eec4c_row21_col2, #T_eec4c_row21_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_eec4c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Db_name</th>
#       <th class="col_heading level0 col1" >Table_name</th>
#       <th class="col_heading level0 col2" >Partition_name</th>
#       <th class="col_heading level0 col3" >Healthy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eec4c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eec4c_row0_col0" class="data row0 col0" >ossinsight</td>
#       <td id="T_eec4c_row0_col1" class="data row0 col1" >github_events</td>
#       <td id="T_eec4c_row0_col2" class="data row0 col2" >global</td>
#       <td id="T_eec4c_row0_col3" class="data row0 col3" >99</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eec4c_row1_col0" class="data row1 col0" >ossinsight</td>
#       <td id="T_eec4c_row1_col1" class="data row1 col1" >github_events</td>
#       <td id="T_eec4c_row1_col2" class="data row1 col2" >push_event</td>
#       <td id="T_eec4c_row1_col3" class="data row1 col3" >99</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eec4c_row2_col0" class="data row2 col0" >ossinsight</td>
#       <td id="T_eec4c_row2_col1" class="data row2 col1" >github_events</td>
#       <td id="T_eec4c_row2_col2" class="data row2 col2" >create_event</td>
#       <td id="T_eec4c_row2_col3" class="data row2 col3" >96</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eec4c_row3_col0" class="data row3 col0" >ossinsight</td>
#       <td id="T_eec4c_row3_col1" class="data row3 col1" >github_events</td>
#       <td id="T_eec4c_row3_col2" class="data row3 col2" >pull_request_event</td>
#       <td id="T_eec4c_row3_col3" class="data row3 col3" >99</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eec4c_row4_col0" class="data row4 col0" >ossinsight</td>
#       <td id="T_eec4c_row4_col1" class="data row4 col1" >github_events</td>
#       <td id="T_eec4c_row4_col2" class="data row4 col2" >watch_event</td>
#       <td id="T_eec4c_row4_col3" class="data row4 col3" >99</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eec4c_row5_col0" class="data row5 col0" >ossinsight</td>
#       <td id="T_eec4c_row5_col1" class="data row5 col1" >github_events</td>
#       <td id="T_eec4c_row5_col2" class="data row5 col2" >issue_comment_event</td>
#       <td id="T_eec4c_row5_col3" class="data row5 col3" >96</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eec4c_row6_col0" class="data row6 col0" >ossinsight</td>
#       <td id="T_eec4c_row6_col1" class="data row6 col1" >github_events</td>
#       <td id="T_eec4c_row6_col2" class="data row6 col2" >issues_event</td>
#       <td id="T_eec4c_row6_col3" class="data row6 col3" >99</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eec4c_row7_col0" class="data row7 col0" >ossinsight</td>
#       <td id="T_eec4c_row7_col1" class="data row7 col1" >github_events</td>
#       <td id="T_eec4c_row7_col2" class="data row7 col2" >delete_event</td>
#       <td id="T_eec4c_row7_col3" class="data row7 col3" >96</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eec4c_row8_col0" class="data row8 col0" >ossinsight</td>
#       <td id="T_eec4c_row8_col1" class="data row8 col1" >github_events</td>
#       <td id="T_eec4c_row8_col2" class="data row8 col2" >fork_event</td>
#       <td id="T_eec4c_row8_col3" class="data row8 col3" >97</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eec4c_row9_col0" class="data row9 col0" >ossinsight</td>
#       <td id="T_eec4c_row9_col1" class="data row9 col1" >github_events</td>
#       <td id="T_eec4c_row9_col2" class="data row9 col2" >pull_request_review_comment_event</td>
#       <td id="T_eec4c_row9_col3" class="data row9 col3" >97</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_eec4c_row10_col0" class="data row10 col0" >ossinsight</td>
#       <td id="T_eec4c_row10_col1" class="data row10 col1" >github_events</td>
#       <td id="T_eec4c_row10_col2" class="data row10 col2" >pull_request_review_event</td>
#       <td id="T_eec4c_row10_col3" class="data row10 col3" >96</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_eec4c_row11_col0" class="data row11 col0" >ossinsight</td>
#       <td id="T_eec4c_row11_col1" class="data row11 col1" >github_events</td>
#       <td id="T_eec4c_row11_col2" class="data row11 col2" >gollum_event</td>
#       <td id="T_eec4c_row11_col3" class="data row11 col3" >97</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_eec4c_row12_col0" class="data row12 col0" >ossinsight</td>
#       <td id="T_eec4c_row12_col1" class="data row12 col1" >github_events</td>
#       <td id="T_eec4c_row12_col2" class="data row12 col2" >release_event</td>
#       <td id="T_eec4c_row12_col3" class="data row12 col3" >97</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_eec4c_row13_col0" class="data row13 col0" >ossinsight</td>
#       <td id="T_eec4c_row13_col1" class="data row13 col1" >github_events</td>
#       <td id="T_eec4c_row13_col2" class="data row13 col2" >member_event</td>
#       <td id="T_eec4c_row13_col3" class="data row13 col3" >96</td>
#     </tr>
#     <tr>
#       <th id="T_eec4c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_eec4c_row14_col0" class="data row14 col0" >ossinsight</td>
#       <td id="T_eec4c_row14_col1" class="data row14 col1" >github_events</td>
#       <td id="T_eec4c_row14_col2" class="data row14 col2" >commit_comment_event</td>
#       <td id="T_ee

# %% [markdown]
# 通过 `ANALYZE TABLE` 命令手动触发收集表的统计信息：

# %%
execute("""
ANALYZE TABLE ossinsight.github_events;
""")
# Out:
# '0 record(s) affected'

# %% [markdown]
# ### Example 1: How many pull request does `ti-chi-bot` created?

# %% [markdown]
# 熟悉 TiDB 的用户可能会知道，在 TiDB 的版本规则里会存在两种版本：
#
# - 一种是为了能够更快交付迭代而设计的开发里程碑版本 (Development Milestone Releases, DMR)
# - 另外一种是提供长期技术支持的长期支持版本 (Long-Term Support Releases, LTS)
#
# 在 LTS 生命周期内会按需发布补丁版本 (Patch Release)。如果一个修复 BUG 的 Pull Request 会被 Cherry-Pick 到受影响的 LTS 分支进行修复，这部分工作会由机器人根据研发和 QA 团队确定的受影响版本列表进行自动的 Cherry—Pick，所以你会在 TiDB 的代码仓库当中看见不少[由机器人发起的 Pull Request](https://github.com/pingcap/tidb/pulls/ti-chi-bot)。
#
# > 🤔 那么，TiDB 的社区机器人（`ti-chi-bot`）一共创建了多少个 Pull Request 呢？
#
# 我们可以通过下面的 SQL 语句进行查询：

# %%
query("""
SELECT repo_name, COUNT(1) AS prs
FROM github_events
WHERE
    type = 'PullRequestEvent'
    AND action = 'opened'
    AND actor_login = 'ti-chi-bot'
GROUP BY repo_name
""")
# Out:
# <style type="text/css">
# #T_eaad8_row0_col0, #T_eaad8_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_eaad8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >repo_name</th>
#       <th class="col_heading level0 col1" >prs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eaad8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eaad8_row0_col0" class="data row0 col0" >pingcap/tidb</td>
#       <td id="T_eaad8_row0_col1" class="data row0 col1" >139</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 通过 `EXPLAIN ANALYZE` 查看上面 SQL 语句的执行计划：

# %%
query("""
EXPLAIN ANALYZE SELECT repo_name, COUNT(1) AS prs
FROM github_events
WHERE
    type = 'PullRequestEvent'
    AND action = 'opened'
    AND actor_login = 'ti-chi-bot'
GROUP BY repo_name
""")
# Out:
# <style type="text/css">
# #T_ead24_row0_col0, #T_ead24_row0_col1, #T_ead24_row0_col2, #T_ead24_row0_col3, #T_ead24_row0_col4, #T_ead24_row0_col5, #T_ead24_row0_col6, #T_ead24_row0_col7, #T_ead24_row0_col8, #T_ead24_row1_col0, #T_ead24_row1_col1, #T_ead24_row1_col2, #T_ead24_row1_col3, #T_ead24_row1_col4, #T_ead24_row1_col5, #T_ead24_row1_col6, #T_ead24_row1_col7, #T_ead24_row1_col8, #T_ead24_row2_col0, #T_ead24_row2_col1, #T_ead24_row2_col2, #T_ead24_row2_col3, #T_ead24_row2_col4, #T_ead24_row2_col5, #T_ead24_row2_col6, #T_ead24_row2_col7, #T_ead24_row2_col8, #T_ead24_row3_col0, #T_ead24_row3_col1, #T_ead24_row3_col2, #T_ead24_row3_col3, #T_ead24_row3_col4, #T_ead24_row3_col5, #T_ead24_row3_col6, #T_ead24_row3_col7, #T_ead24_row3_col8, #T_ead24_row4_col0, #T_ead24_row4_col1, #T_ead24_row4_col2, #T_ead24_row4_col3, #T_ead24_row4_col4, #T_ead24_row4_col5, #T_ead24_row4_col6, #T_ead24_row4_col7, #T_ead24_row4_col8, #T_ead24_row5_col0, #T_ead24_row5_col1, #T_ead24_row5_col2, #T_ead24_row5_col3, #T_ead24_row5_col4, #T_ead24_row5_col5, #T_ead24_row5_col6, #T_ead24_row5_col7, #T_ead24_row5_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_ead24_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >estRows</th>
#       <th class="col_heading level0 col2" >actRows</th>
#       <th class="col_heading level0 col3" >task</th>
#       <th class="col_heading level0 col4" >access object</th>
#       <th class="col_heading level0 col5" >execution info</th>
#       <th class="col_heading level0 col6" >operator info</th>
#       <th class="col_heading level0 col7" >memory</th>
#       <th class="col_heading level0 col8" >disk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ead24_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ead24_row0_col0" class="data row0 col0" >Projection_5</td>
#       <td id="T_ead24_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_ead24_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_ead24_row0_col3" class="data row0 col3" >root</td>
#       <td id="T_ead24_row0_col4" class="data row0 col4" ></td>
#       <td id="T_ead24_row0_col5" class="data row0 col5" >time:16.1ms, loops:2, Concurrency:OFF</td>
#       <td id="T_ead24_row0_col6" class="data row0 col6" >ossinsight.github_events.repo_name, Column#34</td>
#       <td id="T_ead24_row0_col7" class="data row0 col7" >1016 Bytes</td>
#       <td id="T_ead24_row0_col8" class="data row0 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_ead24_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ead24_row1_col0" class="data row1 col0" >└─HashAgg_8</td>
#       <td id="T_ead24_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_ead24_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_ead24_row1_col3" class="data row1 col3" >root</td>
#       <td id="T_ead24_row1_col4" class="data row1 col4" ></td>
#       <td id="T_ead24_row1_col5" class="data row1 col5" >time:16.1ms, loops:2, partial_worker:{wall_time:16.090541ms, concurrency:5, task_num:1, tot_wait:79.717129ms, tot_exec:62.145µs, tot_time:79.795905ms, max:16.020634ms, p95:16.020634ms}, final_worker:{wall_time:16.154917ms, concurrency:5, task_num:1, tot_wait:80.304791ms, tot_exec:14.669µs, tot_time:80.322523ms, max:16.075034ms, p95:16.075034ms}</td>
#       <td id="T_ead24_row1_col6" class="data row1 col6" >group by:ossinsight.github_events.repo_name, funcs:count(1)->Column#34, funcs:firstrow(ossinsight.github_events.repo_name)->ossinsight.github_events.repo_name</td>
#       <td id="T_ead24_row1_col7" class="data row1 col7" >40.8 KB</td>
#       <td id="T_ead24_row1_col8" class="data row1 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_ead24_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ead24_row2_col0" class="data row2 col0" >  └─IndexLookUp_26</td>
#       <td id="T_ead24_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_ead24_row2_col2" class="data row2 col2" >139</td>
#       <td id="T_ead24_row2_col3" class="data row2 col3" >root</td>
#       <td id="T_ead24_row2_col4" class="data row2 col4" >partition:pull_request_event</td>
#       <td id="T_ead24_row2_col5" class="data row2 col5" >time:16ms, loops:2, index_task: {total_time: 2.97ms, fetch_handle: 2.95ms, build: 2.63µs, wait: 20.6µs}, table_task: {total_time: 32.6ms, num: 3, concurrency: 5}</td>
#       <td id="T_ead24_row2_col6" class="data row2 col6" ></td>
#       <td id="T_ead24_row2_col7" class="data row2 col7" >131.5 KB</td>
#       <td id="T_ead24_row2_col8" class="data row2 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_ead24_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ead24_row3_col0" class="data row3 col0" >    ├─IndexRangeScan_23(Build)</td>
#       <td id="T_ead24_row3_col1" class="data row3 col1" >10.00</td>
#       <td id="T_ead24_row3_col2" class="data row3 col2" >6564</td>
#       <td id="T_ead24_row3_col3" class="data row3 col3" >cop[tikv]</td>
#       <td id="T_ead24_row3_col4" class="data row3 col4" >table:github_events, index:index_ge_on_actor_login(actor_login)</td>
#       <td id="T_ead24_row3_col5" class="data row3 col5" >time:2.63ms, loops:9, cop_task: {num: 1, max: 2.53ms, proc_keys: 6564, tot_proc: 4ms, rpc_num: 1, rpc_time: 2.5ms, copr_cache_hit_ratio: 0.00, distsql_concurrency: 15}, tikv_task:{time:4ms, loops:11}, scan_detail: {total_process_keys: 6564, total_process_keys_size: 466044, total_keys: 6565, rocksdb: {block: {}}}</td>
#       <td id="T_ead24_row3_col6" class="data row3 col6" >range:["ti-chi-bot","ti-chi-bot"], keep order:false, stats:pseudo</td>
#       <td id="T_ead24_row3_col7" class="data row3 col7" >N/A</td>
#       <td id="T_ead24_row3_col8" class="data row3 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_ead24_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ead24_row4_col0" class="data row4 col0" >    └─Selection_25(Probe)</td>
#       <td id="T_ead24_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_ead24_row4_col2" class="data row4 col2" >139</td>
#       <td id="T_ead24_row4_col3" class="data row4 col3" >cop[tikv]</td>
#       <td id="T_ead24_row4_col4" class="data row4 col4" ></td>
#       <td id="T_ead24_row4_col5" class="data row4 col5" >time:30.1ms, loops:4, cop_task: {num: 4, max: 11.4ms, min: 1.91ms, avg: 7.68ms, p95: 11.4ms, max_proc_keys: 2500, p95_proc_keys: 2500, tot_proc: 20ms, rpc_num: 4, rpc_time: 30.6ms, copr_cache_hit_ratio: 0.00, distsql_concurrency: 15}, tikv_task:{proc max:8ms, min:0s, avg: 5ms, p80:8ms, p95:8ms, iters:24, tasks:4}, scan_detail: {total_process_keys: 6564, total_process_keys_size: 1881526, total_keys: 6729, rocksdb: {block: {}}}</td>
#       <td id="T_ead24_row4_col6" class="data row4 col6" >eq(ossinsight.github_events.action, "opened"), eq(ossinsight.github_events.type, "PullRequestEvent")</td>
#       <td id="T_ead24_row4_col7" class="data row4 col7" >N/A</td>
#       <td id="T_ead24_row4_col8" class="data row4 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_ead24_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ead24_row5_col0" class="data row5 col0" >      └─TableRowIDScan_24</td>
#       <td id="T_ead24_row5_col1" class="data row5 col1" >10.00</td>
#       <td id="T_ead24_row5_col2" class="data row5 col2" >6564</td>
#       <td id="T_ead24_row5_col3" class="data row5 col3" >cop[tikv]</td>
#       <td id="T_ead24_row5_col4" class="data row5 col4" >table:github_events</td>
#       <td id="T_ead24_row5_col5" class="data row5 col5" >tikv_task:{proc max:8ms, min:0s, avg: 5ms, p80:8ms, p95:8ms, iters:24, tasks:4}</td>
#       <td id="T_ead24_row5_col6" class="data row5 col6" >keep order:false, stats:pseudo</td>
#       <td id="T_ead24_row5_col7" class="data row5 col7" >N/A</td>
#       <td id="T_ead24_row5_col8" class="data row5 col8" >N/A</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 通过执行计划，我们可以知道这个 SQL 会使用 TiKV 存储引擎来读取 `github_events` 表中的数据，并且使用了索引 `index_github_events_on_actor_login`。

# %% [markdown]
# ### Example 2: The history of the number of stars

# %% [markdown]
# #### 问题

# %% [markdown]
# > 🤔 除了通过聚合函数来进行简单数据分析，TiDB 是否可以做更复杂的数据分析吗？
#
# 比如我们想要知道某个指标的增长趋势，以代码仓库 `pingcap/tidb` 为例，能否通过 SQL 语句查询该仓库 Star 的增长趋势 (按月累计)，这样的 SQL 语句我们会怎么写?

# %%
query("""
  SELECT
    actor_id,
    actor_login,
    repo_id,
    repo_name,
    created_at,
    DATE_FORMAT(created_at, '%Y-%m-01') as event_month
  FROM
    github_events
  WHERE
    type = 'WatchEvent'
    AND repo_name = 'pingcap/tidb'
  ORDER BY created_at
  LIMIT 10
""")
# Out:
# <style type="text/css">
# #T_0853d_row0_col0, #T_0853d_row0_col1, #T_0853d_row0_col2, #T_0853d_row0_col3, #T_0853d_row0_col4, #T_0853d_row0_col5, #T_0853d_row1_col0, #T_0853d_row1_col1, #T_0853d_row1_col2, #T_0853d_row1_col3, #T_0853d_row1_col4, #T_0853d_row1_col5, #T_0853d_row2_col0, #T_0853d_row2_col1, #T_0853d_row2_col2, #T_0853d_row2_col3, #T_0853d_row2_col4, #T_0853d_row2_col5, #T_0853d_row3_col0, #T_0853d_row3_col1, #T_0853d_row3_col2, #T_0853d_row3_col3, #T_0853d_row3_col4, #T_0853d_row3_col5, #T_0853d_row4_col0, #T_0853d_row4_col1, #T_0853d_row4_col2, #T_0853d_row4_col3, #T_0853d_row4_col4, #T_0853d_row4_col5, #T_0853d_row5_col0, #T_0853d_row5_col1, #T_0853d_row5_col2, #T_0853d_row5_col3, #T_0853d_row5_col4, #T_0853d_row5_col5, #T_0853d_row6_col0, #T_0853d_row6_col1, #T_0853d_row6_col2, #T_0853d_row6_col3, #T_0853d_row6_col4, #T_0853d_row6_col5, #T_0853d_row7_col0, #T_0853d_row7_col1, #T_0853d_row7_col2, #T_0853d_row7_col3, #T_0853d_row7_col4, #T_0853d_row7_col5, #T_0853d_row8_col0, #T_0853d_row8_col1, #T_0853d_row8_col2, #T_0853d_row8_col3, #T_0853d_row8_col4, #T_0853d_row8_col5, #T_0853d_row9_col0, #T_0853d_row9_col1, #T_0853d_row9_col2, #T_0853d_row9_col3, #T_0853d_row9_col4, #T_0853d_row9_col5 {
#   text-align: left;
# }
# </style>
# <table id="T_0853d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >actor_id</th>
#       <th class="col_heading level0 col1" >actor_login</th>
#       <th class="col_heading level0 col2" >repo_id</th>
#       <th class="col_heading level0 col3" >repo_name</th>
#       <th class="col_heading level0 col4" >created_at</th>
#       <th class="col_heading level0 col5" >event_month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0853d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0853d_row0_col0" class="data row0 col0" >1953644</td>
#       <td id="T_0853d_row0_col1" class="data row0 col1" >qiuyesuifeng</td>
#       <td id="T_0853d_row0_col2" class="data row0 col2" >41986369</td>
#       <td id="T_0853d_row0_col3" class="data row0 col3" >pingcap/tidb</td>
#       <td id="T_0853d_row0_col4" class="data row0 col4" >2015-09-06 04:15:40</td>
#       <td id="T_0853d_row0_col5" class="data row0 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_0853d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0853d_row1_col0" class="data row1 col0" >878009</td>
#       <td id="T_0853d_row1_col1" class="data row1 col1" >ngaut</td>
#       <td id="T_0853d_row1_col2" class="data row1 col2" >41986369</td>
#       <td id="T_0853d_row1_col3" class="data row1 col3" >pingcap/tidb</td>
#       <td id="T_0853d_row1_col4" class="data row1 col4" >2015-09-06 04:15:44</td>
#       <td id="T_0853d_row1_col5" class="data row1 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_0853d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0853d_row2_col0" class="data row2 col0" >4242506</td>
#       <td id="T_0853d_row2_col1" class="data row2 col1" >zimulala</td>
#       <td id="T_0853d_row2_col2" class="data row2 col2" >41986369</td>
#       <td id="T_0853d_row2_col3" class="data row2 col3" >pingcap/tidb</td>
#       <td id="T_0853d_row2_col4" class="data row2 col4" >2015-09-06 04:15:53</td>
#       <td id="T_0853d_row2_col5" class="data row2 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_0853d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0853d_row3_col0" class="data row3 col0" >1192573</td>
#       <td id="T_0853d_row3_col1" class="data row3 col1" >shenli</td>
#       <td id="T_0853d_row3_col2" class="data row3 col2" >41986369</td>
#       <td id="T_0853d_row3_col3" class="data row3 col3" >pingcap/tidb</td>
#       <td id="T_0853d_row3_col4" class="data row3 col4" >2015-09-06 04:15:53</td>
#       <td id="T_0853d_row3_col5" class="data row3 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_0853d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0853d_row4_col0" class="data row4 col0" >891222</td>
#       <td id="T_0853d_row4_col1" class="data row4 col1" >coocood</td>
#       <td id="T_0853d_row4_col2" class="data row4 col2" >41986369</td>
#       <td id="T_0853d_row4_col3" class="data row4 col3" >pingcap/tidb</td>
#       <td id="T_0853d_row4_col4" class="data row4 col4" >2015-09-06 04:16:19</td>
#       <td id="T_0853d_row4_col5" class="data row4 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_0853d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0853d_row5_col0" class="data row5 col0" >541236</td>
#       <td id="T_0853d_row5_col1" class="data row5 col1" >tomzhang</td>
#       <td id="T_0853d_row5_col2" class="data row5 col2" >41986369</td>
#       <td id="T_0853d_row5_col3" class="data row5 col3" >pingcap/tidb</td>
#       <td id="T_0853d_row5_col4" class="data row5 col4" >2015-09-06 04:17:26</td>
#       <td id="T_0853d_row5_col5" class="data row5 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_0853d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0853d_row6_col0" class="data row6 col0" >1782276</td>
#       <td id="T_0853d_row6_col1" class="data row6 col1" >FlamingTree</td>
#       <td id="T_0853d_row6_col2" class="data row6 col2" >41986369</td>
#       <td id="T_0853d_row6_col3" class="data row6 col3" >pingcap/tidb</td>
#       <td id="T_0853d_row6_col4" class="data row6 col4" >2015-09-06 04:17:45</td>
#       <td id="T_0853d_row6_col5" class="data row6 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_0853d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0853d_row7_col0" class="data row7 col0" >14066328</td>
#       <td id="T_0853d_row7_col1" class="data row7 col1" >nengwang</td>
#       <td id="T_0853d_row7_col2" class="data row7 col2" >41986369</td>
#       <td id="T_0853d_row7_col3" class="data row7 col3" >pingcap/tidb</td>
#       <td id="T_0853d_row7_col4" class="data row7 col4" >2015-09-06 04:18:10</td>
#       <td id="T_0853d_row7_col5" class="data row7 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_0853d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0853d_row8_col0" class="data row8 col0" >1468284</td>
#       <td id="T_0853d_row8_col1" class="data row8 col1" >se77en</td>
#       <td id="T_0853d_row8_col2" class="data row8 col2" >41986369</td>
#       <td id="T_0853d_row8_col3" class="data row8 col3" >pingcap/tidb</td>
#       <td id="T_0853d_row8_col4" class="data row8 col4" >2015-09-06 04:19:55</td>
#       <td id="T_0853d_row8_col5" class="data row8 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_0853d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0853d_row9_col0" class="data row9 col0" >773853</td>
#       <td id="T_0853d_row9_col1" class="data row9 col1" >c4pt0r</td>
#       <td id="T_0853d_row9_col2" class="data row9 col2" >41986369</td>
#       <td id="T_0853d_row9_col3" class="data row9 col3" >pingcap/tidb</td>
#       <td id="T_0853d_row9_col4" class="data row9 col4" >2015-09-06 04:20:56</td>
#       <td id="T_0853d_row9_col5" class="data row9 col5" >2015-09-01</td>
#     </tr>
#   </tbody>
# </table>

# %%
query("""
  -- 请尝试在空白处编写一个 SQL 语句来实现上述需求，并执行查看结果














""")

# %% [markdown]
# #### 答案
#
# 我们可以利用[窗口函数](https://docs.pingcap.com/zh/tidb/stable/window-functions)来实现这一个需求。窗口函数通常也被称为 “OLAP 函数”，又或者是 “开窗函数”。
#
# 例如，在下面的 SQL 语句当中，我们通过 `OVER` 语句定义窗口的范围，TiDB 会将数据行按照 `created_at` 列进行排序，然后对这些数据行按顺序扫描，将当前行之前的所有行作为一个窗口。
#
# 随着扫描的行数越多，窗口也会逐步扩大。对于每个窗口都会执行一次聚合函数 `COUNT(1)` 来统计窗口内的事件总数，从而可以得到一组随着时间累积增长的统计数据。

# %%
query("""
SELECT
    created_at,
    COUNT(1) OVER (ORDER BY created_at) AS stars
FROM
    github_events
WHERE
    type = 'WatchEvent'
    AND repo_name = 'pingcap/tidb'
ORDER BY created_at
LIMIT 100;
""");

# %% [markdown]
# 在这个基础之上，我们进行一个按月聚合，使用 `DATE_FORMAT('%Y-%m-01')` 函数将同一个月的事件记录进行分组统计。

# %%
query("""
SELECT
  event_month, stars
FROM (
  SELECT
    DATE_FORMAT(created_at, '%Y-%m-01') as event_month,
    COUNT(1) OVER (ORDER BY DATE_FORMAT(created_at, '%Y-%m-01')) AS stars,
    ROW_NUMBER() OVER (PARTITION BY DATE_FORMAT(created_at, '%Y-%m-01')) AS row_num
  FROM
    github_events
  WHERE
    type = 'WatchEvent'
    AND repo_name = 'pingcap/tidb'
  ORDER BY 1
) sub
WHERE row_num = 1
ORDER BY event_month DESC
""");

# %% [markdown]
# 通过 `EXPLAIN` 语句查看其执行计划：

# %%
query("""
EXPLAIN ANALYZE SELECT
  event_month, stars
FROM (
  SELECT
    DATE_FORMAT(created_at, '%Y-%m-01') as event_month,
    COUNT(1) OVER (ORDER BY DATE_FORMAT(created_at, '%Y-%m-01')) AS stars,
    ROW_NUMBER() OVER (PARTITION BY DATE_FORMAT(created_at, '%Y-%m-01')) AS row_num
  FROM
    github_events ge
  WHERE
    type = 'WatchEvent'
    AND repo_name = 'pingcap/tidb'
  ORDER BY 1
) sub
WHERE row_num = 1
ORDER BY event_month DESC;
""");

# %% [markdown]
# #### 创建 TiFlash 副本
#
# 我们发现对于 OLAP 函数，TiDB 的优化器仍然会使用 TiKV 作为存储引擎进行数据查询。
#
# 这是因为在默认情况下，TiDB 不会是为 `github_events` 表创建 TiFlash 副本的，你需要手动地进行创建，创建 TiFlash 副本的方法也十分简单，你只需要执行下面这条 SQL 语句，就可以为 `github_events` 表创建一个 TiFlash 副本：

# %%
execute("""
ALTER TABLE ossinsight.github_events SET TIFLASH REPLICA 1;
""")
# Out:
# '0 record(s) affected'

# %% [markdown]
# 执行完上面的 SQL 语句后，TiFlash 会在后台自动地完成副本的创建，你可以通过执行下面的 SQL 语句来查看副本的创建进度：

# %%
query("""
SELECT * FROM information_schema.tiflash_replica WHERE TABLE_SCHEMA = 'ossinsight' and TABLE_NAME = 'github_events';
""")
# Out:
# <style type="text/css">
# #T_41e7f_row0_col0, #T_41e7f_row0_col1, #T_41e7f_row0_col2, #T_41e7f_row0_col3, #T_41e7f_row0_col4, #T_41e7f_row0_col5, #T_41e7f_row0_col6, #T_41e7f_row0_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_41e7f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >TABLE_SCHEMA</th>
#       <th class="col_heading level0 col1" >TABLE_NAME</th>
#       <th class="col_heading level0 col2" >TABLE_ID</th>
#       <th class="col_heading level0 col3" >REPLICA_COUNT</th>
#       <th class="col_heading level0 col4" >LOCATION_LABELS</th>
#       <th class="col_heading level0 col5" >AVAILABLE</th>
#       <th class="col_heading level0 col6" >PROGRESS</th>
#       <th class="col_heading level0 col7" >TABLE_MODE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41e7f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41e7f_row0_col0" class="data row0 col0" >ossinsight</td>
#       <td id="T_41e7f_row0_col1" class="data row0 col1" >github_events</td>
#       <td id="T_41e7f_row0_col2" class="data row0 col2" >92</td>
#       <td id="T_41e7f_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_41e7f_row0_col4" class="data row0 col4" ></td>
#       <td id="T_41e7f_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_41e7f_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_41e7f_row0_col7" class="data row0 col7" >NORMAL</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 当 AVAILABLE 状态为 1, PROCESS 进度为 1.0（即 100%）时，表示该表的 TiFlash 副本已经创建完成。

# %% [markdown]
# #### 再次执行
#
# 再次执行上面的分析查询语句：

# %%
query("""
EXPLAIN ANALYZE SELECT
  event_month, stars
FROM (
  SELECT
    DATE_FORMAT(created_at, '%Y-%m-01') as event_month,
    COUNT(1) OVER (ORDER BY DATE_FORMAT(created_at, '%Y-%m-01')) AS stars,
    ROW_NUMBER() OVER (PARTITION BY DATE_FORMAT(created_at, '%Y-%m-01')) AS row_num
  FROM
    github_events ge
  WHERE
    type = 'WatchEvent'
    AND repo_name = 'pingcap/tidb'
  ORDER BY 1
) sub
WHERE row_num = 1
ORDER BY event_month DESC;
""");

# %% [markdown]
# 我们会发现此时的执行计划当中已经出现了 `cop[tiflash]` 的字样，说明此时的查询已经在使用 TiFlash 存储引擎来读取数据。

# %% [markdown]
# ### Example 3: Trends in the growth of the number of robots

# %% [markdown]
# > 🤔 看上去上面的查询的速度并没有多大的差异？
#
# 我们来看一下更加复杂的例子，在前面的查询当中，我们只是在查询一个仓库的数据，TiDB 也许还能够借助索引找到一条更高效的基于 TiKV 的执行计划。
#
# 但是有的时候，我们的数据分析可能并没有这么简单，可能需要同时分析 N 个代码仓库，甚至所有代码仓库的数据。又或者是我们希望能够进行大批量的数据报表统计，这个时候需要扫描更为大量的数据，这时候优化器即便仍然选择了索引查询的方式，查询的效率可能仍然不会很高。

# %% [markdown]
# 首先，我们应用我们在背景知识章节当中学习到的技巧，通过 `/*+ READ_FROM_STORAGE(TIKV[ge]) */` Hints 来告诉优化器在查询 `github_events` 表时强制使用 TiKV 存储引擎：

# %%
query("""
WITH bots_with_first_seen AS (
    SELECT
        /*+ READ_FROM_STORAGE(TIKV[ge]) */
        actor_login, MIN(YEAR(created_at)) AS first_seen_at
    FROM github_events ge
    WHERE
        actor_login REGEXP '^(bot-.+|.+bot|.+\\[bot\\]|.+-bot-.+|robot-.+|.+-ci-.+|.+-ci|.+-testing|.+clabot.+|.+-gerrit|k8s-.+|.+-machine|.+-automation|github-.+|.+-github|.+-service|.+-builds|codecov-.+|.+teamcity.+|jenkins-.+|.+-jira-.+)$'
    GROUP BY actor_login
    ORDER BY first_seen_at
),  acc AS (
    SELECT
        COUNT(actor_login) OVER (ORDER BY first_seen_at) AS cnt,
        first_seen_at AS event_year
    FROM
        bots_with_first_seen AS bwfs
    ORDER BY event_year
)
SELECT ANY_VALUE(cnt) AS bots_total, event_year
FROM acc
GROUP BY event_year
ORDER BY event_year;
""");

# %% [markdown]
# 然后我们通过 `/*+ READ_FROM_STORAGE(TIFLASH[ge]) */` Hints 来强制优化器使用 TiFlash 存储引擎来读取 `github_events` 表，再次执行：

# %%
query("""
WITH bots_with_first_seen AS (
    SELECT
        /*+ READ_FROM_STORAGE(TIFLASH[ge]) */
        actor_login, MIN(YEAR(created_at)) AS first_seen_at
    FROM github_events ge
    WHERE
        actor_login REGEXP '^(bot-.+|.+bot|.+\\[bot\\]|.+-bot-.+|robot-.+|.+-ci-.+|.+-ci|.+-testing|.+clabot.+|.+-gerrit|k8s-.+|.+-machine|.+-automation|github-.+|.+-github|.+-service|.+-builds|codecov-.+|.+teamcity.+|jenkins-.+|.+-jira-.+)$'
    GROUP BY actor_login
    ORDER BY first_seen_at
),  acc AS (
    SELECT
        COUNT(actor_login) OVER (ORDER BY first_seen_at) AS cnt,
        first_seen_at AS event_year
    FROM
        bots_with_first_seen AS bwfs
    ORDER BY event_year
)
SELECT ANY_VALUE(cnt) AS bots_total, event_year
FROM acc
GROUP BY event_year
ORDER BY event_year;
""");

# %% [markdown]
# 在更大数据量的情况下，使用 TiFlash 查询相比 TiKV 查询速度上有了明显的提升。

# %% [markdown]
# ### Example 4: Top Contributor List

# %% [markdown]
# 除了单表查询，更多的时候我们需要将多张表的数据结合在一起进行分析，这个时候我们就需要进行表连接查询。
#
# > 如果在一个查询当中需要从多个表中访问数据，TiDB 会怎么进行处理？

# %%
query("""
SELECT
    repo_id, repo_name, stars, created_at
FROM github_repos
ORDER BY stars DESC
LIMIT 10;
""")
# Out:
# <style type="text/css">
# #T_1ba50_row0_col0, #T_1ba50_row0_col1, #T_1ba50_row0_col2, #T_1ba50_row0_col3, #T_1ba50_row1_col0, #T_1ba50_row1_col1, #T_1ba50_row1_col2, #T_1ba50_row1_col3, #T_1ba50_row2_col0, #T_1ba50_row2_col1, #T_1ba50_row2_col2, #T_1ba50_row2_col3, #T_1ba50_row3_col0, #T_1ba50_row3_col1, #T_1ba50_row3_col2, #T_1ba50_row3_col3, #T_1ba50_row4_col0, #T_1ba50_row4_col1, #T_1ba50_row4_col2, #T_1ba50_row4_col3, #T_1ba50_row5_col0, #T_1ba50_row5_col1, #T_1ba50_row5_col2, #T_1ba50_row5_col3, #T_1ba50_row6_col0, #T_1ba50_row6_col1, #T_1ba50_row6_col2, #T_1ba50_row6_col3, #T_1ba50_row7_col0, #T_1ba50_row7_col1, #T_1ba50_row7_col2, #T_1ba50_row7_col3, #T_1ba50_row8_col0, #T_1ba50_row8_col1, #T_1ba50_row8_col2, #T_1ba50_row8_col3, #T_1ba50_row9_col0, #T_1ba50_row9_col1, #T_1ba50_row9_col2, #T_1ba50_row9_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_1ba50_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >repo_id</th>
#       <th class="col_heading level0 col1" >repo_name</th>
#       <th class="col_heading level0 col2" >stars</th>
#       <th class="col_heading level0 col3" >created_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ba50_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ba50_row0_col0" class="data row0 col0" >41986369</td>
#       <td id="T_1ba50_row0_col1" class="data row0 col1" >pingcap/tidb</td>
#       <td id="T_1ba50_row0_col2" class="data row0 col2" >32602</td>
#       <td id="T_1ba50_row0_col3" class="data row0 col3" >2015-09-06 04:01:52</td>
#     </tr>
#     <tr>
#       <th id="T_1ba50_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1ba50_row1_col0" class="data row1 col0" >16563587</td>
#       <td id="T_1ba50_row1_col1" class="data row1 col1" >cockroachdb/cockroach</td>
#       <td id="T_1ba50_row1_col2" class="data row1 col2" >25883</td>
#       <td id="T_1ba50_row1_col3" class="data row1 col3" >2014-02-06 00:18:47</td>
#     </tr>
#     <tr>
#       <th id="T_1ba50_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1ba50_row2_col0" class="data row2 col0" >60246359</td>
#       <td id="T_1ba50_row2_col1" class="data row2 col1" >ClickHouse/ClickHouse</td>
#       <td id="T_1ba50_row2_col2" class="data row2 col2" >25827</td>
#       <td id="T_1ba50_row2_col3" class="data row2 col3" >2016-06-02 08:28:18</td>
#     </tr>
#     <tr>
#       <th id="T_1ba50_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1ba50_row3_col0" class="data row3 col0" >108110</td>
#       <td id="T_1ba50_row3_col1" class="data row3 col1" >mongodb/mongo</td>
#       <td id="T_1ba50_row3_col2" class="data row3 col2" >22653</td>
#       <td id="T_1ba50_row3_col3" class="data row3 col3" >2009-01-15 16:15:18</td>
#     </tr>
#     <tr>
#       <th id="T_1ba50_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1ba50_row4_col0" class="data row4 col0" >196353673</td>
#       <td id="T_1ba50_row4_col1" class="data row4 col1" >taosdata/TDengine</td>
#       <td id="T_1ba50_row4_col2" class="data row4 col2" >19462</td>
#       <td id="T_1ba50_row4_col3" class="data row4 col3" >2019-07-11 08:33:48</td>
#     </tr>
#     <tr>
#       <th id="T_1ba50_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1ba50_row5_col0" class="data row5 col0" >11008207</td>
#       <td id="T_1ba50_row5_col1" class="data row5 col1" >vitessio/vitess</td>
#       <td id="T_1ba50_row5_col2" class="data row5 col2" >14875</td>
#       <td id="T_1ba50_row5_col3" class="data row5 col3" >2013-06-27 21:20:28</td>
#     </tr>
#     <tr>
#       <th id="T_1ba50_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1ba50_row6_col0" class="data row6 col0" >5349565</td>
#       <td id="T_1ba50_row6_col1" class="data row6 col1" >prestodb/presto</td>
#       <td id="T_1ba50_row6_col2" class="data row6 col2" >14086</td>
#       <td id="T_1ba50_row6_col3" class="data row6 col3" >2012-08-09 01:03:37</td>
#     </tr>
#     <tr>
#       <th id="T_1ba50_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1ba50_row7_col0" class="data row7 col0" >927442</td>
#       <td id="T_1ba50_row7_col1" class="data row7 col1" >postgres/postgres</td>
#       <td id="T_1ba50_row7_col2" class="data row7 col2" >11082</td>
#       <td id="T_1ba50_row7_col3" class="data row7 col3" >2010-09-21 11:35:45</td>
#     </tr>
#     <tr>
#       <th id="T_1ba50_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1ba50_row8_col0" class="data row8 col0" >44781140</td>
#       <td id="T_1ba50_row8_col1" class="data row8 col1" >greenplum-db/gpdb</td>
#       <td id="T_1ba50_row8_col2" class="data row8 col2" >5417</td>
#       <td id="T_1ba50_row8_col3" class="data row8 col3" >2015-10-23 00:25:17</td>
#     </tr>
#     <tr>
#       <th id="T_1ba50_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1ba50_row9_col0" class="data row9 col0" >302827809</td>
#       <td id="T_1ba50_row9_col1" class="data row9 col1" >datafuselabs/databend</td>
#       <td id="T_1ba50_row9_col2" class="data row9 col2" >4678</td>
#       <td id="T_1ba50_row9_col3" class="data row9 col3" >2020-10-10 06:04:42</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 例如，可以通过下面的 SQL 语句在这些仓库当中，最近一周最活跃的来自中国的 Code Contributors 是哪些人？

# %%
query("""
SELECT ge.actor_id, gu.login, COUNT(1) AS prs, GROUP_CONCAT(DISTINCT ge.repo_name) AS repos
FROM github_events ge
JOIN github_users gu ON ge.actor_id = gu.id
WHERE
    ge.type = 'PullRequestEvent'
    AND ge.action = 'opened'
    AND ge.created_at > DATE_SUB(NOW(), INTERVAL 1 WEEK) 
    AND gu.country_code = 'CN'
GROUP BY ge.actor_id
ORDER BY prs DESC
LIMIT 20
""")
# Out:
# <style type="text/css">
# #T_220f6_row0_col0, #T_220f6_row0_col1, #T_220f6_row0_col2, #T_220f6_row0_col3, #T_220f6_row1_col0, #T_220f6_row1_col1, #T_220f6_row1_col2, #T_220f6_row1_col3, #T_220f6_row2_col0, #T_220f6_row2_col1, #T_220f6_row2_col2, #T_220f6_row2_col3, #T_220f6_row3_col0, #T_220f6_row3_col1, #T_220f6_row3_col2, #T_220f6_row3_col3, #T_220f6_row4_col0, #T_220f6_row4_col1, #T_220f6_row4_col2, #T_220f6_row4_col3, #T_220f6_row5_col0, #T_220f6_row5_col1, #T_220f6_row5_col2, #T_220f6_row5_col3, #T_220f6_row6_col0, #T_220f6_row6_col1, #T_220f6_row6_col2, #T_220f6_row6_col3, #T_220f6_row7_col0, #T_220f6_row7_col1, #T_220f6_row7_col2, #T_220f6_row7_col3, #T_220f6_row8_col0, #T_220f6_row8_col1, #T_220f6_row8_col2, #T_220f6_row8_col3, #T_220f6_row9_col0, #T_220f6_row9_col1, #T_220f6_row9_col2, #T_220f6_row9_col3, #T_220f6_row10_col0, #T_220f6_row10_col1, #T_220f6_row10_col2, #T_220f6_row10_col3, #T_220f6_row11_col0, #T_220f6_row11_col1, #T_220f6_row11_col2, #T_220f6_row11_col3, #T_220f6_row12_col0, #T_220f6_row12_col1, #T_220f6_row12_col2, #T_220f6_row12_col3, #T_220f6_row13_col0, #T_220f6_row13_col1, #T_220f6_row13_col2, #T_220f6_row13_col3, #T_220f6_row14_col0, #T_220f6_row14_col1, #T_220f6_row14_col2, #T_220f6_row14_col3, #T_220f6_row15_col0, #T_220f6_row15_col1, #T_220f6_row15_col2, #T_220f6_row15_col3, #T_220f6_row16_col0, #T_220f6_row16_col1, #T_220f6_row16_col2, #T_220f6_row16_col3, #T_220f6_row17_col0, #T_220f6_row17_col1, #T_220f6_row17_col2, #T_220f6_row17_col3, #T_220f6_row18_col0, #T_220f6_row18_col1, #T_220f6_row18_col2, #T_220f6_row18_col3, #T_220f6_row19_col0, #T_220f6_row19_col1, #T_220f6_row19_col2, #T_220f6_row19_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_220f6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >actor_id</th>
#       <th class="col_heading level0 col1" >login</th>
#       <th class="col_heading level0 col2" >prs</th>
#       <th class="col_heading level0 col3" >repos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_220f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_220f6_row0_col0" class="data row0 col0" >3427324</td>
#       <td id="T_220f6_row0_col1" class="data row0 col1" >hawkingrei</td>
#       <td id="T_220f6_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_220f6_row0_col3" class="data row0 col3" >pingcap/tidb</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_220f6_row1_col0" class="data row1 col0" >28882257</td>
#       <td id="T_220f6_row1_col1" class="data row1 col1" >guanshengliang</td>
#       <td id="T_220f6_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_220f6_row1_col3" class="data row1 col3" >taosdata/TDengine</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_220f6_row2_col0" class="data row2 col0" >27468951</td>
#       <td id="T_220f6_row2_col1" class="data row2 col1" >castermode</td>
#       <td id="T_220f6_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_220f6_row2_col3" class="data row2 col3" >taosdata/TDengine</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_220f6_row3_col0" class="data row3 col0" >825729</td>
#       <td id="T_220f6_row3_col1" class="data row3 col1" >sangshuduo</td>
#       <td id="T_220f6_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_220f6_row3_col3" class="data row3 col3" >taosdata/TDengine</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_220f6_row4_col0" class="data row4 col0" >8252296</td>
#       <td id="T_220f6_row4_col1" class="data row4 col1" >hjxilinx</td>
#       <td id="T_220f6_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_220f6_row4_col3" class="data row4 col3" >taosdata/TDengine</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_220f6_row5_col0" class="data row5 col0" >29391315</td>
#       <td id="T_220f6_row5_col1" class="data row5 col1" >huangjw806</td>
#       <td id="T_220f6_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_220f6_row5_col3" class="data row5 col3" >risingwavelabs/risingwave</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_220f6_row6_col0" class="data row6 col0" >985418</td>
#       <td id="T_220f6_row6_col1" class="data row6 col1" >zhanglistar</td>
#       <td id="T_220f6_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_220f6_row6_col3" class="data row6 col3" >ClickHouse/ClickHouse</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_220f6_row7_col0" class="data row7 col0" >7846227</td>
#       <td id="T_220f6_row7_col1" class="data row7 col1" >winoros</td>
#       <td id="T_220f6_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_220f6_row7_col3" class="data row7 col3" >pingcap/tidb</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_220f6_row8_col0" class="data row8 col0" >1070352</td>
#       <td id="T_220f6_row8_col1" class="data row8 col1" >b41sh</td>
#       <td id="T_220f6_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_220f6_row8_col3" class="data row8 col3" >datafuselabs/databend</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_220f6_row9_col0" class="data row9 col0" >7493273</td>
#       <td id="T_220f6_row9_col1" class="data row9 col1" >guo-shaoge</td>
#       <td id="T_220f6_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_220f6_row9_col3" class="data row9 col3" >pingcap/tidb</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_220f6_row10_col0" class="data row10 col0" >51781608</td>
#       <td id="T_220f6_row10_col1" class="data row10 col1" >DuanKuanJun</td>
#       <td id="T_220f6_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_220f6_row10_col3" class="data row10 col3" >taosdata/TDengine</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_220f6_row11_col0" class="data row11 col0" >36239017</td>
#       <td id="T_220f6_row11_col1" class="data row11 col1" >YuJuncen</td>
#       <td id="T_220f6_row11_col2" class="data row11 col2" >1</td>
#       <td id="T_220f6_row11_col3" class="data row11 col3" >pingcap/tidb</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_220f6_row12_col0" class="data row12 col0" >14054293</td>
#       <td id="T_220f6_row12_col1" class="data row12 col1" >wshwsh12</td>
#       <td id="T_220f6_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_220f6_row12_col3" class="data row12 col3" >pingcap/tidb</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_220f6_row13_col0" class="data row13 col0" >6949944</td>
#       <td id="T_220f6_row13_col1" class="data row13 col1" >winkyao</td>
#       <td id="T_220f6_row13_col2" class="data row13 col2" >1</td>
#       <td id="T_220f6_row13_col3" class="data row13 col3" >pingcap/tidb</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_220f6_row14_col0" class="data row14 col0" >22127746</td>
#       <td id="T_220f6_row14_col1" class="data row14 col1" >ucasfl</td>
#       <td id="T_220f6_row14_col2" class="data row14 col2" >1</td>
#       <td id="T_220f6_row14_col3" class="data row14 col3" >ClickHouse/ClickHouse</td>
#     </tr>
#     <tr>
#       <th id="T_220f6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_220f6_row15_col0" class="data row15 col0" >5244316</td>
#       <td id="T_220f6_row15_col1" class="data row15 col1" >Yan

# %% [markdown]
# 查看其执行计划：

# %%
query("""
EXPLAIN ANALYZE SELECT ge.actor_id, gu.login, COUNT(1) AS prs, GROUP_CONCAT(DISTINCT ge.repo_name) AS repos
FROM github_events ge
JOIN github_users gu ON ge.actor_id = gu.id
WHERE
    ge.type = 'PullRequestEvent'
    AND ge.action = 'opened'
    AND ge.created_at > DATE_SUB(NOW(), INTERVAL 1 WEEK) 
    AND gu.country_code = 'CN'
GROUP BY ge.actor_id
ORDER BY prs DESC
LIMIT 20
""")
# Out:
# <style type="text/css">
# #T_f9401_row0_col0, #T_f9401_row0_col1, #T_f9401_row0_col2, #T_f9401_row0_col3, #T_f9401_row0_col4, #T_f9401_row0_col5, #T_f9401_row0_col6, #T_f9401_row0_col7, #T_f9401_row0_col8, #T_f9401_row1_col0, #T_f9401_row1_col1, #T_f9401_row1_col2, #T_f9401_row1_col3, #T_f9401_row1_col4, #T_f9401_row1_col5, #T_f9401_row1_col6, #T_f9401_row1_col7, #T_f9401_row1_col8, #T_f9401_row2_col0, #T_f9401_row2_col1, #T_f9401_row2_col2, #T_f9401_row2_col3, #T_f9401_row2_col4, #T_f9401_row2_col5, #T_f9401_row2_col6, #T_f9401_row2_col7, #T_f9401_row2_col8, #T_f9401_row3_col0, #T_f9401_row3_col1, #T_f9401_row3_col2, #T_f9401_row3_col3, #T_f9401_row3_col4, #T_f9401_row3_col5, #T_f9401_row3_col6, #T_f9401_row3_col7, #T_f9401_row3_col8, #T_f9401_row4_col0, #T_f9401_row4_col1, #T_f9401_row4_col2, #T_f9401_row4_col3, #T_f9401_row4_col4, #T_f9401_row4_col5, #T_f9401_row4_col6, #T_f9401_row4_col7, #T_f9401_row4_col8, #T_f9401_row5_col0, #T_f9401_row5_col1, #T_f9401_row5_col2, #T_f9401_row5_col3, #T_f9401_row5_col4, #T_f9401_row5_col5, #T_f9401_row5_col6, #T_f9401_row5_col7, #T_f9401_row5_col8, #T_f9401_row6_col0, #T_f9401_row6_col1, #T_f9401_row6_col2, #T_f9401_row6_col3, #T_f9401_row6_col4, #T_f9401_row6_col5, #T_f9401_row6_col6, #T_f9401_row6_col7, #T_f9401_row6_col8, #T_f9401_row7_col0, #T_f9401_row7_col1, #T_f9401_row7_col2, #T_f9401_row7_col3, #T_f9401_row7_col4, #T_f9401_row7_col5, #T_f9401_row7_col6, #T_f9401_row7_col7, #T_f9401_row7_col8, #T_f9401_row8_col0, #T_f9401_row8_col1, #T_f9401_row8_col2, #T_f9401_row8_col3, #T_f9401_row8_col4, #T_f9401_row8_col5, #T_f9401_row8_col6, #T_f9401_row8_col7, #T_f9401_row8_col8, #T_f9401_row9_col0, #T_f9401_row9_col1, #T_f9401_row9_col2, #T_f9401_row9_col3, #T_f9401_row9_col4, #T_f9401_row9_col5, #T_f9401_row9_col6, #T_f9401_row9_col7, #T_f9401_row9_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_f9401_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >estRows</th>
#       <th class="col_heading level0 col2" >actRows</th>
#       <th class="col_heading level0 col3" >task</th>
#       <th class="col_heading level0 col4" >access object</th>
#       <th class="col_heading level0 col5" >execution info</th>
#       <th class="col_heading level0 col6" >operator info</th>
#       <th class="col_heading level0 col7" >memory</th>
#       <th class="col_heading level0 col8" >disk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9401_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9401_row0_col0" class="data row0 col0" >Projection_12</td>
#       <td id="T_f9401_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_f9401_row0_col2" class="data row0 col2" >20</td>
#       <td id="T_f9401_row0_col3" class="data row0 col3" >root</td>
#       <td id="T_f9401_row0_col4" class="data row0 col4" ></td>
#       <td id="T_f9401_row0_col5" class="data row0 col5" >time:133.7ms, loops:2, Concurrency:OFF</td>
#       <td id="T_f9401_row0_col6" class="data row0 col6" >ossinsight.github_events.actor_id, ossinsight.github_users.login, Column#56, Column#57</td>
#       <td id="T_f9401_row0_col7" class="data row0 col7" >2.23 KB</td>
#       <td id="T_f9401_row0_col8" class="data row0 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_f9401_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9401_row1_col0" class="data row1 col0" >└─TopN_15</td>
#       <td id="T_f9401_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_f9401_row1_col2" class="data row1 col2" >20</td>
#       <td id="T_f9401_row1_col3" class="data row1 col3" >root</td>
#       <td id="T_f9401_row1_col4" class="data row1 col4" ></td>
#       <td id="T_f9401_row1_col5" class="data row1 col5" >time:133.6ms, loops:2</td>
#       <td id="T_f9401_row1_col6" class="data row1 col6" >Column#56:desc, offset:0, count:20</td>
#       <td id="T_f9401_row1_col7" class="data row1 col7" >2.39 KB</td>
#       <td id="T_f9401_row1_col8" class="data row1 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_f9401_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f9401_row2_col0" class="data row2 col0" >  └─HashAgg_19</td>
#       <td id="T_f9401_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_f9401_row2_col2" class="data row2 col2" >28</td>
#       <td id="T_f9401_row2_col3" class="data row2 col3" >root</td>
#       <td id="T_f9401_row2_col4" class="data row2 col4" ></td>
#       <td id="T_f9401_row2_col5" class="data row2 col5" >time:133.6ms, loops:3</td>
#       <td id="T_f9401_row2_col6" class="data row2 col6" >group by:ossinsight.github_events.actor_id, funcs:count(1)->Column#56, funcs:group_concat(distinct ossinsight.github_events.repo_name separator ",")->Column#57, funcs:firstrow(ossinsight.github_events.actor_id)->ossinsight.github_events.actor_id, funcs:firstrow(ossinsight.github_users.login)->ossinsight.github_users.login</td>
#       <td id="T_f9401_row2_col7" class="data row2 col7" >25.7 KB</td>
#       <td id="T_f9401_row2_col8" class="data row2 col8" >0 Bytes</td>
#     </tr>
#     <tr>
#       <th id="T_f9401_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f9401_row3_col0" class="data row3 col0" >    └─IndexJoin_28</td>
#       <td id="T_f9401_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_f9401_row3_col2" class="data row3 col2" >44</td>
#       <td id="T_f9401_row3_col3" class="data row3 col3" >root</td>
#       <td id="T_f9401_row3_col4" class="data row3 col4" ></td>
#       <td id="T_f9401_row3_col5" class="data row3 col5" >time:133.5ms, loops:2, inner:{total:38.8ms, concurrency:5, task:7, construct:27.2ms, fetch:11.6ms, build:17.9µs}, probe:3.79ms</td>
#       <td id="T_f9401_row3_col6" class="data row3 col6" >inner join, inner:TableReader_24, outer key:ossinsight.github_events.actor_id, inner key:ossinsight.github_users.id, equal cond:eq(ossinsight.github_events.actor_id, ossinsight.github_users.id)</td>
#       <td id="T_f9401_row3_col7" class="data row3 col7" >1.65 MB</td>
#       <td id="T_f9401_row3_col8" class="data row3 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_f9401_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f9401_row4_col0" class="data row4 col0" >      ├─TableReader_46(Build)</td>
#       <td id="T_f9401_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_f9401_row4_col2" class="data row4 col2" >11613</td>
#       <td id="T_f9401_row4_col3" class="data row4 col3" >root</td>
#       <td id="T_f9401_row4_col4" class="data row4 col4" >partition:pull_request_event</td>
#       <td id="T_f9401_row4_col5" class="data row4 col5" >time:121.4ms, loops:17, cop_task: {num: 2, max: 121.3ms, min: 45.3ms, avg: 83.3ms, p95: 121.3ms, max_proc_keys: 241655, p95_proc_keys: 241655, tot_proc: 164ms, rpc_num: 2, rpc_time: 166.5ms, copr_cache_hit_ratio: 0.00, distsql_concurrency: 15}</td>
#       <td id="T_f9401_row4_col6" class="data row4 col6" >data:Selection_45</td>
#       <td id="T_f9401_row4_col7" class="data row4 col7" >990.2 KB</td>
#       <td id="T_f9401_row4_col8" class="data row4 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_f9401_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f9401_row5_col0" class="data row5 col0" >      │ └─Selection_45</td>
#       <td id="T_f9401_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_f9401_row5_col2" class="data row5 col2" >11613</td>
#       <td id="T_f9401_row5_col3" class="data row5 col3" >cop[tikv]</td>
#       <td id="T_f9401_row5_col4" class="data row5 col4" ></td>
#       <td id="T_f9401_row5_col5" class="data row5 col5" >tikv_task:{proc max:120ms, min:44ms, avg: 82ms, p80:120ms, p95:120ms, iters:334, tasks:2}, scan_detail: {total_process_keys: 332088, total_process_keys_size: 96370566, total_keys: 332090, rocksdb: {block: {}}}</td>
#       <td id="T_f9401_row5_col6" class="data row5 col6" >eq(ossinsight.github_events.action, "opened"), eq(ossinsight.github_events.type, "PullRequestEvent"), gt(ossinsight.github_

# %% [markdown]
# 如果把日期范围条件 `ge.created_at > DATE_SUB(NOW(), INTERVAL 1 WEEK)` 去掉，查询在整个时间段内最活跃的来自中国的 Code Contributors：

# %%
query("""
SELECT ge.actor_id, gu.login, COUNT(1) AS prs, GROUP_CONCAT(DISTINCT ge.repo_name) AS repos
FROM github_events ge
JOIN github_users gu ON ge.actor_id = gu.id
WHERE
    ge.type = 'PullRequestEvent'
    AND ge.action = 'opened'
    AND gu.country_code = 'CN'
GROUP BY ge.actor_id
ORDER BY prs DESC
LIMIT 20
""")
# Out:
# <style type="text/css">
# #T_b68da_row0_col0, #T_b68da_row0_col1, #T_b68da_row0_col2, #T_b68da_row0_col3, #T_b68da_row1_col0, #T_b68da_row1_col1, #T_b68da_row1_col2, #T_b68da_row1_col3, #T_b68da_row2_col0, #T_b68da_row2_col1, #T_b68da_row2_col2, #T_b68da_row2_col3, #T_b68da_row3_col0, #T_b68da_row3_col1, #T_b68da_row3_col2, #T_b68da_row3_col3, #T_b68da_row4_col0, #T_b68da_row4_col1, #T_b68da_row4_col2, #T_b68da_row4_col3, #T_b68da_row5_col0, #T_b68da_row5_col1, #T_b68da_row5_col2, #T_b68da_row5_col3, #T_b68da_row6_col0, #T_b68da_row6_col1, #T_b68da_row6_col2, #T_b68da_row6_col3, #T_b68da_row7_col0, #T_b68da_row7_col1, #T_b68da_row7_col2, #T_b68da_row7_col3, #T_b68da_row8_col0, #T_b68da_row8_col1, #T_b68da_row8_col2, #T_b68da_row8_col3, #T_b68da_row9_col0, #T_b68da_row9_col1, #T_b68da_row9_col2, #T_b68da_row9_col3, #T_b68da_row10_col0, #T_b68da_row10_col1, #T_b68da_row10_col2, #T_b68da_row10_col3, #T_b68da_row11_col0, #T_b68da_row11_col1, #T_b68da_row11_col2, #T_b68da_row11_col3, #T_b68da_row12_col0, #T_b68da_row12_col1, #T_b68da_row12_col2, #T_b68da_row12_col3, #T_b68da_row13_col0, #T_b68da_row13_col1, #T_b68da_row13_col2, #T_b68da_row13_col3, #T_b68da_row14_col0, #T_b68da_row14_col1, #T_b68da_row14_col2, #T_b68da_row14_col3, #T_b68da_row15_col0, #T_b68da_row15_col1, #T_b68da_row15_col2, #T_b68da_row15_col3, #T_b68da_row16_col0, #T_b68da_row16_col1, #T_b68da_row16_col2, #T_b68da_row16_col3, #T_b68da_row17_col0, #T_b68da_row17_col1, #T_b68da_row17_col2, #T_b68da_row17_col3, #T_b68da_row18_col0, #T_b68da_row18_col1, #T_b68da_row18_col2, #T_b68da_row18_col3, #T_b68da_row19_col0, #T_b68da_row19_col1, #T_b68da_row19_col2, #T_b68da_row19_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_b68da_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >actor_id</th>
#       <th class="col_heading level0 col1" >login</th>
#       <th class="col_heading level0 col2" >prs</th>
#       <th class="col_heading level0 col3" >repos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b68da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b68da_row0_col0" class="data row0 col0" >825729</td>
#       <td id="T_b68da_row0_col1" class="data row0 col1" >sangshuduo</td>
#       <td id="T_b68da_row0_col2" class="data row0 col2" >1945</td>
#       <td id="T_b68da_row0_col3" class="data row0 col3" >taosdata/TDengine</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b68da_row1_col0" class="data row1 col0" >28882257</td>
#       <td id="T_b68da_row1_col1" class="data row1 col1" >guanshengliang</td>
#       <td id="T_b68da_row1_col2" class="data row1 col2" >1509</td>
#       <td id="T_b68da_row1_col3" class="data row1 col3" >taosdata/TDengine</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b68da_row2_col0" class="data row2 col0" >8252296</td>
#       <td id="T_b68da_row2_col1" class="data row2 col1" >hjxilinx</td>
#       <td id="T_b68da_row2_col2" class="data row2 col2" >911</td>
#       <td id="T_b68da_row2_col3" class="data row2 col3" >taosdata/TDengine</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b68da_row3_col0" class="data row3 col0" >891222</td>
#       <td id="T_b68da_row3_col1" class="data row3 col1" >coocood</td>
#       <td id="T_b68da_row3_col2" class="data row3 col2" >768</td>
#       <td id="T_b68da_row3_col3" class="data row3 col3" >pingcap/tidb</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b68da_row4_col0" class="data row4 col0" >4242506</td>
#       <td id="T_b68da_row4_col1" class="data row4 col1" >zimulala</td>
#       <td id="T_b68da_row4_col2" class="data row4 col2" >701</td>
#       <td id="T_b68da_row4_col3" class="data row4 col3" >pingcap/tidb</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b68da_row5_col0" class="data row5 col0" >7499936</td>
#       <td id="T_b68da_row5_col1" class="data row5 col1" >qw4990</td>
#       <td id="T_b68da_row5_col2" class="data row5 col2" >563</td>
#       <td id="T_b68da_row5_col3" class="data row5 col3" >pingcap/tidb</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b68da_row6_col0" class="data row6 col0" >5085485</td>
#       <td id="T_b68da_row6_col1" class="data row6 col1" >amosbird</td>
#       <td id="T_b68da_row6_col2" class="data row6 col2" >505</td>
#       <td id="T_b68da_row6_col3" class="data row6 col3" >ClickHouse/ClickHouse,greenplum-db/gpdb,yandex/ClickHouse,taosdata/TDengine,cockroachdb/cockroach</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b68da_row7_col0" class="data row7 col0" >4352397</td>
#       <td id="T_b68da_row7_col1" class="data row7 col1" >jackysp</td>
#       <td id="T_b68da_row7_col2" class="data row7 col2" >491</td>
#       <td id="T_b68da_row7_col3" class="data row7 col3" >pingcap/tidb</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b68da_row8_col0" class="data row8 col0" >3427324</td>
#       <td id="T_b68da_row8_col1" class="data row8 col1" >hawkingrei</td>
#       <td id="T_b68da_row8_col2" class="data row8 col2" >479</td>
#       <td id="T_b68da_row8_col3" class="data row8 col3" >pingcap/tidb,singularity-data/risingwave</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b68da_row9_col0" class="data row9 col0" >52318143</td>
#       <td id="T_b68da_row9_col1" class="data row9 col1" >plum-lihui</td>
#       <td id="T_b68da_row9_col2" class="data row9 col2" >469</td>
#       <td id="T_b68da_row9_col3" class="data row9 col3" >taosdata/TDengine</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b68da_row10_col0" class="data row10 col0" >528332</td>
#       <td id="T_b68da_row10_col1" class="data row10 col1" >lysu</td>
#       <td id="T_b68da_row10_col2" class="data row10 col2" >463</td>
#       <td id="T_b68da_row10_col3" class="data row10 col3" >pingcap/tidb</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b68da_row11_col0" class="data row11 col0" >5268763</td>
#       <td id="T_b68da_row11_col1" class="data row11 col1" >zz-jason</td>
#       <td id="T_b68da_row11_col2" class="data row11 col2" >454</td>
#       <td id="T_b68da_row11_col3" class="data row11 col3" >pingcap/tidb</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b68da_row12_col0" class="data row12 col0" >44069</td>
#       <td id="T_b68da_row12_col1" class="data row12 col1" >drmingdrmer</td>
#       <td id="T_b68da_row12_col2" class="data row12 col2" >449</td>
#       <td id="T_b68da_row12_col3" class="data row12 col3" >datafuselabs/datafuse,datafuselabs/databend</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b68da_row13_col0" class="data row13 col0" >3325189</td>
#       <td id="T_b68da_row13_col1" class="data row13 col1" >sundy-li</td>
#       <td id="T_b68da_row13_col2" class="data row13 col2" >432</td>
#       <td id="T_b68da_row13_col3" class="data row13 col3" >datafuselabs/databend,datafusedev/fuse-query,datafuselabs/datafuse,ClickHouse/ClickHouse,yandex/ClickHouse,pingcap/tidb,datafuselabs/fuse-query</td>
#     </tr>
#     <tr>
#       <th id="T_b68da_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b68da_row14_col0" class="data row14 col0" >7846227</td>
#       <td id="T_b68da_row14_col1" class="data row14 col1" >winoros</td>
#       <td id="T_b68da_row14_col2" class="data row14 col2" >402</td>
#       <td id="T_b68da_row14_col3" class="data row14 col3" >ping

# %% [markdown]
# 查看其执行计划：

# %%
query("""
EXPLAIN ANALYZE SELECT ge.actor_id, gu.login, COUNT(1) AS prs, GROUP_CONCAT(DISTINCT ge.repo_name) AS repos
FROM github_events ge
JOIN github_users gu ON ge.actor_id = gu.id
WHERE
    ge.type = 'PullRequestEvent'
    AND ge.action = 'opened'
    AND gu.country_code = 'CN'
GROUP BY ge.actor_id
ORDER BY prs DESC
LIMIT 20
""")
# Out:
# <style type="text/css">
# #T_ebd9e_row0_col0, #T_ebd9e_row0_col1, #T_ebd9e_row0_col2, #T_ebd9e_row0_col3, #T_ebd9e_row0_col4, #T_ebd9e_row0_col5, #T_ebd9e_row0_col6, #T_ebd9e_row0_col7, #T_ebd9e_row0_col8, #T_ebd9e_row1_col0, #T_ebd9e_row1_col1, #T_ebd9e_row1_col2, #T_ebd9e_row1_col3, #T_ebd9e_row1_col4, #T_ebd9e_row1_col5, #T_ebd9e_row1_col6, #T_ebd9e_row1_col7, #T_ebd9e_row1_col8, #T_ebd9e_row2_col0, #T_ebd9e_row2_col1, #T_ebd9e_row2_col2, #T_ebd9e_row2_col3, #T_ebd9e_row2_col4, #T_ebd9e_row2_col5, #T_ebd9e_row2_col6, #T_ebd9e_row2_col7, #T_ebd9e_row2_col8, #T_ebd9e_row3_col0, #T_ebd9e_row3_col1, #T_ebd9e_row3_col2, #T_ebd9e_row3_col3, #T_ebd9e_row3_col4, #T_ebd9e_row3_col5, #T_ebd9e_row3_col6, #T_ebd9e_row3_col7, #T_ebd9e_row3_col8, #T_ebd9e_row4_col0, #T_ebd9e_row4_col1, #T_ebd9e_row4_col2, #T_ebd9e_row4_col3, #T_ebd9e_row4_col4, #T_ebd9e_row4_col5, #T_ebd9e_row4_col6, #T_ebd9e_row4_col7, #T_ebd9e_row4_col8, #T_ebd9e_row5_col0, #T_ebd9e_row5_col1, #T_ebd9e_row5_col2, #T_ebd9e_row5_col3, #T_ebd9e_row5_col4, #T_ebd9e_row5_col5, #T_ebd9e_row5_col6, #T_ebd9e_row5_col7, #T_ebd9e_row5_col8, #T_ebd9e_row6_col0, #T_ebd9e_row6_col1, #T_ebd9e_row6_col2, #T_ebd9e_row6_col3, #T_ebd9e_row6_col4, #T_ebd9e_row6_col5, #T_ebd9e_row6_col6, #T_ebd9e_row6_col7, #T_ebd9e_row6_col8, #T_ebd9e_row7_col0, #T_ebd9e_row7_col1, #T_ebd9e_row7_col2, #T_ebd9e_row7_col3, #T_ebd9e_row7_col4, #T_ebd9e_row7_col5, #T_ebd9e_row7_col6, #T_ebd9e_row7_col7, #T_ebd9e_row7_col8, #T_ebd9e_row8_col0, #T_ebd9e_row8_col1, #T_ebd9e_row8_col2, #T_ebd9e_row8_col3, #T_ebd9e_row8_col4, #T_ebd9e_row8_col5, #T_ebd9e_row8_col6, #T_ebd9e_row8_col7, #T_ebd9e_row8_col8, #T_ebd9e_row9_col0, #T_ebd9e_row9_col1, #T_ebd9e_row9_col2, #T_ebd9e_row9_col3, #T_ebd9e_row9_col4, #T_ebd9e_row9_col5, #T_ebd9e_row9_col6, #T_ebd9e_row9_col7, #T_ebd9e_row9_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_ebd9e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >estRows</th>
#       <th class="col_heading level0 col2" >actRows</th>
#       <th class="col_heading level0 col3" >task</th>
#       <th class="col_heading level0 col4" >access object</th>
#       <th class="col_heading level0 col5" >execution info</th>
#       <th class="col_heading level0 col6" >operator info</th>
#       <th class="col_heading level0 col7" >memory</th>
#       <th class="col_heading level0 col8" >disk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebd9e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ebd9e_row0_col0" class="data row0 col0" >Projection_12</td>
#       <td id="T_ebd9e_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_ebd9e_row0_col2" class="data row0 col2" >20</td>
#       <td id="T_ebd9e_row0_col3" class="data row0 col3" >root</td>
#       <td id="T_ebd9e_row0_col4" class="data row0 col4" ></td>
#       <td id="T_ebd9e_row0_col5" class="data row0 col5" >time:283.6ms, loops:2, Concurrency:OFF</td>
#       <td id="T_ebd9e_row0_col6" class="data row0 col6" >ossinsight.github_events.actor_id, ossinsight.github_users.login, Column#56, Column#57</td>
#       <td id="T_ebd9e_row0_col7" class="data row0 col7" >2.61 KB</td>
#       <td id="T_ebd9e_row0_col8" class="data row0 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_ebd9e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ebd9e_row1_col0" class="data row1 col0" >└─TopN_15</td>
#       <td id="T_ebd9e_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_ebd9e_row1_col2" class="data row1 col2" >20</td>
#       <td id="T_ebd9e_row1_col3" class="data row1 col3" >root</td>
#       <td id="T_ebd9e_row1_col4" class="data row1 col4" ></td>
#       <td id="T_ebd9e_row1_col5" class="data row1 col5" >time:283.5ms, loops:2</td>
#       <td id="T_ebd9e_row1_col6" class="data row1 col6" >Column#56:desc, offset:0, count:20</td>
#       <td id="T_ebd9e_row1_col7" class="data row1 col7" >2.39 KB</td>
#       <td id="T_ebd9e_row1_col8" class="data row1 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_ebd9e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ebd9e_row2_col0" class="data row2 col0" >  └─HashAgg_19</td>
#       <td id="T_ebd9e_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_ebd9e_row2_col2" class="data row2 col2" >849</td>
#       <td id="T_ebd9e_row2_col3" class="data row2 col3" >root</td>
#       <td id="T_ebd9e_row2_col4" class="data row2 col4" ></td>
#       <td id="T_ebd9e_row2_col5" class="data row2 col5" >time:283.5ms, loops:3</td>
#       <td id="T_ebd9e_row2_col6" class="data row2 col6" >group by:ossinsight.github_events.actor_id, funcs:count(1)->Column#56, funcs:group_concat(distinct ossinsight.github_events.repo_name separator ",")->Column#57, funcs:firstrow(ossinsight.github_events.actor_id)->ossinsight.github_events.actor_id, funcs:firstrow(ossinsight.github_users.login)->ossinsight.github_users.login</td>
#       <td id="T_ebd9e_row2_col7" class="data row2 col7" >754.4 KB</td>
#       <td id="T_ebd9e_row2_col8" class="data row2 col8" >0 Bytes</td>
#     </tr>
#     <tr>
#       <th id="T_ebd9e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ebd9e_row3_col0" class="data row3 col0" >    └─IndexJoin_28</td>
#       <td id="T_ebd9e_row3_col1" class="data row3 col1" >0.01</td>
#       <td id="T_ebd9e_row3_col2" class="data row3 col2" >26147</td>
#       <td id="T_ebd9e_row3_col3" class="data row3 col3" >root</td>
#       <td id="T_ebd9e_row3_col4" class="data row3 col4" ></td>
#       <td id="T_ebd9e_row3_col5" class="data row3 col5" >time:258.3ms, loops:27, inner:{total:310.5ms, concurrency:5, task:15, construct:210.3ms, fetch:99.2ms, build:943.7µs}, probe:58.7ms</td>
#       <td id="T_ebd9e_row3_col6" class="data row3 col6" >inner join, inner:TableReader_24, outer key:ossinsight.github_events.actor_id, inner key:ossinsight.github_users.id, equal cond:eq(ossinsight.github_events.actor_id, ossinsight.github_users.id)</td>
#       <td id="T_ebd9e_row3_col7" class="data row3 col7" >22.6 MB</td>
#       <td id="T_ebd9e_row3_col8" class="data row3 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_ebd9e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ebd9e_row4_col0" class="data row4 col0" >      ├─TableReader_46(Build)</td>
#       <td id="T_ebd9e_row4_col1" class="data row4 col1" >0.01</td>
#       <td id="T_ebd9e_row4_col2" class="data row4 col2" >165523</td>
#       <td id="T_ebd9e_row4_col3" class="data row4 col3" >root</td>
#       <td id="T_ebd9e_row4_col4" class="data row4 col4" >partition:pull_request_event</td>
#       <td id="T_ebd9e_row4_col5" class="data row4 col5" >time:159.5ms, loops:171, cop_task: {num: 2, max: 156.1ms, min: 53.7ms, avg: 104.9ms, p95: 156.1ms, max_proc_keys: 241655, p95_proc_keys: 241655, tot_proc: 184ms, rpc_num: 2, rpc_time: 209.7ms, copr_cache_hit_ratio: 0.00, distsql_concurrency: 15}</td>
#       <td id="T_ebd9e_row4_col6" class="data row4 col6" >data:Selection_45</td>
#       <td id="T_ebd9e_row4_col7" class="data row4 col7" >11.4 MB</td>
#       <td id="T_ebd9e_row4_col8" class="data row4 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_ebd9e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ebd9e_row5_col0" class="data row5 col0" >      │ └─Selection_45</td>
#       <td id="T_ebd9e_row5_col1" class="data row5 col1" >0.01</td>
#       <td id="T_ebd9e_row5_col2" class="data row5 col2" >165523</td>
#       <td id="T_ebd9e_row5_col3" class="data row5 col3" >cop[tikv]</td>
#       <td id="T_ebd9e_row5_col4" class="data row5 col4" ></td>
#       <td id="T_ebd9e_row5_col5" class="data row5 col5" >tikv_task:{proc max:116ms, min:44ms, avg: 80ms, p80:116ms, p95:116ms, iters:334, tasks:2}, scan_detail: {total_process_keys: 332088, total_process_keys_size: 96370566, total_keys: 332090, rocksdb: {block: {}}}</td>
#       <td id="T_ebd9e_row5_col6" class="data row5 col6" >eq(ossinsight.github_events.action, "opened"), eq(ossinsight.github_events.type, "PullRequestEvent")</td>

# %% [markdown]
# 通过对比前后两次查询的执行计划，可以发现优化器会根据查询所设置的数据量的不同，智能的选择是使用能够利用索引能力的 TiKV 还是使用能够胜任大量数据快速扫描的 TiFlash 来查询数据。
#
# 通过优化器，TiDB 已经为我们智能地决定在何时何表使用何种存储引擎效率更高，这很大程度地能减轻了编写 SQL 时的工作量，让我们将注意力更好地聚焦到我们的实际业务当中。

# %% [markdown]
# ## 图表可视化

# %% [markdown]
# 在上面的章节当中，我们已经掌握了通过 SQL 语句来进行简单的数据分析，现在，我们可以使用各种 BI 工具或者前端图表框架来将 SQL 语句查询到的数据结果进行可视化。
#
# 你可以通过 [Data visualization tools for application developers](https://awesome.cube.dev/) 到这些工具的集合。
#
# 这里我们以 [Grafana Cloud](https://grafana.com/products/cloud/) 为例，介绍如何将 TiDB Cloud Serverless tier 与其他数据可视化工具进行集成。

# %% [markdown]
# ### 创建账号
#
# 你可以通过你的 GitHub 账号快速[注册](https://grafana.com/auth/sign-up/create-user)一个 Grafana Cloud 账号。
#
# 在其 Overview 页面，可以在 Grafana 实例的卡片当中点击 “Lauch”按钮来启动一个 Grafana 实例。

# %% [markdown]
# ### 连接 TiDB Cloud

# %% [markdown]
# 在进入到 Grafana 的管理界面时，我们可以点击左侧菜单中的 “Configuration” > “Data sources” 菜单项进入到数据源配置页面。
#
# <center>
#     <img width="200" alt="image" src="https://user-images.githubusercontent.com/88522432/205971297-ab1b822a-2461-445c-8f85-99a5f834dc7d.png">
#     <p><i>Data source config entry</i></p>
# </center>
#
# 添加新的 Data Source，Data Source 的类型可以选择使用 “MySQL”。
#
# <center>
#     <img width="600" alt="image" src="https://user-images.githubusercontent.com/88522432/205973144-85da8262-7efd-4762-b958-6b710a6f1c43.png">
#     <p><i>Add data source</i></p>
# </center>
#
# 将 TiDB Cloud Serverless Tier 集群的连接信息填写到对应的位置。
#
# 因为 Serverless Tier 要求必须使用 TLS 连接，因此还需要勾选 “With CA Cert” 选项，然后将受信任的 CA 证书填写到文本框当中（例如：[isrgrootx1.pem.txt](https://letsencrypt.org/certs/isrgrootx1.pem.txt)）。
#
# <center>
#     <img width="540" alt="image" src="https://user-images.githubusercontent.com/88522432/205973887-a1fb69be-2d0d-4166-b234-61d17a1196a2.png">
#     <p><i>Config data source</i></p>
# </center>

# %% [markdown]
# ### 新建 Dashboard
#
# 点击左侧菜单中 “New Dashboard” 按钮以创建一个新的 Dashboard。
#
# <center>
#     <img width="254" alt="image" src="https://user-images.githubusercontent.com/88522432/205975900-472c39c4-7eb2-45a4-b928-cd89567fe6bc.png">
#     <p><i>New Dashbaord</i></p>
# </center>
#
# 在 Dashboard 上新建创建新的 Panel，然后将数据源选择了上面创建的 “TiDB” 数据库，编写 SQL 语句，执行，然后选择合适的图表用于数据可视化。
#
# <center>
#     <img width="1000" alt="image" src="https://user-images.githubusercontent.com/88522432/205977281-234203cc-bf3b-44d3-920e-9b17c077c357.png">
#     <p><i>New Panel</i></p>
# </center>
