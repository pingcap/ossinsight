# %% [markdown]
# ## Mini OSS Insight Workshop
#
# 👏 欢迎来到 Mini OSS Insight 的 Workshop!
#
# 这是关于 Workshop 的完整指南，你可以通过阅读该指南一步一步地搭建起一个 Mini 版的 OSS Insight，并在过程掌握一些使用 TiDB / TiDB Cloud 进行数据分析的技巧。

# %% [markdown]
# ### 准备
#
# 在开始之前，你需要确保在你的开发环境中已经安装了以下软件/工具：
#
# - 可供连接的 TiDB 集群 - 用于存储数据的数据库
# - MyCLI - 连接到 TiDB 集群
# - Node.js 18.x and above - API Server 的运行时环境
# - PNPM - Node.js 的包管理器
# - Python 3.x and pip - Jupyter Notebook 需要的运行时环境
#
# #### 1. 启动 TiDB 集群
#
# 首先, 你需要开启一个 TiDB 集群。你可以通过查看文档 [TiDB Cloud Quick Start](https://docs.pingcap.com/tidbcloud/tidb-cloud-quickstart#step-1-create-a-tidb-cluster) 学习如何创建一个 **Serverless tier** 集群，这可能会需要 20～25s 的时间。
#
# 在你创建完集群，你可以进入到集群的详情页。在这个页面，你可以在 **Connection** 面板中找到数据库集群的连接信息。
#
# <center>
#   <img align="middle" width="800" alt="Serverless Tier Cluster Manage Interface" src="https://user-images.githubusercontent.com/5086433/204476069-0ddbdf6f-419c-4291-b929-ccfbd2f5ea5f.png">
#   <p><i>Serverless Tier 集群管理界面</i></p>
# </center>
#
# You can enter to the cluster's security settings window by clicking on the modify menu in the upper right corner of the cluster details page and generate a root user password.
#
# <center>
#   <img width="480" alt="The Cluster Modify Menu" src="https://user-images.githubusercontent.com/85985765/204876779-3a4c6ac4-8814-47cd-b82a-40eb5e4d8f96.png">
#   <p><i>The Cluster Modify Menu</i></p>
# </center>
#
# <center>
#   <img width="720" alt="Security Settings" src="https://user-images.githubusercontent.com/85985765/204877348-5c3e9012-f7bf-42e9-8a03-fd9f14bfc826.png">
#   <p><i>Security Settings</i></p>
# </center>
#
# #### 3. 个人 GitHub 的 Access Token
#
# You need to prepare a personal access token to allow the application to access the data through the GitHub API.
#
# > **Note**
# >
# > If you are viewing this document from GitHub codespace, you can skip this step because `GITHUB_TOKEN` is set by default in the codespace environment.
# >
#
# You can learn how to generate one by reading: [Creating a personal access token](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token). Or just click this [link](https://github.com/settings/personal-access-tokens/new) to generate your personal access token quickly.
#
# <center>
#   <img align="middle" width="800" alt="Create a New GitHub Personal Access Token" src="https://user-images.githubusercontent.com/5086433/204564273-93cccbe4-d10a-4d1b-a9d1-112a1144712a.png">
#   <p><i>Create a new GitHub personal access token</i></p>
# </center>

# %% [markdown]
# #### 4. 设置环境变量

# %%
import getpass
import os

api_server_dot_env="./packages/api-server/.env"
if os.path.exists(api_server_dot_env): 
    con = input(api_server_dot_env + " file already exists, do you want to overwrite it? (y/n) [y]")
    if con != 'y':
        exit();

# Config GitHub personal access token.
github_token = ""
if os.getenv('GITHUB_TOKEN') is None:
    github_token = getpass.getpass(prompt='Enter your personal access token of GitHub: ')
else:
    github_token = os.getenv('GITHUB_TOKEN')

# Config database connection.
db_endpoint = input("The endpoint of TiDB cluster: ")
db_port = input("The port of TiDB cluster [4000]: ")

if db_port == "":
    db_port = "4000"

db_username = input("The username of TiDB cluster: ")
db_password = getpass.getpass(prompt='Enter the password of TiDB cluster: ')
db_name = "ossinsight"
db_enable_ssl = input("Enable ssl connection to the TiDB cluster? (y/n) [y]") or "y"
db_ssl_config='&ssl={"minVersion":"TLSv1.2"}'
if db_enable_ssl == "n":
    db_ssl_config = ""

api_database_url = "mysql://{}:{}@{}:{}/{}?connectionLimit=100&queueLimit=10000{}\n".format(
    db_username, db_password, db_endpoint, db_port, db_name, db_ssl_config
)

etl_database_url = "tidb://{}:{}@{}:{}/{}".format(
    db_username, db_password, db_endpoint, db_port, db_name
)

os.system("gh secret set DB_ENDPOINT --body \"" + db_endpoint + "\" -a codespaces --repo ${GITHUB_REPOSITORY}")
os.system("gh secret set DB_PORT --body \"" + db_port + "\" -a codespaces --repo ${GITHUB_REPOSITORY}")
os.system("gh secret set DB_USERNAME --body \"" + db_username + "\" -a codespaces --repo ${GITHUB_REPOSITORY}")
os.system("gh secret set DB_PASSWORD --body \"" + db_password + "\" -a codespaces --repo ${GITHUB_REPOSITORY}")
os.system("gh secret set DB_NAME --body \"" + db_name + "\" -a codespaces --repo ${GITHUB_REPOSITORY}")
os.system("gh secret set DB_ENABLE_SSL --body \"" + db_enable_ssl + "\" -a codespaces --repo ${GITHUB_REPOSITORY}")
os.system("gh secret set API_DATABASE_URL --body \"" + api_database_url + "\" -a codespaces --repo ${GITHUB_REPOSITORY}")
os.system("gh secret set ETL_DATABASE_URL --body \"" + etl_database_url + "\" -a codespaces --repo ${GITHUB_REPOSITORY}")

# Write to ./packages/api-server/.env file.
with open(api_server_dot_env, "w") as file:
    file.write(
        "DATABASE_URL={}".format(api_database_url)
    )
    file.write("ENABLE_CACHE=false\n")
    file.write("GITHUB_ACCESS_TOKENS={}\n".format(github_token))

print("Setup successfully!")

# %% [markdown]
# #### 5. 验证是否能够连接到 TiDB 集群
#
# 上执行下面的 SQL 语句验证是否能够连接到 TiDB 集群:

# %%
# !mycli -h ${DB_ENDPOINT} -P ${DB_PORT} -u ${DB_USERNAME} -p ${DB_PASSWORD} -D ${DB_NAME} \
    --ssl-ca=/etc/ssl/certs/ca-certificates.crt \
    --ssl-verify-server-cert \
     -e 'SELECT tidb_version()\G'
# Out:
# tidb_version()
# Release Version: v6.3.0-serverless
# Edition: Community
# Git Commit Hash: e87c16b215d518aed4921b8ef3b13e90e3ed6e2d
# Git Branch: release-6.3-serverless
# UTC Build Time: 2022-11-25 09:31:28
# GoVersion: go1.19
# Race Enabled: false
# TiKV Min Version: 6.1.0
# Check Table Before Drop: false
# Store: tikv

# %% [markdown]
# 如果成功执行，你会看到 TiDB 集群的版本信息。

# %% [markdown]
# ### 加载数据
#
# 从 2011 年开始，GitHub 便对外提供了一个 [`/events`](https://api.github.com/events) API，我们可以通过这个 API 来获取在 GitHub 上发生的近乎实时（GitHub 设定了 5 分钟的延迟）的公开事件。
#
# > **GitHub API 文档**
# >
# > Link: https://docs.github.com/en/rest/activity/events
# >

# %%
# !curl -s \
  -H "Accept: application/vnd.github.v3+json" \
  -H "Authorization: token $GITHUB_TOKEN" \
  https://api.github.com/events
# Out:
# [
#   {
#     "id": "25618713222",
#     "type": "PushEvent",
#     "actor": {
#       "id": 80751634,
#       "login": "vacseeker",
#       "display_login": "vacseeker",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/vacseeker",
#       "avatar_url": "https://avatars.githubusercontent.com/u/80751634?"
#     },
#     "repo": {
#       "id": 348289466,
#       "name": "vacseeker/vacseeker.github.io",
#       "url": "https://api.github.com/repos/vacseeker/vacseeker.github.io"
#     },
#     "payload": {
#       "push_id": 11862047375,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "99ad4573b8edc52b2535ef196ebdae751b2a10b2",
#       "before": "80118a6f474389f0c777132f3e81f60e4594b26c",
#       "commits": [
#         {
#           "sha": "99ad4573b8edc52b2535ef196ebdae751b2a10b2",
#           "author": {
#             "email": "80751634+vacseeker@users.noreply.github.com",
#             "name": "vacseeker"
#           },
#           "message": "snred_commit_message",
#           "distinct": true,
#           "url": "https://api.github.com/repos/vacseeker/vacseeker.github.io/commits/99ad4573b8edc52b2535ef196ebdae751b2a10b2"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   },
#   {
#     "id": "25618713219",
#     "type": "PushEvent",
#     "actor": {
#       "id": 41898282,
#       "login": "github-actions[bot]",
#       "display_login": "github-actions",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/github-actions[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/41898282?"
#     },
#     "repo": {
#       "id": 407301902,
#       "name": "puntorigen/puntorigen",
#       "url": "https://api.github.com/repos/puntorigen/puntorigen"
#     },
#     "payload": {
#       "push_id": 11862047364,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "b13e0c05a1c929e5035fa0ad6eb2ef17d22dd625",
#       "before": "4363c294f004d7145d1d5023ba07b39158a2f25e",
#       "commits": [
#         {
#           "sha": "b13e0c05a1c929e5035fa0ad6eb2ef17d22dd625",
#           "author": {
#             "email": "github-action@users.noreply.github.com",
#             "name": "GitHub Action"
#           },
#           "message": "Auto updated readme file",
#           "distinct": true,
#           "url": "https://api.github.com/repos/puntorigen/puntorigen/commits/b13e0c05a1c929e5035fa0ad6eb2ef17d22dd625"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   },
#   {
#     "id": "25618713259",
#     "type": "PushEvent",
#     "actor": {
#       "id": 82041246,
#       "login": "vaidyanath-b",
#       "display_login": "vaidyanath-b",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/vaidyanath-b",
#       "avatar_url": "https://avatars.githubusercontent.com/u/82041246?"
#     },
#     "repo": {
#       "id": 573295860,
#       "name": "vaidyanath-b/swachh-server",
#       "url": "https://api.github.com/repos/vaidyanath-b/swachh-server"
#     },
#     "payload": {
#       "push_id": 11862047371,
#       "size": 2,
#       "distinct_size": 2,
#       "ref": "refs/heads/main",
#       "head": "cd7c8f3eb7dadeb9fd895828e223d42a1a618a6c",
#       "before": "8427d30f06e2f4bec5954d017ba912acd2b1d07c",
#       "commits": [
#         {
#           "sha": "39232abd9bbbe7a3047145fcf882aa046685f463",
#           "author": {
#             "email": "93600615+alapanoski@users.noreply.github.com",
#             "name": "Allen Shibu"
#           },
#           "message": "Merge pull request #7 from vaidyanath-b/main\n\ncollection report added",
#           "distinct": true,
#           "url": "https://api.github.com/repos/vaidyanath-b/swachh-server/commits/39232abd9bbbe7a3047145fcf882aa046685f463"
#         },
#         {
#           "sha": "cd7c8f3eb7dadeb9fd895828e223d42a1a618a6c",
#           "author": {
#             "email": "82041246+vaidyanath-b@users.noreply.github.com",
#             "name": "vaidyanath-b"
#           },
#           "message": "Merge branch 'runtime-terror-hack:main' into main",
#           "distinct": true,
#           "url": "https://api.github.com/repos/vaidyanath-b/swachh-server/commits/cd7c8f3eb7dadeb9fd895828e223d42a1a618a6c"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   },
#   {
#     "id": "25618713266",
#     "type": "CreateEvent",
#     "actor": {
#       "id": 735836,
#       "login": "felipedeboni",
#       "display_login": "felipedeboni",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/felipedeboni",
#       "avatar_url": "https://avatars.githubusercontent.com/u/735836?"
#     },
#     "repo": {
#       "id": 573474388,
#       "name": "felipedeboni/test-gh-actions",
#       "url": "https://api.github.com/repos/felipedeboni/test-gh-actions"
#     },
#     "payload": {
#       "ref": null,
#       "ref_type": "repository",
#       "master_branch": "main",
#       "description": null,
#       "pusher_type": "user"
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   },
#   {
#     "id": "25618713221",
#     "type": "PushEvent",
#     "actor": {
#       "id": 41898282,
#       "login": "github-actions[bot]",
#       "display_login": "github-actions",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/github-actions[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/41898282?"
#     },
#     "repo": {
#       "id": 351445612,
#       "name": "eclipse/birt-website",
#       "url": "https://api.github.com/repos/eclipse/birt-website"
#     },
#     "payload": {
#       "push_id": 11862047378,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/gh-pages",
#       "head": "ab825513ae39a6aef0ceaa9b3741e904980c526e",
#       "before": "dacffd22617bbd254ab063ad2166ce94088f3dbb",
#       "commits": [
#         {
#           "sha": "ab825513ae39a6aef0ceaa9b3741e904980c526e",
#           "author": {
#             "email": "wimjongman@users.noreply.github.com",
#             "name": "wimjongman"
#           },
#           "message": "deploy: 1ff8ef90af361ea7e974111672cb09beafb0986f",
#           "distinct": true,
#           "url": "https://api.github.com/repos/eclipse/birt-website/commits/ab825513ae39a6aef0ceaa9b3741e904980c526e"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z",
#     "org": {
#       "id": 56974,
#       "login": "eclipse",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/eclipse",
#       "avatar_url": "https://avatars.githubusercontent.com/u/56974?"
#     }
#   },
#   {
#     "id": "25618713256",
#     "type": "WatchEvent",
#     "actor": {
#       "id": 19875557,
#       "login": "eeshankeni",
#       "display_login": "eeshankeni",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/eeshankeni",
#       "avatar_url": "https://avatars.githubusercontent.com/u/19875557?"
#     },
#     "repo": {
#       "id": 52630616,
#       "name": "apollographql/apollo-client",
#       "url": "https://api.github.com/repos/apollographql/apollo-client"
#     },
#     "payload": {
#       "action": "started"
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z",
#     "org": {
#       "id": 17189275,
#       "login": "apollographql",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/apollographql",
#       "avatar_url": "https://avatars.githubusercontent.com/u/17189275?"
#     }
#   },
#   {
#     "id": "25618713185",
#     "type": "CreateEvent",
#     "actor": {
#       "id": 74860846,
#       "login": "ValerianExp",
#       "display_login": "ValerianExp",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/ValerianExp",
#       "avatar_url": "https://avatars.githubusercontent.com/u/74860846?"
#     },
#     "repo": {
#       "id": 573474389,
#       "name": "ValerianExp/AssesmentTestForum",
#       "url": "https://api.github.com/repos/ValerianExp/AssesmentTestForum"
#     },
#     "payload": {
#       "ref": null,
#       "ref_type": "repository",
#       "master_branch": "main",
#       "description": null,
#       "pusher_type": "user"
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   },
#   {
#     "id": "25618713180",
#     "type": "PushEvent",
#     "actor": {
#       "id": 29139614,
#       "login": "renovate[bot]",
#       "display_login": "renovate",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/renovate[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/29139614?"
#     },
#     "repo": {
#       "id": 350464188,
#       "name": "esm-bundle/vuex",
#       "url": "https://api.github.com/repos/esm-bundle/vuex"
#     },
#     "payload": {
#       "push_id": 11862047340,
#       "size": 2,
#       "distinct_size": 1,
#       "ref": "refs/heads/renovate/rollup-3.x",
#       "head": "afdf0c4a7593080a23e5a03856f032f9d5cdfec6",
#       "before": "f702427e2d99e4d5b13317d528c6cbeb3b2b6e43",
#       "commits": [
#         {
#           "sha": "5f3351abf727dcd12e90e6081d4b8d9f8b9055af",
#           "author": {
#             "email": "29139614+renovate[bot]@users.noreply.github.com",
#             "name": "renovate[bot]"
#           },
#           "message": "Update dependency release-it to v15.5.1 (#271)\n\nCo-authored-by: renovate[bot] <29139614+renovate[bot]@users.noreply.github.com>",
#           "distinct": false,
#           "url": "https://api.github.com/repos/esm-bundle/vuex/commits/5f3351abf727dcd12e90e6081d4b8d9f8b9055af"
#         },
#         {
#           "sha": "afdf0c4a7593080a23e5a03856f032f9d5cdfec6",
#           "author": {
#             "email": "29139614+renovate[bot]@users.noreply.github.com",
#             "name": "renovate[bot]"
#           },
#           "message": "Update dependency rollup to v3",
#           "distinct": true,
#           "url": "https://api.github.com/repos/esm-bundle/vuex/commits/afdf0c4a7593080a23e5a03856f032f9d5cdfec6"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z",
#     "org": {
#       "id": 60286277,
#       "login": "esm-bundle",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/esm-bundle",
#       "avatar_url": "https://avatars.githubusercontent.com/u/60286277?"
#     }
#   },
#   {
#     "id": "25618713157",
#     "type": "PushEvent",
#     "actor": {
#       "id": 2299951,
#       "login": "pietroalbini",
#       "display_login": "pietroalbini",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/pietroalbini",
#       "avatar_url": "https://avatars.githubusercontent.com/u/2299951?"
#     },
#     "repo": {
#       "id": 26193547,
#       "name": "rust-lang/crates.io-index",
#       "url": "https://api.github.com/repos/rust-lang/crates.io-index"
#     },
#     "payload": {
#       "push_id": 11862047347,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/master",
#       "head": "6a9de175f77fb5d9025dbce9bb6149684787f926",
#       "before": "e3b690ff325182eee6973afffb19c980b1d3274b",
#       "commits": [
#         {
#           "sha": "6a9de175f77fb5d9025dbce9bb6149684787f926",
#           "author": {
#             "email": "bors@rust-lang.org",
#             "name": "bors"
#           },
#           "message": "Updating crate `fl2rust#0.5.12`",
#           "distinct": true,
#           "url": "https://api.github.com/repos/rust-lang/crates.io-index/commits/6a9de175f77fb5d9025dbce9bb6149684787f926"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z",
#     "org": {
#       "id": 5430905,
#       "login": "rust-lang",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/rust-lang",
#       "avatar_url": "https://avatars.githubusercontent.com/u/5430905?"
#     }
#   },
#   {
#     "id": "25618713181",
#     "type": "CreateEvent",
#     "actor": {
#       "id": 110819800,
#       "login": "Ansiyashafeeq",
#       "display_login": "Ansiyashafeeq",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Ansiyashafeeq",
#       "avatar_url": "https://avatars.githubusercontent.com/u/110819800?"
#     },
#     "repo": {
#       "id": 573474386,
#       "name": "Ansiyashafeeq/Cfreshdby",
#       "url": "https://api.github.com/repos/Ansiyashafeeq/Cfreshdby"
#     },
#     "payload": {
#       "ref": null,
#       "ref_type": "repository",
#       "master_branch": "main",
#       "description": null,
#       "pusher_type": "user"
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   },
#   {
#     "id": "25618713191",
#     "type": "PushEvent",
#     "actor": {
#       "id": 1139984,
#       "login": "joshbegley",
#       "display_login": "joshbegley",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/joshbegley",
#       "avatar_url": "https://avatars.githubusercontent.com/u/1139984?"
#     },
#     "repo": {
#       "id": 241755385,
#       "name": "joshbegley/nyt-latest",
#       "url": "https://api.github.com/repos/joshbegley/nyt-latest"
#     },
#     "payload": {
#       "push_id": 11862047346,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/master",
#       "head": "5143ef358ae37af69ea179254f6cc303f8050e5c",
#       "before": "25b27aab754042d2f582b1e815bac11cfc355fe4",
#       "commits": [
#         {
#           "sha": "5143ef358ae37af69ea179254f6cc303f8050e5c",
#           "author": {
#             "email": "josh@joshbegley.com",
#             "name": "root"
#           },
#           "message": "automatic updates",
#           "distinct": true,
#           "url": "https://api.github.com/repos/joshbegley/nyt-latest/commits/5143ef358ae37af69ea179254f6cc303f8050e5c"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   },
#   {
#     "id": "25618713217",
#     "type": "WatchEvent",
#     "actor": {
#       "id": 58053397,
#       "login": "fernanduandrade",
#       "display_login": "fernanduandrade",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/fernanduandrade",
#       "avatar_url": "https://avatars.githubusercontent.com/u/58053397?"
#     },
#     "repo": {
#       "id": 573413642,
#       "name": "alisonjr/azure-task-google-chat",
#       "url": "https://api.github.com/repos/alisonjr/azure-task-google-chat"
#     },
#     "payload": {
#       "action": "started"
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   },
#   {
#     "id": "25618713211",
#     "type": "WatchEvent",
#     "actor": {
#       "id": 59648528,
#       "login": "Jahirul07",
#       "display_login": "Jahirul07",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Jahirul07",
#       "avatar_url": "https://avatars.githubusercontent.com/u/59648528?"
#     },
#     "repo": {
#       "id": 135786093,
#       "name": "typescript-cheatsheets/react",
#       "url": "https://api.github.com/repos/typescript-cheatsheets/react"
#     },
#     "payload": {
#       "action": "started"
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z",
#     "org": {
#       "id": 50188264,
#       "login": "typescript-cheatsheets",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/typescript-cheatsheets",
#       "avatar_url": "https://avatars.githubusercontent.com/u/50188264?"
#     }
#   },
#   {
#     "id": "25618713215",
#     "type": "IssuesEvent",
#     "actor": {
#       "id": 64501125,
#       "login": "kr15tyk",
#       "display_login": "kr15tyk",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/kr15tyk",
#       "avatar_url": "https://avatars.githubusercontent.com/u/64501125?"
#     },
#     "repo": {
#       "id": 340391790,
#       "name": "ND-iTC/Documents",
#       "url": "https://api.github.com/repos/ND-iTC/Documents"
#     },
#     "payload": {
#       "action": "opened",
#       "issue": {
#         "url": "https://api.github.com/repos/ND-iTC/Documents/issues/175",
#         "repository_url": "https://api.github.com/repos/ND-iTC/Documents",
#         "labels_url": "https://api.github.com/repos/ND-iTC/Documents/issues/175/labels{/name}",
#         "comments_url": "https://api.github.com/repos/ND-iTC/Documents/issues/175/comments",
#         "events_url": "https://api.github.com/repos/ND-iTC/Documents/issues/175/events",
#         "html_url": "https://github.com/ND-iTC/Documents/issues/175",
#         "id": 1472987279,
#         "node_id": "I_kwDOFEn3bs5XzACP",
#         "number": 175,
#         "title": "Section 4.2.1.1, FCS_DTLSC_EXT.1.4, TSS correction",
#         "user": {
#           "login": "kr15tyk",
#           "id": 64501125,
#           "node_id": "MDQ6VXNlcjY0NTAxMTI1",
#           "avatar_url": "https://avatars.githubusercontent.com/u/64501125?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/kr15tyk",
#           "html_url": "https://github.com/kr15tyk",
#           "followers_url": "https://api.github.com/users/kr15tyk/followers",
#           "following_url": "https://api.github.com/users/kr15tyk/following{/other_user}",
#           "gists_url": "https://api.github.com/users/kr15tyk/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/kr15tyk/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/kr15tyk/subscriptions",
#           "organizations_url": "https://api.github.com/users/kr15tyk/orgs",
#           "repos_url": "https://api.github.com/users/kr15tyk/repos",
#           "events_url": "https://api.github.com/users/kr15tyk/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/kr15tyk/received_events",
#           "type": "User",
#           "site_admin": false
#         },
#         "labels": [
#           {
#             "id": 2983438667,
#             "node_id": "MDU6TGFiZWwyOTgzNDM4NjY3",
#             "url": "https://api.github.com/repos/ND-iTC/Documents/labels/SD",
#             "name": "SD",
#             "color": "E8B267",
#             "default": false,
#             "description": "Related to the Supporting Document"
#           },
#           {
#             "id": 3011213340,
#             "node_id": "MDU6TGFiZWwzMDExMjEzMzQw",
#             "url": "https://api.github.com/repos/ND-iTC/Documents/labels/correction",
#             "name": "correction",
#             "color": "FA208F",
#             "default": false,
#             "description": "Issues with the way in which something has been written"
#           },
#           {
#             "id": 4422712650,
#             "node_id": "LA_kwDOFEn3bs8AAAABB509Sg",
#             "url": "https://api.github.com/repos/ND-iTC/Documents/labels/Editorial",
#             "name": "Editorial",
#             "color": "750BB5",
#             "default": false,
#             "description": ""
#           },
#           {
#             "id": 4614238946,
#             "node_id": "LA_kwDOFEn3bs8AAAABEwey4g",
#             "url": "https://api.github.com/repos/ND-iTC/Documents/labels/v3.0",
#             "name": "v3.0",
#             "color": "D74988",
#             "default": false,
#             "description": "Issues related to the v3.0 draft"
#           }
#         ],
#         "state": "open",
#         "locked": false,
#         "assignee": null,
#         "assignees": [
#
#         ],
#         "milestone": null,
#         "comments": 0,
#         "created_at": "2022-12-02T14:49:08Z",
#         "updated_at": "2022-12-02T14:49:08Z",
#         "closed_at": null,
#         "author_association": "CONTRIBUTOR",
#         "active_lock_reason": null,
#         "body": "Section 4.2.1.1, FCS_DTLSC_EXT.1.4, TSS\r\nSince the SFR has a selection for whether the Supported Groups Extension is presented, The TSS EA is missing a conditional.\r\n\r\nSuggested change:\r\nAdd “If “present the Supported Groups Extension” is selected”",
#         "reactions": {
#           "url": "https://api.github.com/repos/ND-iTC/Documents/issues/175/reactions",
#           "total_count": 0,
#           "+1": 0,
#           "-1": 0,
#           "laugh": 0,
#           "hooray": 0,
#           "confused": 0,
#           "heart": 0,
#           "rocket": 0,
#           "eyes": 0
#         },
#         "timeline_url": "https://api.github.com/repos/ND-iTC/Documents/issues/175/timeline",
#         "performed_via_github_app": null,
#         "state_reason": null
#       }
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z",
#     "org": {
#       "id": 79233477,
#       "login": "ND-iTC",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/ND-iTC",
#       "avatar_url": "https://avatars.githubusercontent.com/u/79233477?"
#     }
#   },
#   {
#     "id": "25618713137",
#     "type": "PushEvent",
#     "actor": {
#       "id": 101288516,
#       "login": "VillainsRule4000",
#       "display_login": "VillainsRule4000",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/VillainsRule4000",
#       "avatar_url": "https://avatars.githubusercontent.com/u/101288516?"
#     },
#     "repo": {
#       "id": 521057387,
#       "name": "unblockrr/unblockrr.github.io",
#       "url": "https://api.github.com/repos/unblockrr/unblockrr.github.io"
#     },
#     "payload": {
#       "push_id": 11862047325,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "efb1ae2ea8f52de3b30b65156a40f1039a555315",
#       "before": "8ea6456cb1d18a658d762fa051b7a8c8f9a3e716",
#       "commits": [
#         {
#           "sha": "efb1ae2ea8f52de3b30b65156a40f1039a555315",
#           "author": {
#             "email": "101288516+VillainsRule4000@users.noreply.github.com",
#             "name": "VillainsRule"
#           },
#           "message": "v3 beta",
#           "distinct": true,
#           "url": "https://api.github.com/repos/unblockrr/unblockrr.github.io/commits/efb1ae2ea8f52de3b30b65156a40f1039a555315"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z",
#     "org": {
#       "id": 118207809,
#       "login": "unblockrr",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/unblockrr",
#       "avatar_url": "https://avatars.githubusercontent.com/u/118207809?"
#     }
#   },
#   {
#     "id": "25618713184",
#     "type": "PushEvent",
#     "actor": {
#       "id": 3771924,
#       "login": "austinkelleher",
#       "display_login": "austinkelleher",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/austinkelleher",
#       "avatar_url": "https://avatars.githubusercontent.com/u/3771924?"
#     },
#     "repo": {
#       "id": 252546704,
#       "name": "JupiterOne/sdk",
#       "url": "https://api.github.com/repos/JupiterOne/sdk"
#     },
#     "payload": {
#       "push_id": 11862047359,
#       "size": 4,
#       "distinct_size": 1,
#       "ref": "refs/heads/no-ticket-cleanups",
#       "head": "f0d8f2893319dfd3c05eca029215ca33de6b621d",
#       "before": "ecf9e05ed4635c79000603f61c1053d0070871c0",
#       "commits": [
#         {
#           "sha": "dd5ecf5e42eb80232334a22092b826b5921d36b6",
#           "author": {
#             "email": "austinlkelleher@gmail.com",
#             "name": "Austin Kelleher"
#           },
#           "message": "Prepare v8.29.3",
#           "distinct": false,
#           "url": "https://api.github.com/repos/JupiterOne/sdk/commits/dd5ecf5e42eb80232334a22092b826b5921d36b6"
#         },
#         {
#           "sha": "3f543bc2cb383dbde30898b926a80315e971b4e0",
#           "author": {
#             "email": "austinlkelleher@gmail.com",
#             "name": "Austin Kelleher"
#           },
#           "message": "Publish\n\n - @jupiterone/cli@8.29.3\n - @jupiterone/integration-sdk-benchmark@8.29.3\n - @jupiterone/integration-sdk-cli@8.29.3\n - @jupiterone/integration-sdk-core@8.29.3\n - @jupiterone/integration-sdk-dev-tools@8.29.3\n - @jupiterone/integration-sdk-http-client@8.29.3\n - @jupiterone/integration-sdk-private-test-utils@8.29.3\n - @jupiterone/integration-sdk-runtime@8.29.3\n - @jupiterone/integration-sdk-testing@8.29.3",
#           "distinct": false,
#           "url": "https://api.github.com/repos/JupiterOne/sdk/commits/3f543bc2cb383dbde30898b926a80315e971b4e0"
#         },
#         {
#           "sha": "1dd1aa68b625d6d761b8a86cc71006911b5db255",
#           "author": {
#             "email": "austinlkelleher@gmail.com",
#             "name": "Austin Kelleher"
#           },
#           "message": "Merge pull request #826 from JupiterOne/INT-6275-version\n\nv8.29.3",
#           "distinct": false,
#           "url": "https://api.github.com/repos/JupiterOne/sdk/commits/1dd1aa68b625d6d761b8a86cc71006911b5db255"
#         },
#         {
#           "sha": "f0d8f2893319dfd3c05eca029215ca33de6b621d",
#           "author": {
#             "email": "austinlkelleher@gmail.com",
#             "name": "Austin Kelleher"
#           },
#           "message": "NO-TICKET - Fix cache paths on Windows",
#           "distinct": true,
#           "url": "https://api.github.com/repos/JupiterOne/sdk/commits/f0d8f2893319dfd3c05eca029215ca33de6b621d"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z",
#     "org": {
#       "id": 44646512,
#       "login": "JupiterOne",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/JupiterOne",
#       "avatar_url": "https://avatars.githubusercontent.com/u/44646512?"
#     }
#   },
#   {
#     "id": "25618713152",
#     "type": "WatchEvent",
#     "actor": {
#       "id": 12649158,
#       "login": "DoomStorm",
#       "display_login": "DoomStorm",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/DoomStorm",
#       "avatar_url": "https://avatars.githubusercontent.com/u/12649158?"
#     },
#     "repo": {
#       "id": 242707350,
#       "name": "Proteus1989/Air-Explorer-Decrypter",
#       "url": "https://api.github.com/repos/Proteus1989/Air-Explorer-Decrypter"
#     },
#     "payload": {
#       "action": "started"
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   },
#   {
#     "id": "25618713134",
#     "type": "PushEvent",
#     "actor": {
#       "id": 50071847,
#       "login": "amymariparker",
#       "display_login": "amymariparker",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/amymariparker",
#       "avatar_url": "https://avatars.githubusercontent.com/u/50071847?"
#     },
#     "repo": {
#       "id": 341173075,
#       "name": "amymariparker/Fyhhy",
#       "url": "https://api.github.com/repos/amymariparker/Fyhhy"
#     },
#     "payload": {
#       "push_id": 11862047333,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/snyk-fix-94f8045b78962b01b429f50a28bb3242",
#       "head": "f673cada71dccfbdf0fe9b47e447a5a1875c68e0",
#       "before": "9e256896b26baf12c0cee5466e8ac215535d2d04",
#       "commits": [
#         {
#           "sha": "f673cada71dccfbdf0fe9b47e447a5a1875c68e0",
#           "author": {
#             "email": "snyk-bot@snyk.io",
#             "name": "snyk-bot"
#           },
#           "message": "fix: packages/components/package.json to reduce vulnerabilities\n\nThe following vulnerabilities are fixed with an upgrade:\n- https://snyk.io/vuln/SNYK-JS-DECODEURICOMPONENT-3149970",
#           "distinct": true,
#           "url": "https://api.github.com/repos/amymariparker/Fyhhy/commits/f673cada71dccfbdf0fe9b47e447a5a1875c68e0"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   },
#   {
#     "id": "25618713149",
#     "type": "PushEvent",
#     "actor": {
#       "id": 108341933,
#       "login": "jetano",
#       "display_login": "jetano",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/jetano",
#       "avatar_url": "https://avatars.githubusercontent.com/u/108341933?"
#     },
#     "repo": {
#       "id": 573463523,
#       "name": "jetano/TitanicEDA",
#       "url": "https://api.github.com/repos/jetano/TitanicEDA"
#     },
#     "payload": {
#       "push_id": 11862047335,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "2e66bf4982589fa2c06448f025ce91f66f860749",
#       "before": "be33eca7a84ced05d9de6b7191e51c9e25d57eff",
#       "commits": [
#         {
#           "sha": "2e66bf4982589fa2c06448f025ce91f66f860749",
#           "author": {
#             "email": "108341933+jetano@users.noreply.github.com",
#             "name": "Jetano"
#           },
#           "message": "changed ipnyb code",
#           "distinct": true,
#           "url": "https://api.github.com/repos/jetano/TitanicEDA/commits/2e66bf4982589fa2c06448f025ce91f66f860749"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   },
#   {
#     "id": "25618713140",
#     "type": "PullRequestEvent",
#     "actor": {
#       "id": 84948785,
#       "login": "guru-dev-cicd-canary-beta",
#       "display_login": "guru-dev-cicd-canary-beta",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/guru-dev-cicd-canary-beta",
#       "avatar_url": "https://avatars.githubusercontent.com/u/84948785?"
#     },
#     "repo": {
#       "id": 379001100,
#       "name": "GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod",
#       "url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod"
#     },
#     "payload": {
#       "action": "opened",
#       "number": 9916,
#       "pull_request": {
#         "url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/pulls/9916",
#         "id": 1143344109,
#         "node_id": "PR_kwDOFpcZDM5EJgvt",
#         "html_url": "https://github.com/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/pull/9916",
#         "diff_url": "https://github.com/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/pull/9916.diff",
#         "patch_url": "https://github.com/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/pull/9916.patch",
#         "issue_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/issues/9916",
#         "number": 9916,
#         "state": "open",
#         "locked": false,
#         "title": "Test pull request",
#         "user": {
#           "login": "guru-dev-cicd-canary-beta",
#           "id": 84948785,
#           "node_id": "MDQ6VXNlcjg0OTQ4Nzg1",
#           "avatar_url": "https://avatars.githubusercontent.com/u/84948785?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/guru-dev-cicd-canary-beta",
#           "html_url": "https://github.com/guru-dev-cicd-canary-beta",
#           "followers_url": "https://api.github.com/users/guru-dev-cicd-canary-beta/followers",
#           "following_url": "https://api.github.com/users/guru-dev-cicd-canary-beta/following{/other_user}",
#           "gists_url": "https://api.github.com/users/guru-dev-cicd-canary-beta/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/guru-dev-cicd-canary-beta/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/guru-dev-cicd-canary-beta/subscriptions",
#           "organizations_url": "https://api.github.com/users/guru-dev-cicd-canary-beta/orgs",
#           "repos_url": "https://api.github.com/users/guru-dev-cicd-canary-beta/repos",
#           "events_url": "https://api.github.com/users/guru-dev-cicd-canary-beta/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/guru-dev-cicd-canary-beta/received_events",
#           "type": "User",
#           "site_admin": false
#         },
#         "body": "Test pull request",
#         "created_at": "2022-12-02T14:49:07Z",
#         "updated_at": "2022-12-02T14:49:07Z",
#         "closed_at": null,
#         "merged_at": null,
#         "merge_commit_sha": null,
#         "assignee": null,
#         "assignees": [
#
#         ],
#         "requested_reviewers": [
#
#         ],
#         "requested_teams": [
#
#         ],
#         "labels": [
#
#         ],
#         "milestone": null,
#         "draft": false,
#         "commits_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/pulls/9916/commits",
#         "review_comments_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/pulls/9916/comments",
#         "review_comment_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/pulls/comments{/number}",
#         "comments_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/issues/9916/comments",
#         "statuses_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/statuses/59a7729852d19439a6472503c53fac54ac08c4fe",
#         "head": {
#           "label": "GuruCICDCanary-Prod-Release:BughuntCICDCanarySource-prod-us-east-1-1669990620798",
#           "ref": "BughuntCICDCanarySource-prod-us-east-1-1669990620798",
#           "sha": "59a7729852d19439a6472503c53fac54ac08c4fe",
#           "user": {
#             "login": "GuruCICDCanary-Prod-Release",
#             "id": 85661847,
#             "node_id": "MDEyOk9yZ2FuaXphdGlvbjg1NjYxODQ3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/85661847?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/GuruCICDCanary-Prod-Release",
#             "html_url": "https://github.com/GuruCICDCanary-Prod-Release",
#             "followers_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/followers",
#             "following_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/following{/other_user}",
#             "gists_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/subscriptions",
#             "organizations_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/orgs",
#             "repos_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/repos",
#             "events_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/received_events",
#             "type": "Organization",
#             "site_admin": false
#           },
#           "repo": {
#             "id": 379001100,
#             "node_id": "MDEwOlJlcG9zaXRvcnkzNzkwMDExMDA=",
#             "name": "BugBustCICDCanary-prod",
#             "full_name": "GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod",
#             "private": false,
#             "owner": {
#               "login": "GuruCICDCanary-Prod-Release",
#               "id": 85661847,
#               "node_id": "MDEyOk9yZ2FuaXphdGlvbjg1NjYxODQ3",
#               "avatar_url": "https://avatars.githubusercontent.com/u/85661847?v=4",
#               "gravatar_id": "",
#               "url": "https://api.github.com/users/GuruCICDCanary-Prod-Release",
#               "html_url": "https://github.com/GuruCICDCanary-Prod-Release",
#               "followers_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/followers",
#               "following_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/following{/other_user}",
#               "gists_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/gists{/gist_id}",
#               "starred_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/subscriptions",
#               "organizations_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/orgs",
#               "repos_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/repos",
#               "events_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/events{/privacy}",
#               "received_events_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/received_events",
#               "type": "Organization",
#               "site_admin": false
#             },
#             "html_url": "https://github.com/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod",
#             "description": "Used for Bughunt CICD canary tests in prod.",
#             "fork": false,
#             "url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod",
#             "forks_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/forks",
#             "keys_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/keys{/key_id}",
#             "collaborators_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/collaborators{/collaborator}",
#             "teams_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/teams",
#             "hooks_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/hooks",
#             "issue_events_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/issues/events{/number}",
#             "events_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/events",
#             "assignees_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/assignees{/user}",
#             "branches_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/branches{/branch}",
#             "tags_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/tags",
#             "blobs_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/git/blobs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/git/tags{/sha}",
#             "git_refs_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/git/refs{/sha}",
#             "trees_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/git/trees{/sha}",
#             "statuses_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/statuses/{sha}",
#             "languages_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/languages",
#             "stargazers_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/stargazers",
#             "contributors_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/contributors",
#             "subscribers_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/subscribers",
#             "subscription_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/subscription",
#             "commits_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/commits{/sha}",
#             "git_commits_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/git/commits{/sha}",
#             "comments_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/comments{/number}",
#             "issue_comment_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/issues/comments{/number}",
#             "contents_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/contents/{+path}",
#             "compare_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/compare/{base}...{head}",
#             "merges_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/merges",
#             "archive_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/{archive_format}{/ref}",
#             "downloads_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/downloads",
#             "issues_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/issues{/number}",
#             "pulls_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/pulls{/number}",
#             "milestones_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/milestones{/number}",
#             "notifications_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/notifications{?since,all,participating}",
#             "labels_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/labels{/name}",
#             "releases_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/releases{/id}",
#             "deployments_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/deployments",
#             "created_at": "2021-06-21T16:50:05Z",
#             "updated_at": "2022-11-28T05:21:07Z",
#             "pushed_at": "2022-12-02T14:49:08Z",
#             "git_url": "git://github.com/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod.git",
#             "ssh_url": "git@github.com:GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod.git",
#             "clone_url": "https://github.com/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod.git",
#             "svn_url": "https://github.com/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod",
#             "homepage": null,
#             "size": 18,
#             "stargazers_count": 1,
#             "watchers_count": 1,
#             "language": "Java",
#             "has_issues": true,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": true,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 0,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 1,
#             "license": null,
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [
#
#             ],
#             "visibility": "public",
#             "forks": 0,
#             "open_issues": 1,
#             "watchers": 1,
#             "default_branch": "main"
#           }
#         },
#         "base": {
#           "label": "GuruCICDCanary-Prod-Release:BughuntCICDCanaryDestination-prod-us-east-1-1669990620798",
#           "ref": "BughuntCICDCanaryDestination-prod-us-east-1-1669990620798",
#           "sha": "3b0025ed7e448038eb643b320c42b9fd2105cfda",
#           "user": {
#             "login": "GuruCICDCanary-Prod-Release",
#             "id": 85661847,
#             "node_id": "MDEyOk9yZ2FuaXphdGlvbjg1NjYxODQ3",
#             "avatar_url": "https://avatars.githubusercontent.com/u/85661847?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/GuruCICDCanary-Prod-Release",
#             "html_url": "https://github.com/GuruCICDCanary-Prod-Release",
#             "followers_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/followers",
#             "following_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/following{/other_user}",
#             "gists_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/subscriptions",
#             "organizations_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/orgs",
#             "repos_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/repos",
#             "events_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/received_events",
#             "type": "Organization",
#             "site_admin": false
#           },
#           "repo": {
#             "id": 379001100,
#             "node_id": "MDEwOlJlcG9zaXRvcnkzNzkwMDExMDA=",
#             "name": "BugBustCICDCanary-prod",
#             "full_name": "GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod",
#             "private": false,
#             "owner": {
#               "login": "GuruCICDCanary-Prod-Release",
#               "id": 85661847,
#               "node_id": "MDEyOk9yZ2FuaXphdGlvbjg1NjYxODQ3",
#               "avatar_url": "https://avatars.githubusercontent.com/u/85661847?v=4",
#               "gravatar_id": "",
#               "url": "https://api.github.com/users/GuruCICDCanary-Prod-Release",
#               "html_url": "https://github.com/GuruCICDCanary-Prod-Release",
#               "followers_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/followers",
#               "following_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/following{/other_user}",
#               "gists_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/gists{/gist_id}",
#               "starred_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/subscriptions",
#               "organizations_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/orgs",
#               "repos_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/repos",
#               "events_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/events{/privacy}",
#               "received_events_url": "https://api.github.com/users/GuruCICDCanary-Prod-Release/received_events",
#               "type": "Organization",
#               "site_admin": false
#             },
#             "html_url": "https://github.com/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod",
#             "description": "Used for Bughunt CICD canary tests in prod.",
#             "fork": false,
#             "url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod",
#             "forks_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/forks",
#             "keys_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/keys{/key_id}",
#             "collaborators_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/collaborators{/collaborator}",
#             "teams_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/teams",
#             "hooks_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/hooks",
#             "issue_events_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/issues/events{/number}",
#             "events_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/events",
#             "assignees_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/assignees{/user}",
#             "branches_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/branches{/branch}",
#             "tags_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/tags",
#             "blobs_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/git/blobs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/git/tags{/sha}",
#             "git_refs_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/git/refs{/sha}",
#             "trees_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/git/trees{/sha}",
#             "statuses_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/statuses/{sha}",
#             "languages_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/languages",
#             "stargazers_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/stargazers",
#             "contributors_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/contributors",
#             "subscribers_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/subscribers",
#             "subscription_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/subscription",
#             "commits_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/commits{/sha}",
#             "git_commits_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/git/commits{/sha}",
#             "comments_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/comments{/number}",
#             "issue_comment_url": "https://api.github.com/repos/GuruCICDCanary-Prod-Release/BugBustCICDCanary-prod/issues/comments{/number}",
# ...
#             "language": "Jupyter Notebook",
#             "has_issues": true,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": true,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 0,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 1,
#             "license": null,
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [
#
#             ],
#             "visibility": "public",
#             "forks": 0,
#             "open_issues": 1,
#             "watchers": 0,
#             "default_branch": "main"
#           }
#         },
#         "_links": {
#           "self": {
#             "href": "https://api.github.com/repos/Sailing-Ranking/number-ocr-machine-learning/pulls/6"
#           },
#           "html": {
#             "href": "https://github.com/Sailing-Ranking/number-ocr-machine-learning/pull/6"
#           },
#           "issue": {
#             "href": "https://api.github.com/repos/Sailing-Ranking/number-ocr-machine-learning/issues/6"
#           },
#           "comments": {
#             "href": "https://api.github.com/repos/Sailing-Ranking/number-ocr-machine-learning/issues/6/comments"
#           },
#           "review_comments": {
#             "href": "https://api.github.com/repos/Sailing-Ranking/number-ocr-machine-learning/pulls/6/comments"
#           },
#           "review_comment": {
#             "href": "https://api.github.com/repos/Sailing-Ranking/number-ocr-machine-learning/pulls/comments{/number}"
#           },
#           "commits": {
#             "href": "https://api.github.com/repos/Sailing-Ranking/number-ocr-machine-learning/pulls/6/commits"
#           },
#           "statuses": {
#             "href": "https://api.github.com/repos/Sailing-Ranking/number-ocr-machine-learning/statuses/6907a52994bc6315e1c1c503b1c4cdfde59d1b72"
#           }
#         },
#         "author_association": "CONTRIBUTOR",
#         "auto_merge": null,
#         "active_lock_reason": null,
#         "merged": true,
#         "mergeable": null,
#         "rebaseable": null,
#         "mergeable_state": "unknown",
#         "merged_by": {
#           "login": "michael-gvdw",
#           "id": 80892812,
#           "node_id": "MDQ6VXNlcjgwODkyODEy",
#           "avatar_url": "https://avatars.githubusercontent.com/u/80892812?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/michael-gvdw",
#           "html_url": "https://github.com/michael-gvdw",
#           "followers_url": "https://api.github.com/users/michael-gvdw/followers",
#           "following_url": "https://api.github.com/users/michael-gvdw/following{/other_user}",
#           "gists_url": "https://api.github.com/users/michael-gvdw/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/michael-gvdw/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/michael-gvdw/subscriptions",
#           "organizations_url": "https://api.github.com/users/michael-gvdw/orgs",
#           "repos_url": "https://api.github.com/users/michael-gvdw/repos",
#           "events_url": "https://api.github.com/users/michael-gvdw/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/michael-gvdw/received_events",
#           "type": "User",
#           "site_admin": false
#         },
#         "comments": 0,
#         "review_comments": 0,
#         "maintainer_can_modify": false,
#         "commits": 3,
#         "additions": 2,
#         "deletions": 5,
#         "changed_files": 3
#       }
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z",
#     "org": {
#       "id": 115995879,
#       "login": "Sailing-Ranking",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/Sailing-Ranking",
#       "avatar_url": "https://avatars.githubusercontent.com/u/115995879?"
#     }
#   },
#   {
#     "id": "25618713092",
#     "type": "PushEvent",
#     "actor": {
#       "id": 62675494,
#       "login": "benjamin32561",
#       "display_login": "benjamin32561",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/benjamin32561",
#       "avatar_url": "https://avatars.githubusercontent.com/u/62675494?"
#     },
#     "repo": {
#       "id": 535727114,
#       "name": "benjamin32561/TAU-F1-Object-Detection",
#       "url": "https://api.github.com/repos/benjamin32561/TAU-F1-Object-Detection"
#     },
#     "payload": {
#       "push_id": 11862047308,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/Camera",
#       "head": "d6679a7c84864030ece66c7465cf2c4f62039aa3",
#       "before": "e8e99fe0fb4ff3946a67c6540728f26150d5e950",
#       "commits": [
#         {
#           "sha": "d6679a7c84864030ece66c7465cf2c4f62039aa3",
#           "author": {
#             "email": "ben32561@gmail.com",
#             "name": "benjamin32561"
#           },
#           "message": "now commiting wandb data",
#           "distinct": true,
#           "url": "https://api.github.com/repos/benjamin32561/TAU-F1-Object-Detection/commits/d6679a7c84864030ece66c7465cf2c4f62039aa3"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   },
#   {
#     "id": "25618713097",
#     "type": "IssueCommentEvent",
#     "actor": {
#       "id": 35613825,
#       "login": "vercel[bot]",
#       "display_login": "vercel",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/vercel[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/35613825?"
#     },
#     "repo": {
#       "id": 351984728,
#       "name": "inabagumi/nerutube",
#       "url": "https://api.github.com/repos/inabagumi/nerutube"
#     },
#     "payload": {
#       "action": "created",
#       "issue": {
#         "url": "https://api.github.com/repos/inabagumi/nerutube/issues/505",
#         "repository_url": "https://api.github.com/repos/inabagumi/nerutube",
#         "labels_url": "https://api.github.com/repos/inabagumi/nerutube/issues/505/labels{/name}",
#         "comments_url": "https://api.github.com/repos/inabagumi/nerutube/issues/505/comments",
#         "events_url": "https://api.github.com/repos/inabagumi/nerutube/issues/505/events",
#         "html_url": "https://github.com/inabagumi/nerutube/pull/505",
#         "id": 1472984414,
#         "node_id": "PR_kwDOFPrcWM5EJgGn",
#         "number": 505,
#         "title": "build(deps): update dependency @types/react to ^18.0.26",
#         "user": {
#           "login": "renovate[bot]",
#           "id": 29139614,
#           "node_id": "MDM6Qm90MjkxMzk2MTQ=",
#           "avatar_url": "https://avatars.githubusercontent.com/in/2740?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/renovate%5Bbot%5D",
#           "html_url": "https://github.com/apps/renovate",
#           "followers_url": "https://api.github.com/users/renovate%5Bbot%5D/followers",
#           "following_url": "https://api.github.com/users/renovate%5Bbot%5D/following{/other_user}",
#           "gists_url": "https://api.github.com/users/renovate%5Bbot%5D/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/renovate%5Bbot%5D/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/renovate%5Bbot%5D/subscriptions",
#           "organizations_url": "https://api.github.com/users/renovate%5Bbot%5D/orgs",
#           "repos_url": "https://api.github.com/users/renovate%5Bbot%5D/repos",
#           "events_url": "https://api.github.com/users/renovate%5Bbot%5D/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/renovate%5Bbot%5D/received_events",
#           "type": "Bot",
#           "site_admin": false
#         },
#         "labels": [
#           {
#             "id": 2860209806,
#             "node_id": "MDU6TGFiZWwyODYwMjA5ODA2",
#             "url": "https://api.github.com/repos/inabagumi/nerutube/labels/dependencies",
#             "name": "dependencies",
#             "color": "0366d6",
#             "default": false,
#             "description": "Pull requests that update a dependency file"
#           }
#         ],
#         "state": "open",
#         "locked": false,
#         "assignee": null,
#         "assignees": [
#
#         ],
#         "milestone": null,
#         "comments": 0,
#         "created_at": "2022-12-02T14:47:44Z",
#         "updated_at": "2022-12-02T14:49:08Z",
#         "closed_at": null,
#         "author_association": "CONTRIBUTOR",
#         "active_lock_reason": null,
#         "draft": false,
#         "pull_request": {
#           "url": "https://api.github.com/repos/inabagumi/nerutube/pulls/505",
#           "html_url": "https://github.com/inabagumi/nerutube/pull/505",
#           "diff_url": "https://github.com/inabagumi/nerutube/pull/505.diff",
#           "patch_url": "https://github.com/inabagumi/nerutube/pull/505.patch",
#           "merged_at": null
#         },
#         "body": "[![Mend Renovate](https://app.renovatebot.com/images/banner.svg)](https://renovatebot.com)\n\nThis PR contains the following updates:\n\n| Package | Change | Age | Adoption | Passing | Confidence |\n|---|---|---|---|---|---|\n| [@types/react](https://togithub.com/DefinitelyTyped/DefinitelyTyped/tree/master/types/react) ([source](https://togithub.com/DefinitelyTyped/DefinitelyTyped)) | [`^18.0.25` -> `^18.0.26`](https://renovatebot.com/diffs/npm/@types%2freact/18.0.25/18.0.26) | [![age](https://badges.renovateapi.com/packages/npm/@types%2freact/18.0.26/age-slim)](https://docs.renovatebot.com/merge-confidence/) | [![adoption](https://badges.renovateapi.com/packages/npm/@types%2freact/18.0.26/adoption-slim)](https://docs.renovatebot.com/merge-confidence/) | [![passing](https://badges.renovateapi.com/packages/npm/@types%2freact/18.0.26/compatibility-slim/18.0.25)](https://docs.renovatebot.com/merge-confidence/) | [![confidence](https://badges.renovateapi.com/packages/npm/@types%2freact/18.0.26/confidence-slim/18.0.25)](https://docs.renovatebot.com/merge-confidence/) |\n\n---\n\n### Configuration\n\n📅 **Schedule**: Branch creation - At any time (no schedule defined), Automerge - At any time (no schedule defined).\n\n🚦 **Automerge**: Enabled.\n\n♻ **Rebasing**: Whenever PR becomes conflicted, or you tick the rebase/retry checkbox.\n\n🔕 **Ignore**: Close this PR and you won't be reminded about this update again.\n\n---\n\n - [ ] <!-- rebase-check -->If you want to rebase/retry this PR, check this box\n\n---\n\nThis PR has been generated by [Mend Renovate](https://www.mend.io/free-developer-tools/renovate/). View repository job log [here](https://app.renovatebot.com/dashboard#github/inabagumi/nerutube).\n<!--renovate-debug:eyJjcmVhdGVkSW5WZXIiOiIzNC40NC4wIiwidXBkYXRlZEluVmVyIjoiMzQuNDQuMCJ9-->\n",
#         "reactions": {
#           "url": "https://api.github.com/repos/inabagumi/nerutube/issues/505/reactions",
#           "total_count": 0,
#           "+1": 0,
#           "-1": 0,
#           "laugh": 0,
#           "hooray": 0,
#           "confused": 0,
#           "heart": 0,
#           "rocket": 0,
#           "eyes": 0
#         },
#         "timeline_url": "https://api.github.com/repos/inabagumi/nerutube/issues/505/timeline",
#         "performed_via_github_app": null,
#         "state_reason": null
#       },
#       "comment": {
#         "url": "https://api.github.com/repos/inabagumi/nerutube/issues/comments/1335353752",
#         "html_url": "https://github.com/inabagumi/nerutube/pull/505#issuecomment-1335353752",
#         "issue_url": "https://api.github.com/repos/inabagumi/nerutube/issues/505",
#         "id": 1335353752,
#         "node_id": "IC_kwDOFPrcWM5Pl-GY",
#         "user": {
#           "login": "vercel[bot]",
#           "id": 35613825,
#           "node_id": "MDM6Qm90MzU2MTM4MjU=",
#           "avatar_url": "https://avatars.githubusercontent.com/in/8329?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/vercel%5Bbot%5D",
#           "html_url": "https://github.com/apps/vercel",
#           "followers_url": "https://api.github.com/users/vercel%5Bbot%5D/followers",
#           "following_url": "https://api.github.com/users/vercel%5Bbot%5D/following{/other_user}",
#           "gists_url": "https://api.github.com/users/vercel%5Bbot%5D/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/vercel%5Bbot%5D/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/vercel%5Bbot%5D/subscriptions",
#           "organizations_url": "https://api.github.com/users/vercel%5Bbot%5D/orgs",
#           "repos_url": "https://api.github.com/users/vercel%5Bbot%5D/repos",
#           "events_url": "https://api.github.com/users/vercel%5Bbot%5D/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/vercel%5Bbot%5D/received_events",
#           "type": "Bot",
#           "site_admin": false
#         },
#         "created_at": "2022-12-02T14:49:08Z",
#         "updated_at": "2022-12-02T14:49:08Z",
#         "author_association": "NONE",
#         "body": "**The latest updates on your projects**. Learn more about [Vercel for Git ↗︎](https://vercel.link/github-learn-more)\n\n| Name | Status | Preview | Updated |\n| :--- | :----- | :------ | :------ |\n| **nerutube** | ✅ Ready ([Inspect](https://vercel.com/inabagumi/nerutube/2kp2Ya4ogFunZvs1DNWwPxsEw262)) | [Visit Preview](https://nerutube-git-renovate-react-18x-inabagumi.vercel.app) | Dec 2, 2022 at 2:49PM (UTC) |\n\n",
#         "reactions": {
#           "url": "https://api.github.com/repos/inabagumi/nerutube/issues/comments/1335353752/reactions",
#           "total_count": 0,
#           "+1": 0,
#           "-1": 0,
#           "laugh": 0,
#           "hooray": 0,
#           "confused": 0,
#           "heart": 0,
#           "rocket": 0,
#           "eyes": 0
#         },
#         "performed_via_github_app": null
#       }
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z",
#     "org": {
#       "id": 42648621,
#       "login": "inabagumi",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/inabagumi",
#       "avatar_url": "https://avatars.githubusercontent.com/u/42648621?"
#     }
#   },
#   {
#     "id": "25618713130",
#     "type": "CreateEvent",
#     "actor": {
#       "id": 105529907,
#       "login": "AlandaFaustino",
#       "display_login": "AlandaFaustino",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/AlandaFaustino",
#       "avatar_url": "https://avatars.githubusercontent.com/u/105529907?"
#     },
#     "repo": {
#       "id": 573473106,
#       "name": "AlandaFaustino/Desenvolvimento-Web-Site",
#       "url": "https://api.github.com/repos/AlandaFaustino/Desenvolvimento-Web-Site"
#     },
#     "payload": {
#       "ref": "main",
#       "ref_type": "branch",
#       "master_branch": "main",
#       "description": null,
#       "pusher_type": "user"
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   },
#   {
#     "id": "25618713049",
#     "type": "PushEvent",
#     "actor": {
#       "id": 91325016,
#       "login": "FevenSeyfu",
#       "display_login": "FevenSeyfu",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/FevenSeyfu",
#       "avatar_url": "https://avatars.githubusercontent.com/u/91325016?"
#     },
#     "repo": {
#       "id": 572673967,
#       "name": "FevenSeyfu/portfolio-v1",
#       "url": "https://api.github.com/repos/FevenSeyfu/portfolio-v1"
#     },
#     "payload": {
#       "push_id": 11862047306,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/styled_header",
#       "head": "82dff3618f4f958f018a90be945e138fa374b091",
#       "before": "5c1687459ffea708e3bfe229a1782218f0fa13f0",
#       "commits": [
#         {
#           "sha": "82dff3618f4f958f018a90be945e138fa374b091",
#           "author": {
#             "email": "fevenseyfu00@gmail.com",
#             "name": "Feven Seyfu"
#           },
#           "message": "Update .stylelintrc.json\n\nRemoved typo error that was created while solving merge conflict",
#           "distinct": true,
#           "url": "https://api.github.com/repos/FevenSeyfu/portfolio-v1/commits/82dff3618f4f958f018a90be945e138fa374b091"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-02T14:49:08Z"
#   }
# ]

# %% [markdown]
# OSS Insight 已经收集了超过 53 亿条公开事件数据，你可以通过访问 API 或在网站上查看当前收集的事件总数：

# %%
# !curl -s https://api.ossinsight.io/q/events-total | jq -r ".data[0]"
# Out:
# {
#   "cnt": 5322990364,
#   "latest_created_at": "2022-12-02T14:53:58.000Z",
#   "latest_timestamp": 1669992838
# }

# %% [markdown]
# #### 导入实时数据
#
# 通过 [GitHub 的 API 文档](https://docs.github.com/en/rest/activity/events), 我们知道可以通过请求 `/events` API 来获取准实时的 events 数据。你可以执行下面的命令查看这个接口返回数据的结构：

# %%
# !docker-compose pull
# !docker-compose up -d etl

# %% [markdown]
# #### 导入历史数据
#
# 由于通过 `/events` API 我们无法完全获取到所有的历史数据, 在 OSS Insight 的数据准备阶段，我们利用了 [GH Archive](https://gharchive.org) 上归档数据，将其导入数据库当中.
#
# | Query | Downloadable Files |
# | ---- | ---- |
# | Activity for 1/1/2015 @ 3PM UTC |	`https://data.gharchive.org/2015-01-01-15.json.gz` |
# | Activity for 1/1/2015 | `https://data.gharchive.org/2015-01-01-{0..23}.json.gz` |
# | Activity for all of January 2015 | `https://data.gharchive.org/2015-01-{01..31}-{0..23}.json.gz` |
#
# 为了方便演示我们在 AWS S3 上保存了一份示例数据，你可以使用 TiDB Cloud 的 Import 功能将其导入数据库当中：
#
# S3 URI:
#
# ```
# s3://ossinsight/workshop/oss_database_sample/
# ```
#
# Role ARN:
#
# ```
# arn:aws:iam::494090988690:role/tidb-cloud-reader
# ```

# %% [markdown]
# ## 一些背景知识

# %% [markdown]
# #### 优化器
#
# SQL 是一种声明式语言，而非过程性的语言。也就是说，它描述的是最终结果应该如何，而非按顺序执行的步骤。因此在 TiDB 在处理 SQL 语句的过程中，除了要确保能够正确返回语句所描述的最终结果，还要确定 SQL 语句的执行过程，并且尽可能的对 SQL 语句进行性能优化，从而得到最佳的执行计划。
#
# SQL 性能优化的过程，可以理解为 GPS 导航的过程。你提供地址后，GPS 软件利用各种统计信息（例如以前的行程、速度限制等元数据，以及实时交通信息）规划出一条最省时的路线。这与 TiDB 中的 SQL 性能优化过程相对应。
#
# 我们通常会把负责这部分 SQL 优化工作的组件成为**优化器（Optimizer）**。
#
# 如下图所示，一条 SQL 语句在经过语法解析和校验之后，经过优化器的逻辑优化和物理优化来制定最终的执行计划，交给执行器（Executor）去执行。和 GPS 软件一样，优化器在进行执行计划规划的时候也会利用到一些统计信息来进行评估。
#
# <center>
#   <img width="640" alt="The Cluster Modify Menu" src="https://user-images.githubusercontent.com/85985765/205136445-3d9dd676-56bc-4f75-bf6d-cdb1af8c1b79.png">
#   <p><i>SQL 优化流程图</i></p>
# </center>
#
# 上图其实是一个简化的示意图，因为它只描述了以 TiKV 为存储引擎的情况。但是在 TiDB 支持 HTAP 能力后，引进了负责分析负载的 TiFlash 存储引擎。这给优化器带来了新的挑战，优化器需要在制定执行计划和进行物理
# 优化时需要考虑：
#
# > 这条 SQL 应该使用哪个存储引擎执行性能会更好，选 TiKV 还是 TiFlash？

# %% [markdown]
# #### Optimizer Hints
#
# > 如果优化器难以抉择，那我们不妨给它一点提示，告诉它我们希望使用哪种存储引擎执行?
#
# TiDB 的优化器提供了 `READ_FROM_STORAGE` Hint 来允许开发者在 SQL 语句级别来控制哪一张表应该使用哪个执行引擎去执行。例如，下在面这条 SQL 语句当中，TiDB 从 TiFlash 上读取 t1 表的数据，在 TiKV 上读取 t2 的数据。
#
# ```sql
# SELECT /*+ READ_FROM_STORAGE(TIFLASH[t1], TIKV[t2]) */ t1.a FROM t t1, t t2 WHERE t1.a = t2.a;
# ```

# %% [markdown]
# #### 代价模型
#
# > 使用 Optimizer Hints 很简单，但是有没有更智能的方法，特别是在做临时查询时，优化器能否智能的选择应该使用哪种引擎查询效率最高？
#
# <center>
#   <img width="640" alt="物理优化中的代码模型" src="https://user-images.githubusercontent.com/85985765/205192450-c23f2199-1ab1-41d2-90f3-c17c5d6e252e.png">
#   <p><i>SQL 优化流程图</i></p>
# </center>
#
# TiDB v6.2.0 引入了新的代价模型 Cost Model Version 2。
#
# Cost Model Version 2 对代价公式进行了更精确的回归校准，调整了部分代价公式，比此前版本的代价公式更加准确。
#
# OSS Insight 使用了该版本的 Cost Model, 但是因为目前 Cost Model Version 2 还处于实验阶段，需要通过执行以下 SQL 语句进行启用：

# %%
set global tidb_enable_new_cost_interface = 'ON';
set global tidb_cost_model_version = 2;

# %% [markdown]
# 在后续版本当中，Cost Model Version 2 会替代掉原有的 Cost Model 作为默认的代码模型。

# %% [markdown]
# ## Demo SQL
#
# 下面，我们会以 OSS Insight 为示例，讲解如何使用 TiDB 进行数据分析以及在数据分析时如何更好的通过优化器来发挥行存 TiKV 和列存 TiFlash 各自的优势。

# %% [markdown]
# #### 定义 Query 工具函数
#
# 首先，请执行下面的 Python 代码，初始化一个 query 函数用于后续的 SQL 查询：

# %%
import mysql.connector as connection
import pandas as pd

db_host = os.getenv('DB_ENDPOINT')
db_port = os.getenv("DB_PORT")
db_username = os.getenv('DB_USERNAME')
db_password = os.getenv('DB_PASSWORD')
db_name = os.getenv('DB_NAME')

mydb = connection.connect(
  host=db_host,
  port=db_port,
  user=db_username,
  password=db_password,
  database=db_name
)

def execute(sql):
  try:
    df = pd.read_sql(sql, mydb)
    return df.style.set_properties(**{'text-align': 'left'})
  except Exception as e:
    print(str(e))

def query(sql):
  try:

    df = pd.read_sql(sql, mydb)
    return df.style.set_properties(**{'text-align': 'left'})
  except Exception as e:
    print(str(e))

# %% [markdown]
# #### Example 1

# %% [markdown]
# 熟悉 TiDB 的用户可能会知道，在 TiDB 的版本规则里会存在两种版本：
#
# - 一种是为了能够更快交付迭代而设计的开发里程碑版本 (Development Milestone Releases, DMR)
# - 另外一种是提供长期技术支持的长期支持版本 (Long-Term Support Releases, LTS)
#
# 在 LTS 生命周期内会按需发布补丁版本 (Patch Release)。如果一个修复 BUG 的 Pull Request 会被 Cherry-Pick 到受影响的 LTS 分支进行修复，这部分工作会由机器人根据研发和 QA 团队确定的受影响版本列表进行自动的 Cherry—Pick，所以你会在 TiDB 的代码仓库当中看见不少由机器人发起的 Pull Request。
#
# > 🤔 那么，TiDB 的社区机器人（`ti-chi-bot`）一共创建了多少个 Pull Request 呢？
#
# 我们可以通过下面的 SQL 语句进行查询：

# %%
query("""
SELECT repo_name, COUNT(1) AS prs
FROM github_events
WHERE
    type = 'PullRequestEvent'
    AND action = 'opened'
    AND actor_login = 'ti-chi-bot'
GROUP BY repo_name
""")
# Out:
# <style type="text/css">
# #T_c6e6d_row0_col0, #T_c6e6d_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_c6e6d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >repo_name</th>
#       <th class="col_heading level0 col1" >prs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6e6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6e6d_row0_col0" class="data row0 col0" >pingcap/tidb</td>
#       <td id="T_c6e6d_row0_col1" class="data row0 col1" >138</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 通过 `EXPLAIN ANALYZE` 查看上面 SQL 语句的执行计划：

# %%
query("""
EXPLAIN ANALYZE SELECT repo_name, COUNT(1) AS prs
FROM github_events
WHERE
    type = 'PullRequestEvent'
    AND action = 'opened'
    AND actor_login = 'ti-chi-bot'
GROUP BY repo_name
""")
# Out:
# <style type="text/css">
# #T_0a5ce_row0_col0, #T_0a5ce_row0_col1, #T_0a5ce_row0_col2, #T_0a5ce_row0_col3, #T_0a5ce_row0_col4, #T_0a5ce_row0_col5, #T_0a5ce_row0_col6, #T_0a5ce_row0_col7, #T_0a5ce_row0_col8, #T_0a5ce_row1_col0, #T_0a5ce_row1_col1, #T_0a5ce_row1_col2, #T_0a5ce_row1_col3, #T_0a5ce_row1_col4, #T_0a5ce_row1_col5, #T_0a5ce_row1_col6, #T_0a5ce_row1_col7, #T_0a5ce_row1_col8, #T_0a5ce_row2_col0, #T_0a5ce_row2_col1, #T_0a5ce_row2_col2, #T_0a5ce_row2_col3, #T_0a5ce_row2_col4, #T_0a5ce_row2_col5, #T_0a5ce_row2_col6, #T_0a5ce_row2_col7, #T_0a5ce_row2_col8, #T_0a5ce_row3_col0, #T_0a5ce_row3_col1, #T_0a5ce_row3_col2, #T_0a5ce_row3_col3, #T_0a5ce_row3_col4, #T_0a5ce_row3_col5, #T_0a5ce_row3_col6, #T_0a5ce_row3_col7, #T_0a5ce_row3_col8, #T_0a5ce_row4_col0, #T_0a5ce_row4_col1, #T_0a5ce_row4_col2, #T_0a5ce_row4_col3, #T_0a5ce_row4_col4, #T_0a5ce_row4_col5, #T_0a5ce_row4_col6, #T_0a5ce_row4_col7, #T_0a5ce_row4_col8, #T_0a5ce_row5_col0, #T_0a5ce_row5_col1, #T_0a5ce_row5_col2, #T_0a5ce_row5_col3, #T_0a5ce_row5_col4, #T_0a5ce_row5_col5, #T_0a5ce_row5_col6, #T_0a5ce_row5_col7, #T_0a5ce_row5_col8, #T_0a5ce_row6_col0, #T_0a5ce_row6_col1, #T_0a5ce_row6_col2, #T_0a5ce_row6_col3, #T_0a5ce_row6_col4, #T_0a5ce_row6_col5, #T_0a5ce_row6_col6, #T_0a5ce_row6_col7, #T_0a5ce_row6_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_0a5ce_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >estRows</th>
#       <th class="col_heading level0 col2" >actRows</th>
#       <th class="col_heading level0 col3" >task</th>
#       <th class="col_heading level0 col4" >access object</th>
#       <th class="col_heading level0 col5" >execution info</th>
#       <th class="col_heading level0 col6" >operator info</th>
#       <th class="col_heading level0 col7" >memory</th>
#       <th class="col_heading level0 col8" >disk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a5ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a5ce_row0_col0" class="data row0 col0" >Projection_5</td>
#       <td id="T_0a5ce_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_0a5ce_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_0a5ce_row0_col3" class="data row0 col3" >root</td>
#       <td id="T_0a5ce_row0_col4" class="data row0 col4" ></td>
#       <td id="T_0a5ce_row0_col5" class="data row0 col5" >time:16.9ms, loops:2, Concurrency:OFF</td>
#       <td id="T_0a5ce_row0_col6" class="data row0 col6" >ossinsight.github_events.repo_name, Column#34</td>
#       <td id="T_0a5ce_row0_col7" class="data row0 col7" >1016 Bytes</td>
#       <td id="T_0a5ce_row0_col8" class="data row0 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_0a5ce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0a5ce_row1_col0" class="data row1 col0" >└─HashAgg_20</td>
#       <td id="T_0a5ce_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_0a5ce_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_0a5ce_row1_col3" class="data row1 col3" >root</td>
#       <td id="T_0a5ce_row1_col4" class="data row1 col4" ></td>
#       <td id="T_0a5ce_row1_col5" class="data row1 col5" >time:16.9ms, loops:2, partial_worker:{wall_time:16.866894ms, concurrency:5, task_num:1, tot_wait:84.067782ms, tot_exec:25.378µs, tot_time:84.102555ms, max:16.828683ms, p95:16.828683ms}, final_worker:{wall_time:16.918265ms, concurrency:5, task_num:1, tot_wait:84.272723ms, tot_exec:29.637µs, tot_time:84.306145ms, max:16.878693ms, p95:16.878693ms}</td>
#       <td id="T_0a5ce_row1_col6" class="data row1 col6" >group by:ossinsight.github_events.repo_name, funcs:count(Column#38)->Column#34, funcs:firstrow(ossinsight.github_events.repo_name)->ossinsight.github_events.repo_name</td>
#       <td id="T_0a5ce_row1_col7" class="data row1 col7" >16.1 KB</td>
#       <td id="T_0a5ce_row1_col8" class="data row1 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_0a5ce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0a5ce_row2_col0" class="data row2 col0" >  └─IndexLookUp_21</td>
#       <td id="T_0a5ce_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_0a5ce_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_0a5ce_row2_col3" class="data row2 col3" >root</td>
#       <td id="T_0a5ce_row2_col4" class="data row2 col4" >partition:pull_request_event</td>
#       <td id="T_0a5ce_row2_col5" class="data row2 col5" >time:16.8ms, loops:2, index_task: {total_time: 3.36ms, fetch_handle: 3.34ms, build: 2.66µs, wait: 19.2µs}, table_task: {total_time: 39.2ms, num: 3, concurrency: 5}</td>
#       <td id="T_0a5ce_row2_col6" class="data row2 col6" ></td>
#       <td id="T_0a5ce_row2_col7" class="data row2 col7" >131.5 KB</td>
#       <td id="T_0a5ce_row2_col8" class="data row2 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_0a5ce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0a5ce_row3_col0" class="data row3 col0" >    ├─IndexRangeScan_17(Build)</td>
#       <td id="T_0a5ce_row3_col1" class="data row3 col1" >12145.00</td>
#       <td id="T_0a5ce_row3_col2" class="data row3 col2" >6563</td>
#       <td id="T_0a5ce_row3_col3" class="data row3 col3" >cop[tikv]</td>
#       <td id="T_0a5ce_row3_col4" class="data row3 col4" >table:github_events, index:index_github_events_on_actor_login(actor_login)</td>
#       <td id="T_0a5ce_row3_col5" class="data row3 col5" >time:3.05ms, loops:9, cop_task: {num: 1, max: 2.95ms, proc_keys: 6564, tot_proc: 4ms, rpc_num: 1, rpc_time: 2.92ms, copr_cache_hit_ratio: 0.00, distsql_concurrency: 15}, tikv_task:{time:4ms, loops:11}, scan_detail: {total_process_keys: 6564, total_process_keys_size: 466024, total_keys: 6565, rocksdb: {block: {}}}</td>
#       <td id="T_0a5ce_row3_col6" class="data row3 col6" >range:["ti-chi-bot","ti-chi-bot"], keep order:false</td>
#       <td id="T_0a5ce_row3_col7" class="data row3 col7" >N/A</td>
#       <td id="T_0a5ce_row3_col8" class="data row3 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_0a5ce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0a5ce_row4_col0" class="data row4 col0" >    └─HashAgg_7(Probe)</td>
#       <td id="T_0a5ce_row4_col1" class="data row4 col1" >1.00</td>
#       <td id="T_0a5ce_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_0a5ce_row4_col3" class="data row4 col3" >cop[tikv]</td>
#       <td id="T_0a5ce_row4_col4" class="data row4 col4" ></td>
#       <td id="T_0a5ce_row4_col5" class="data row4 col5" >time:36.8ms, loops:4, cop_task: {num: 3, max: 12.1ms, min: 11.5ms, avg: 11.8ms, p95: 12.1ms, max_proc_keys: 2499, p95_proc_keys: 2499, tot_proc: 24ms, rpc_num: 3, rpc_time: 35.4ms, copr_cache_hit_ratio: 0.00, distsql_concurrency: 15}, tikv_task:{proc max:8ms, min:8ms, avg: 8ms, p80:8ms, p95:8ms, iters:8, tasks:3}, scan_detail: {total_process_keys: 6563, total_process_keys_size: 1881239, total_keys: 6728, rocksdb: {block: {}}}</td>
#       <td id="T_0a5ce_row4_col6" class="data row4 col6" >group by:ossinsight.github_events.repo_name, funcs:count(1)->Column#38</td>
#       <td id="T_0a5ce_row4_col7" class="data row4 col7" >N/A</td>
#       <td id="T_0a5ce_row4_col8" class="data row4 col8" >N/A</td>
#     </tr>
#     <tr>
#       <th id="T_0a5ce_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0a5ce_row5_col0" class="data row5 col0" >      └─Selection_19</td>
#       <td id="T_0a5ce_row5_col1" class="data row5 col1" >616.14</td>
#       <td id="T_0a5ce_row5_col2" class="data row5 col2" >138</td>
#       <td id="T_0a5ce_row5_col3" class="data row5 col3" >cop[tikv]</td>
#       <td id="T_0a5ce_row5_col4" class="data row5 col4" ></td>
#       <td id="T_0a5ce_row5_col5" class="data row5 col5" >tikv_task:{proc max:8ms, min:8ms, avg: 8ms, p80:8ms, p95:8ms, iters:8, tasks:3}</td>
#       <td id="T_0a5ce_row5_col6" class="data row5 col6" >eq(ossinsight.github_events.action, "opened"), eq(ossinsight.github_events.type, "PullRequestEvent")</td>
#       <td id="T_0a5ce_row5_col7" class="data row5 col7" >N/A</td>
#       <td id="T_0a5

# %% [markdown]
# 通过执行计划，我们可以知道这个 SQL 会使用 TiKV 存储引擎来读取 `github_events` 表中的数据，并且使用了索引 `index_github_events_on_actor_login`。

# %% [markdown]
# #### Example 2

# %% [markdown]
# > 🤔 除了通过聚合函数来进行简单数据分析，TiDB 是否可以做更复杂的数据分析吗？
#
# 比如我们想要知道某个指标的增长趋势，以代码仓库 `pingcap/tidb` 为例，我们能否通过 SQL 查询该仓库 Star 的增长趋势 (按月累计)，这样的 SQL 语句我们会怎么写?

# %%
query("""
  SELECT
    actor_id,
    actor_login,
    repo_id,
    repo_name,
    created_at,
    DATE_FORMAT(created_at, '%Y-%m-01') as event_month
  FROM
    github_events
  WHERE
    type = 'WatchEvent'
    AND repo_name = 'pingcap/tidb'
  ORDER BY created_at
  LIMIT 10
""")
# Out:
# <style type="text/css">
# #T_77203_row0_col0, #T_77203_row0_col1, #T_77203_row0_col2, #T_77203_row0_col3, #T_77203_row0_col4, #T_77203_row0_col5, #T_77203_row1_col0, #T_77203_row1_col1, #T_77203_row1_col2, #T_77203_row1_col3, #T_77203_row1_col4, #T_77203_row1_col5, #T_77203_row2_col0, #T_77203_row2_col1, #T_77203_row2_col2, #T_77203_row2_col3, #T_77203_row2_col4, #T_77203_row2_col5, #T_77203_row3_col0, #T_77203_row3_col1, #T_77203_row3_col2, #T_77203_row3_col3, #T_77203_row3_col4, #T_77203_row3_col5, #T_77203_row4_col0, #T_77203_row4_col1, #T_77203_row4_col2, #T_77203_row4_col3, #T_77203_row4_col4, #T_77203_row4_col5, #T_77203_row5_col0, #T_77203_row5_col1, #T_77203_row5_col2, #T_77203_row5_col3, #T_77203_row5_col4, #T_77203_row5_col5, #T_77203_row6_col0, #T_77203_row6_col1, #T_77203_row6_col2, #T_77203_row6_col3, #T_77203_row6_col4, #T_77203_row6_col5, #T_77203_row7_col0, #T_77203_row7_col1, #T_77203_row7_col2, #T_77203_row7_col3, #T_77203_row7_col4, #T_77203_row7_col5, #T_77203_row8_col0, #T_77203_row8_col1, #T_77203_row8_col2, #T_77203_row8_col3, #T_77203_row8_col4, #T_77203_row8_col5, #T_77203_row9_col0, #T_77203_row9_col1, #T_77203_row9_col2, #T_77203_row9_col3, #T_77203_row9_col4, #T_77203_row9_col5 {
#   text-align: left;
# }
# </style>
# <table id="T_77203_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >actor_id</th>
#       <th class="col_heading level0 col1" >actor_login</th>
#       <th class="col_heading level0 col2" >repo_id</th>
#       <th class="col_heading level0 col3" >repo_name</th>
#       <th class="col_heading level0 col4" >created_at</th>
#       <th class="col_heading level0 col5" >event_month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77203_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_77203_row0_col0" class="data row0 col0" >1953644</td>
#       <td id="T_77203_row0_col1" class="data row0 col1" >qiuyesuifeng</td>
#       <td id="T_77203_row0_col2" class="data row0 col2" >41986369</td>
#       <td id="T_77203_row0_col3" class="data row0 col3" >pingcap/tidb</td>
#       <td id="T_77203_row0_col4" class="data row0 col4" >2015-09-06 04:15:40</td>
#       <td id="T_77203_row0_col5" class="data row0 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_77203_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_77203_row1_col0" class="data row1 col0" >878009</td>
#       <td id="T_77203_row1_col1" class="data row1 col1" >ngaut</td>
#       <td id="T_77203_row1_col2" class="data row1 col2" >41986369</td>
#       <td id="T_77203_row1_col3" class="data row1 col3" >pingcap/tidb</td>
#       <td id="T_77203_row1_col4" class="data row1 col4" >2015-09-06 04:15:44</td>
#       <td id="T_77203_row1_col5" class="data row1 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_77203_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_77203_row2_col0" class="data row2 col0" >1192573</td>
#       <td id="T_77203_row2_col1" class="data row2 col1" >shenli</td>
#       <td id="T_77203_row2_col2" class="data row2 col2" >41986369</td>
#       <td id="T_77203_row2_col3" class="data row2 col3" >pingcap/tidb</td>
#       <td id="T_77203_row2_col4" class="data row2 col4" >2015-09-06 04:15:53</td>
#       <td id="T_77203_row2_col5" class="data row2 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_77203_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_77203_row3_col0" class="data row3 col0" >4242506</td>
#       <td id="T_77203_row3_col1" class="data row3 col1" >zimulala</td>
#       <td id="T_77203_row3_col2" class="data row3 col2" >41986369</td>
#       <td id="T_77203_row3_col3" class="data row3 col3" >pingcap/tidb</td>
#       <td id="T_77203_row3_col4" class="data row3 col4" >2015-09-06 04:15:53</td>
#       <td id="T_77203_row3_col5" class="data row3 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_77203_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_77203_row4_col0" class="data row4 col0" >891222</td>
#       <td id="T_77203_row4_col1" class="data row4 col1" >coocood</td>
#       <td id="T_77203_row4_col2" class="data row4 col2" >41986369</td>
#       <td id="T_77203_row4_col3" class="data row4 col3" >pingcap/tidb</td>
#       <td id="T_77203_row4_col4" class="data row4 col4" >2015-09-06 04:16:19</td>
#       <td id="T_77203_row4_col5" class="data row4 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_77203_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_77203_row5_col0" class="data row5 col0" >541236</td>
#       <td id="T_77203_row5_col1" class="data row5 col1" >tomzhang</td>
#       <td id="T_77203_row5_col2" class="data row5 col2" >41986369</td>
#       <td id="T_77203_row5_col3" class="data row5 col3" >pingcap/tidb</td>
#       <td id="T_77203_row5_col4" class="data row5 col4" >2015-09-06 04:17:26</td>
#       <td id="T_77203_row5_col5" class="data row5 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_77203_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_77203_row6_col0" class="data row6 col0" >1782276</td>
#       <td id="T_77203_row6_col1" class="data row6 col1" >FlamingTree</td>
#       <td id="T_77203_row6_col2" class="data row6 col2" >41986369</td>
#       <td id="T_77203_row6_col3" class="data row6 col3" >pingcap/tidb</td>
#       <td id="T_77203_row6_col4" class="data row6 col4" >2015-09-06 04:17:45</td>
#       <td id="T_77203_row6_col5" class="data row6 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_77203_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_77203_row7_col0" class="data row7 col0" >14066328</td>
#       <td id="T_77203_row7_col1" class="data row7 col1" >nengwang</td>
#       <td id="T_77203_row7_col2" class="data row7 col2" >41986369</td>
#       <td id="T_77203_row7_col3" class="data row7 col3" >pingcap/tidb</td>
#       <td id="T_77203_row7_col4" class="data row7 col4" >2015-09-06 04:18:10</td>
#       <td id="T_77203_row7_col5" class="data row7 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_77203_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_77203_row8_col0" class="data row8 col0" >1468284</td>
#       <td id="T_77203_row8_col1" class="data row8 col1" >se77en</td>
#       <td id="T_77203_row8_col2" class="data row8 col2" >41986369</td>
#       <td id="T_77203_row8_col3" class="data row8 col3" >pingcap/tidb</td>
#       <td id="T_77203_row8_col4" class="data row8 col4" >2015-09-06 04:19:55</td>
#       <td id="T_77203_row8_col5" class="data row8 col5" >2015-09-01</td>
#     </tr>
#     <tr>
#       <th id="T_77203_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_77203_row9_col0" class="data row9 col0" >773853</td>
#       <td id="T_77203_row9_col1" class="data row9 col1" >c4pt0r</td>
#       <td id="T_77203_row9_col2" class="data row9 col2" >41986369</td>
#       <td id="T_77203_row9_col3" class="data row9 col3" >pingcap/tidb</td>
#       <td id="T_77203_row9_col4" class="data row9 col4" >2015-09-06 04:20:56</td>
#       <td id="T_77203_row9_col5" class="data row9 col5" >2015-09-01</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 我们可以利用[窗口函数](https://docs.pingcap.com/zh/tidb/stable/window-functions)来实现这一个需求。窗口函数通常也被称为 “OLAP 函数”，又或者是 “开窗函数”。
#
# 例如，在下面的 SQL 语句当中，我们通过 `OVER` 语句定义窗口的范围，TiDB 会将数据行按照 `created_at` 列进行排序，然后对这些数据行按顺序扫描，将当前行之前的所有行作为一个窗口。
#
# 随着扫描的行数越多，窗口也会逐步扩大。对于每个窗口都会执行一次聚合函数 `COUNT(1)` 来统计窗口内的事件总数，从而可以得到一组随着时间累积增长的统计数据。

# %%
query("""
SELECT
    created_at,
    COUNT(1) OVER (ORDER BY created_at) AS stars
FROM
    github_events
WHERE
    type = 'WatchEvent'
    AND repo_name = 'pingcap/tidb'
ORDER BY created_at
LIMIT 100;
""");

# %% [markdown]
# 在这个基础之上，我们进行一个按月聚合，使用 `DATE_FORMAT('%Y-%m-01')` 函数将同一个月的事件记录进行分组统计。

# %%
query("""
SELECT
  event_month, stars
FROM (
  SELECT
    DATE_FORMAT(created_at, '%Y-%m-01') as event_month,
    COUNT(1) OVER (ORDER BY DATE_FORMAT(created_at, '%Y-%m-01')) AS stars,
    ROW_NUMBER() OVER (PARTITION BY DATE_FORMAT(created_at, '%Y-%m-01')) AS row_num
  FROM
    github_events
  WHERE
    type = 'WatchEvent'
    AND repo_name = 'pingcap/tidb'
  ORDER BY 1
) sub
WHERE row_num = 1
ORDER BY event_month DESC
""");

# %% [markdown]
# 通过 `EXPLAIN` 语句查看其执行计划：

# %%
query("""
EXPLAIN ANALYZE SELECT
  event_month, stars
FROM (
  SELECT
    DATE_FORMAT(created_at, '%Y-%m-01') as event_month,
    COUNT(1) OVER (ORDER BY DATE_FORMAT(created_at, '%Y-%m-01')) AS stars,
    ROW_NUMBER() OVER (PARTITION BY DATE_FORMAT(created_at, '%Y-%m-01')) AS row_num
  FROM
    github_events ge
  WHERE
    type = 'WatchEvent'
    AND repo_name = 'pingcap/tidb'
  ORDER BY 1
) sub
WHERE row_num = 1
ORDER BY event_month DESC;
""");

# %% [markdown]
# 我们发现对于 OLAP 函数，TiDB 的优化器仍然会使用 TiKV 作为存储引擎进行数据查询。
#
# 这是因为在默认情况下，TiDB 不会是为 `github_events` 表创建 TiFlash 副本的，你需要手动地进行创建，创建副本的方法也十分简单，你只需要执行下面这条 SQL 语句，就可以为 `github_events` 表创建一个 TiFlash 副本：

# %%
query("""
ALTER TABLE ossinsight.github_events SET TIFLASH REPLICA 1;
""")

# %% [markdown]
# 执行完上面的 SQL 语句后，TiFlash 会在后台自动地完成副本的创建，你可以通过执行下面的 SQL 语句来查看副本的创建进度：

# %%
query("""
SELECT * FROM information_schema.tiflash_replica WHERE TABLE_SCHEMA = 'ossinsight' and TABLE_NAME = 'github_events';
""")
# Out:
# <style type="text/css">
# #T_5f138_row0_col0, #T_5f138_row0_col1, #T_5f138_row0_col2, #T_5f138_row0_col3, #T_5f138_row0_col4, #T_5f138_row0_col5, #T_5f138_row0_col6, #T_5f138_row0_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_5f138_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >TABLE_SCHEMA</th>
#       <th class="col_heading level0 col1" >TABLE_NAME</th>
#       <th class="col_heading level0 col2" >TABLE_ID</th>
#       <th class="col_heading level0 col3" >REPLICA_COUNT</th>
#       <th class="col_heading level0 col4" >LOCATION_LABELS</th>
#       <th class="col_heading level0 col5" >AVAILABLE</th>
#       <th class="col_heading level0 col6" >PROGRESS</th>
#       <th class="col_heading level0 col7" >TABLE_MODE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f138_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f138_row0_col0" class="data row0 col0" >ossinsight</td>
#       <td id="T_5f138_row0_col1" class="data row0 col1" >github_events</td>
#       <td id="T_5f138_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_5f138_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_5f138_row0_col4" class="data row0 col4" ></td>
#       <td id="T_5f138_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_5f138_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_5f138_row0_col7" class="data row0 col7" >NORMAL</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 当 “PROCESS” 为 1 时，表示 TiFlash 副本已经创建完成，再次执行上面的分析查询语句：

# %%
query("""
EXPLAIN ANALYZE SELECT
  event_month, stars
FROM (
  SELECT
    DATE_FORMAT(created_at, '%Y-%m-01') as event_month,
    COUNT(1) OVER (ORDER BY DATE_FORMAT(created_at, '%Y-%m-01')) AS stars,
    ROW_NUMBER() OVER (PARTITION BY DATE_FORMAT(created_at, '%Y-%m-01')) AS row_num
  FROM
    github_events ge
  WHERE
    type = 'WatchEvent'
    AND repo_name = 'pingcap/tidb'
  ORDER BY 1
) sub
WHERE row_num = 1
ORDER BY event_month DESC;
""");

# %% [markdown]
# 我们会发现此时的执行计划当中已经出现了 `cop[tiflash]` 的字样，说明此时的查询已经在使用 TiFlash 存储引擎来读取数据。
#
# > 🤔 但是看上去前后查询的速度并没有多大的差异。

# %% [markdown]
# #### Example 3

# %% [markdown]
# 我们来看一下更加复杂的例子，在前面的查询当中，我们只是在查询一个仓库的数据，TiDB 也许还能够借助 TiKV 走索引的方式找到一条更高效的执行计划。
#
# 但是有的时候，我们的数据分析可能并没有这么简单，可能需要同时分析 N 个代码仓库，甚至所有代码仓库的数据。又或者是我们希望能够进行大批量的数据报表统计，这个时候需要扫描更为大量的数据，这时候优化器即便仍然选择了索引查询的方式，查询的效率可能仍然不会很高。
#
# 首先，我们应用我们在背景知识当中学习到的技巧，通过 `/*+ READ_FROM_STORAGE(TIKV[ge]) */` Hints 来告诉优化器在查询 `github_events` 表时强制使用 TiKV 存储引擎。

# %%
query("""
WITH bots_with_first_seen AS (
    SELECT
        /*+ READ_FROM_STORAGE(TIKV[ge]) */
        actor_login, MIN(YEAR(created_at)) AS first_seen_at
    FROM github_events ge
    WHERE
        actor_login REGEXP '^(bot-.+|.+bot|.+\\[bot\\]|.+-bot-.+|robot-.+|.+-ci-.+|.+-ci|.+-testing|.+clabot.+|.+-gerrit|k8s-.+|.+-machine|.+-automation|github-.+|.+-github|.+-service|.+-builds|codecov-.+|.+teamcity.+|jenkins-.+|.+-jira-.+)$'
    GROUP BY actor_login
    ORDER BY first_seen_at
),  acc AS (
    SELECT
        COUNT(actor_login) OVER (ORDER BY first_seen_at) AS cnt,
        first_seen_at AS event_year
    FROM
        bots_with_first_seen AS bwfs
    ORDER BY event_year
)
SELECT ANY_VALUE(cnt) AS bots_total, event_year
FROM acc
GROUP BY event_year
ORDER BY event_year;
""");

# %% [markdown]
# 记录下查询的时间。

# %% [markdown]
# 然后我们通过 `/*+ READ_FROM_STORAGE(TIFLASH[ge]) */` Hints 来强制优化器使用 TiFlash 存储引擎来读取 `github_events` 表，再次执行：

# %%
query("""
WITH bots_with_first_seen AS (
    SELECT
        /*+ READ_FROM_STORAGE(TIFLASH[ge]) */
        actor_login, MIN(YEAR(created_at)) AS first_seen_at
    FROM github_events ge
    WHERE
        actor_login REGEXP '^(bot-.+|.+bot|.+\\[bot\\]|.+-bot-.+|robot-.+|.+-ci-.+|.+-ci|.+-testing|.+clabot.+|.+-gerrit|k8s-.+|.+-machine|.+-automation|github-.+|.+-github|.+-service|.+-builds|codecov-.+|.+teamcity.+|jenkins-.+|.+-jira-.+)$'
    GROUP BY actor_login
    ORDER BY first_seen_at
),  acc AS (
    SELECT
        COUNT(actor_login) OVER (ORDER BY first_seen_at) AS cnt,
        first_seen_at AS event_year
    FROM
        bots_with_first_seen AS bwfs
    ORDER BY event_year
)
SELECT ANY_VALUE(cnt) AS bots_total, event_year
FROM acc
GROUP BY event_year
ORDER BY event_year;
""");

# %% [markdown]
# #### Example 4

# %%
> 🤔
