# %% [markdown]
# ## Mini OSS Insight Workshop
#
# 👏 欢迎来到 Mini OSS Insight 的 Workshop!
#
# 这是关于 Workshop 的完整指南，你可以通过阅读该指南一步一步地搭建起一个 Mini 版的 OSS Insight，并在过程掌握一些使用 TiDB / TiDB Cloud 进行数据分析的技巧。

# %% [markdown]
# ### 准备
#
# 在开始之前，你需要确保在你的开发环境中已经安装了以下软件/工具：
#
# - 可供连接的 TiDB 集群 - 用于存储数据的数据库
# - MyCLI - 连接到 TiDB 集群
# - Node.js 18.x and above - API Server 的运行时环境
# - PNPM - Node.js 的包管理器
# - Python 3.x and pip - Jupyter Notebook 需要的运行时环境
#
# #### 1. 启动 TiDB 集群
#
# 首先, 你需要开启一个 TiDB 集群。你可以通过查看文档 [TiDB Cloud Quick Start](https://docs.pingcap.com/tidbcloud/tidb-cloud-quickstart#step-1-create-a-tidb-cluster) 学习如何创建一个 **Serverless tier** 集群，这可能会需要 20～25s 的时间。
#
# 在你创建完集群，你可以进入到集群的详情页。在这个页面，你可以在 **Connection** 面板中找到数据库集群的连接信息。
#
# <center>
#   <img align="middle" width="800" alt="Serverless Tier Cluster Manage Interface" src="https://user-images.githubusercontent.com/5086433/204476069-0ddbdf6f-419c-4291-b929-ccfbd2f5ea5f.png">
#   <p><i>Serverless Tier 集群管理界面</i></p>
# </center>
#
# You can enter to the cluster's security settings window by clicking on the modify menu in the upper right corner of the cluster details page and generate a root user password.
#
# <center>
#   <img width="480" alt="The Cluster Modify Menu" src="https://user-images.githubusercontent.com/85985765/204876779-3a4c6ac4-8814-47cd-b82a-40eb5e4d8f96.png">
#   <p><i>The Cluster Modify Menu</i></p>
# </center>
#
# <center>
#   <img width="720" alt="Security Settings" src="https://user-images.githubusercontent.com/85985765/204877348-5c3e9012-f7bf-42e9-8a03-fd9f14bfc826.png">
#   <p><i>Security Settings</i></p>
# </center>
#
# #### 3. 个人 GitHub 的 Access Token
#
# You need to prepare a personal access token to allow the application to access the data through the GitHub API.
#
# > **Note**
# >
# > If you are viewing this document from GitHub codespace, you can skip this step because `GITHUB_TOKEN` is set by default in the codespace environment.
# >
#
# You can learn how to generate one by reading: [Creating a personal access token](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token). Or just click this [link](https://github.com/settings/personal-access-tokens/new) to generate your personal access token quickly.
#
# <center>
#   <img align="middle" width="800" alt="Create a New GitHub Personal Access Token" src="https://user-images.githubusercontent.com/5086433/204564273-93cccbe4-d10a-4d1b-a9d1-112a1144712a.png">
#   <p><i>Create a new GitHub personal access token</i></p>
# </center>

# %% [markdown]
# #### 4. 设置环境变量

# %%
import getpass
import os

api_server_dot_env="./packages/api-server/.env"
if os.path.exists(api_server_dot_env): 
    con = input(api_server_dot_env + " file already exists, do you want to overwrite it? (y/n) [y]")
    if con != 'y':
        exit();

# Config GitHub personal access token.
github_token = ""
if os.getenv('GITHUB_TOKEN') is None:
    github_token = getpass.getpass(prompt='Enter your personal access token of GitHub: ')
else:
    github_token = os.getenv('GITHUB_TOKEN')

# Config database connection.
db_endpoint = input("The endpoint of TiDB cluster: ")
db_port = int(input("The port of TiDB cluster [4000]: ")) or 4000
db_username = input("The username of TiDB cluster: ")
db_password = getpass.getpass(prompt='Enter the password of TiDB cluster: ')
db_name = "ossinsight"
db_enable_ssl = input("Enable ssl connection to the TiDB cluster? (y/n) [y]") or "y"
db_ssl_config='&ssl={"minVersion":"TLSv1.2"}'
if db_enable_ssl == "n":
    db_ssl_config = ""

# Write to ./packages/api-server/.env file.
with open(api_server_dot_env, "w") as file:
    file.write(
        "DATABASE_URL=mysql://{}:{}@{}:{}/{}?connectionLimit=100&queueLimit=10000{}\n".format(
            db_username, db_password, db_endpoint, db_port, db_name, db_ssl_config
        )
    )
    file.write("ENABLE_CACHE=false\n")
    file.write("GITHUB_ACCESS_TOKENS={}\n".format(github_token))

print("Setup successfully!")
# Out:
# Setup successfully!

# %% [markdown]
# #### 5. 验证是否能够连接到 TiDB 集群
#
# 在终端上执行下面的 SQL 语句验证是否能够连接到 TiDB 集群
#
# ```bash
# mycli -h ${DB_ENDPOINT} -P ${DB_PORT} -u ${DB_USERNAME} -p ${DB_PASSWORD} -D test \
#     --ssl-ca=/etc/ssl/certs/ca-certificates.crt \
#     --ssl-verify-server-cert \
#      -e 'SELECT tidb_version()\G'
# ```
#
# 如果成功执行，你会看到 TiDB 集群的版本信息：
#
# ```
# tidb_version()
# Release Version: v6.3.0-serverless
# Edition: Community
# Git Commit Hash: e87c16b215d518aed4921b8ef3b13e90e3ed6e2d
# Git Branch: release-6.3-serverless
# UTC Build Time: 2022-11-25 09:31:28
# GoVersion: go1.19
# Race Enabled: false
# TiKV Min Version: 6.1.0
# Check Table Before Drop: false
# Store: tikv
# ```

# %% [markdown]
# ### 加载数据
#
# GitHub 成立于 2008 年，在 2011 年二月份的时候，GitHub 提供了一个 `https://api.github.com/events` 接口来对外输出网站上的公开事件数据。
#
# > **GitHub API 文档**
# >
# > Link: https://docs.github.com/en/rest/activity/events
# >

# %% [markdown]
# OSS Insight 已经收集了超过 53 亿条公开事件数据，你可以通过访问 API 或在网站上查看当前的事件总数：

# %%
# !curl -s https://api.ossinsight.io/q/events-total | jq -r ".data[0]"
# Out:
# {
#   "cnt": 5319456119,
#   "latest_created_at": "2022-12-01T19:18:00.000Z",
#   "latest_timestamp": 1669922280
# }

# %% [markdown]
# #### 导入实时数据
#
# 通过 [GitHub 的 API 文档](https://docs.github.com/en/rest/activity/events), 我们知道可以通过请求 `/events` API 来获取准实时的 events 数据。你可以执行下面的命令查看这个接口返回数据的结构：

# %%
# !curl -s \
  -H "Accept: application/vnd.github.v3+json" \
  -H "Authorization: token $GITHUB_TOKEN" \
  https://api.github.com/events
# Out:
# [
#   {
#     "id": "25599598187",
#     "type": "PushEvent",
#     "actor": {
#       "id": 40635516,
#       "login": "DaniBootCamp",
#       "display_login": "DaniBootCamp",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/DaniBootCamp",
#       "avatar_url": "https://avatars.githubusercontent.com/u/40635516?"
#     },
#     "repo": {
#       "id": 573120852,
#       "name": "carlosmavogaro/amoung-us-grupo-1",
#       "url": "https://api.github.com/repos/carlosmavogaro/amoung-us-grupo-1"
#     },
#     "payload": {
#       "push_id": 11852249371,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/daniel",
#       "head": "a6a49030886b478c7047d22e556694e4f39b5b05",
#       "before": "880af9cd744c901d0737f0bf0d27a61393d1f9dc",
#       "commits": [
#         {
#           "sha": "a6a49030886b478c7047d22e556694e4f39b5b05",
#           "author": {
#             "email": "titodani@gmail.com",
#             "name": "DaniBootCamp"
#           },
#           "message": "buscando impostor",
#           "distinct": true,
#           "url": "https://api.github.com/repos/carlosmavogaro/amoung-us-grupo-1/commits/a6a49030886b478c7047d22e556694e4f39b5b05"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z"
#   },
#   {
#     "id": "25599598178",
#     "type": "PushEvent",
#     "actor": {
#       "id": 113677173,
#       "login": "adeneye02",
#       "display_login": "adeneye02",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/adeneye02",
#       "avatar_url": "https://avatars.githubusercontent.com/u/113677173?"
#     },
#     "repo": {
#       "id": 551042477,
#       "name": "adeneye02/alx-low_level_programming",
#       "url": "https://api.github.com/repos/adeneye02/alx-low_level_programming"
#     },
#     "payload": {
#       "push_id": 11852249379,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/master",
#       "head": "84490799349ebb8b7718e1c69e106416296f8dda",
#       "before": "8c784b7df00ca5547ec62116f5f71e10bfbe33c6",
#       "commits": [
#         {
#           "sha": "84490799349ebb8b7718e1c69e106416296f8dda",
#           "author": {
#             "email": "tosinolatunbosun02@gmail.com",
#             "name": "adeneye02"
#           },
#           "message": "0x14-bit_manipulation commit",
#           "distinct": true,
#           "url": "https://api.github.com/repos/adeneye02/alx-low_level_programming/commits/84490799349ebb8b7718e1c69e106416296f8dda"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z"
#   },
#   {
#     "id": "25599598177",
#     "type": "PushEvent",
#     "actor": {
#       "id": 26678117,
#       "login": "gallardoalba",
#       "display_login": "gallardoalba",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/gallardoalba",
#       "avatar_url": "https://avatars.githubusercontent.com/u/26678117?"
#     },
#     "repo": {
#       "id": 327054196,
#       "name": "gallardoalba/galaxy-hub",
#       "url": "https://api.github.com/repos/gallardoalba/galaxy-hub"
#     },
#     "payload": {
#       "push_id": 11852249387,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/Add_COBLET_post",
#       "head": "79d3a6829f11dcb2502196efe40d325ab86ccab0",
#       "before": "07e42339d66b02ef7312559088580484b8b0ccda",
#       "commits": [
#         {
#           "sha": "79d3a6829f11dcb2502196efe40d325ab86ccab0",
#           "author": {
#             "email": "gallardoalbac@gmail.com",
#             "name": "Cristóbal Gallardo"
#           },
#           "message": "Update src/blog/2022-10-19-COBLET-talk/index.md",
#           "distinct": true,
#           "url": "https://api.github.com/repos/gallardoalba/galaxy-hub/commits/79d3a6829f11dcb2502196efe40d325ab86ccab0"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z"
#   },
#   {
#     "id": "25599598149",
#     "type": "PushEvent",
#     "actor": {
#       "id": 81445640,
#       "login": "ThatJesusBabe",
#       "display_login": "ThatJesusBabe",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/ThatJesusBabe",
#       "avatar_url": "https://avatars.githubusercontent.com/u/81445640?"
#     },
#     "repo": {
#       "id": 571748727,
#       "name": "ThatJesusBabe/alx-higher_level_programming",
#       "url": "https://api.github.com/repos/ThatJesusBabe/alx-higher_level_programming"
#     },
#     "payload": {
#       "push_id": 11852249381,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "6bd42b8291c5ab34b42809864592c710a41f3895",
#       "before": "d847837e62819291b7a0715e514e1756115fa1b1",
#       "commits": [
#         {
#           "sha": "6bd42b8291c5ab34b42809864592c710a41f3895",
#           "author": {
#             "email": "adefemilauren@gmail.com",
#             "name": "Lorrine Adefemi"
#           },
#           "message": "commit",
#           "distinct": true,
#           "url": "https://api.github.com/repos/ThatJesusBabe/alx-higher_level_programming/commits/6bd42b8291c5ab34b42809864592c710a41f3895"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z"
#   },
#   {
#     "id": "25599598160",
#     "type": "PushEvent",
#     "actor": {
#       "id": 59265284,
#       "login": "lokWasTaken",
#       "display_login": "lokWasTaken",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/lokWasTaken",
#       "avatar_url": "https://avatars.githubusercontent.com/u/59265284?"
#     },
#     "repo": {
#       "id": 514641988,
#       "name": "lokWasTaken/ROBLOX-SCRIPTS",
#       "url": "https://api.github.com/repos/lokWasTaken/ROBLOX-SCRIPTS"
#     },
#     "payload": {
#       "push_id": 11852249378,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/master",
#       "head": "a1f51ec6bcdb5ab3759ac4e03b00e7b769380d67",
#       "before": "f113daf54ed61fa8636e8fdfc0e5766a30ee8fe9",
#       "commits": [
#         {
#           "sha": "a1f51ec6bcdb5ab3759ac4e03b00e7b769380d67",
#           "author": {
#             "email": "59265284+lokWasTaken@users.noreply.github.com",
#             "name": "lok"
#           },
#           "message": "Update Drone",
#           "distinct": true,
#           "url": "https://api.github.com/repos/lokWasTaken/ROBLOX-SCRIPTS/commits/a1f51ec6bcdb5ab3759ac4e03b00e7b769380d67"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z"
#   },
#   {
#     "id": "25599598070",
#     "type": "PushEvent",
#     "actor": {
#       "id": 107587589,
#       "login": "nuella001",
#       "display_login": "nuella001",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/nuella001",
#       "avatar_url": "https://avatars.githubusercontent.com/u/107587589?"
#     },
#     "repo": {
#       "id": 572900493,
#       "name": "nuella001/alx-system_engineering-devops",
#       "url": "https://api.github.com/repos/nuella001/alx-system_engineering-devops"
#     },
#     "payload": {
#       "push_id": 11852249293,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/master",
#       "head": "32fef161088c37bccba7d4031a696fc243e2710f",
#       "before": "2927f172a1d2d379847ad10144d9f29fefd60861",
#       "commits": [
#         {
#           "sha": "32fef161088c37bccba7d4031a696fc243e2710f",
#           "author": {
#             "email": "chiomamemmanuella@gmail.com",
#             "name": "nuella001"
#           },
#           "message": "file type",
#           "distinct": true,
#           "url": "https://api.github.com/repos/nuella001/alx-system_engineering-devops/commits/32fef161088c37bccba7d4031a696fc243e2710f"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z"
#   },
#   {
#     "id": "25599598142",
#     "type": "PushEvent",
#     "actor": {
#       "id": 41898282,
#       "login": "github-actions[bot]",
#       "display_login": "github-actions",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/github-actions[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/41898282?"
#     },
#     "repo": {
#       "id": 422026046,
#       "name": "Kaikeeksr/Kaikeeksr",
#       "url": "https://api.github.com/repos/Kaikeeksr/Kaikeeksr"
#     },
#     "payload": {
#       "push_id": 11852249343,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/output",
#       "head": "79a2a73ede06a8054407b10bce81c40c97ba936c",
#       "before": "5765f15c35005e9d3ee88e98d0532aa43d33f8e3",
#       "commits": [
#         {
#           "sha": "79a2a73ede06a8054407b10bce81c40c97ba936c",
#           "author": {
#             "email": "41898282+github-actions[bot]@users.noreply.github.com",
#             "name": "github-actions[bot]"
#           },
#           "message": "Deploy to GitHub pages",
#           "distinct": true,
#           "url": "https://api.github.com/repos/Kaikeeksr/Kaikeeksr/commits/79a2a73ede06a8054407b10bce81c40c97ba936c"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z"
#   },
#   {
#     "id": "25599598161",
#     "type": "PushEvent",
#     "actor": {
#       "id": 114601596,
#       "login": "AmarPlakalo",
#       "display_login": "AmarPlakalo",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/AmarPlakalo",
#       "avatar_url": "https://avatars.githubusercontent.com/u/114601596?"
#     },
#     "repo": {
#       "id": 573126756,
#       "name": "AmarPlakalo/Lab-4",
#       "url": "https://api.github.com/repos/AmarPlakalo/Lab-4"
#     },
#     "payload": {
#       "push_id": 11852249372,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "cef4cb954fed6e3b109d2dce3cc3b3270db202db",
#       "before": "b330a9839c926634c2b6d9f70f5d21bc59f20b3e",
#       "commits": [
#         {
#           "sha": "cef4cb954fed6e3b109d2dce3cc3b3270db202db",
#           "author": {
#             "email": "114601596+AmarPlakalo@users.noreply.github.com",
#             "name": "AmarPlakalo"
#           },
#           "message": "Changing name from readme.md to answers.md so answers can stored to the questions",
#           "distinct": true,
#           "url": "https://api.github.com/repos/AmarPlakalo/Lab-4/commits/cef4cb954fed6e3b109d2dce3cc3b3270db202db"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z"
#   },
#   {
#     "id": "25599598110",
#     "type": "PushEvent",
#     "actor": {
#       "id": 107352402,
#       "login": "Pr3vYCa",
#       "display_login": "Pr3vYCa",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Pr3vYCa",
#       "avatar_url": "https://avatars.githubusercontent.com/u/107352402?"
#     },
#     "repo": {
#       "id": 573118419,
#       "name": "ALTA-FE10-WENDY/Movie-app-fin",
#       "url": "https://api.github.com/repos/ALTA-FE10-WENDY/Movie-app-fin"
#     },
#     "payload": {
#       "push_id": 11852249359,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "5110bb31c85e33bd5f7e446895151f92551f8cca",
#       "before": "4581400b05c2bf5e864b1987f9ce17b3acb185f1",
#       "commits": [
#         {
#           "sha": "5110bb31c85e33bd5f7e446895151f92551f8cca",
#           "author": {
#             "email": "107352402+Pr3vYCa@users.noreply.github.com",
#             "name": "Pr3vYCa"
#           },
#           "message": "Update README.md",
#           "distinct": true,
#           "url": "https://api.github.com/repos/ALTA-FE10-WENDY/Movie-app-fin/commits/5110bb31c85e33bd5f7e446895151f92551f8cca"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z",
#     "org": {
#       "id": 118798870,
#       "login": "ALTA-FE10-WENDY",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/ALTA-FE10-WENDY",
#       "avatar_url": "https://avatars.githubusercontent.com/u/118798870?"
#     }
#   },
#   {
#     "id": "25599598095",
#     "type": "PullRequestEvent",
#     "actor": {
#       "id": 60792108,
#       "login": "Elijahrane",
#       "display_login": "Elijahrane",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Elijahrane",
#       "avatar_url": "https://avatars.githubusercontent.com/u/60792108?"
#     },
#     "repo": {
#       "id": 454301866,
#       "name": "Nyanotrasen/Nyanotrasen",
#       "url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen"
#     },
#     "payload": {
#       "action": "opened",
#       "number": 740,
#       "pull_request": {
#         "url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/pulls/740",
#         "id": 1142279124,
#         "node_id": "PR_kwDOGxQYqs5EFcvU",
#         "html_url": "https://github.com/Nyanotrasen/Nyanotrasen/pull/740",
#         "diff_url": "https://github.com/Nyanotrasen/Nyanotrasen/pull/740.diff",
#         "patch_url": "https://github.com/Nyanotrasen/Nyanotrasen/pull/740.patch",
#         "issue_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/issues/740",
#         "number": 740,
#         "state": "open",
#         "locked": false,
#         "title": "display locked roles properly for nonwhitelisted",
#         "user": {
#           "login": "Elijahrane",
#           "id": 60792108,
#           "node_id": "MDQ6VXNlcjYwNzkyMTA4",
#           "avatar_url": "https://avatars.githubusercontent.com/u/60792108?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/Elijahrane",
#           "html_url": "https://github.com/Elijahrane",
#           "followers_url": "https://api.github.com/users/Elijahrane/followers",
#           "following_url": "https://api.github.com/users/Elijahrane/following{/other_user}",
#           "gists_url": "https://api.github.com/users/Elijahrane/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/Elijahrane/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/Elijahrane/subscriptions",
#           "organizations_url": "https://api.github.com/users/Elijahrane/orgs",
#           "repos_url": "https://api.github.com/users/Elijahrane/repos",
#           "events_url": "https://api.github.com/users/Elijahrane/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/Elijahrane/received_events",
#           "type": "User",
#           "site_admin": false
#         },
#         "body": ":cl:\r\n- add: Locked roles are now displayed properly for players who are not whitelisted.\r\n",
#         "created_at": "2022-12-01T18:58:23Z",
#         "updated_at": "2022-12-01T18:58:23Z",
#         "closed_at": null,
#         "merged_at": null,
#         "merge_commit_sha": null,
#         "assignee": null,
#         "assignees": [
#
#         ],
#         "requested_reviewers": [
#
#         ],
#         "requested_teams": [
#
#         ],
#         "labels": [
#
#         ],
#         "milestone": null,
#         "draft": false,
#         "commits_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/pulls/740/commits",
#         "review_comments_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/pulls/740/comments",
#         "review_comment_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/pulls/comments{/number}",
#         "comments_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/issues/740/comments",
#         "statuses_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/statuses/3fd8281985516b9661165cfa0f77b237973c4990",
#         "head": {
#           "label": "Elijahrane:whitelistroleUI",
#           "ref": "whitelistroleUI",
#           "sha": "3fd8281985516b9661165cfa0f77b237973c4990",
#           "user": {
#             "login": "Elijahrane",
#             "id": 60792108,
#             "node_id": "MDQ6VXNlcjYwNzkyMTA4",
#             "avatar_url": "https://avatars.githubusercontent.com/u/60792108?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/Elijahrane",
#             "html_url": "https://github.com/Elijahrane",
#             "followers_url": "https://api.github.com/users/Elijahrane/followers",
#             "following_url": "https://api.github.com/users/Elijahrane/following{/other_user}",
#             "gists_url": "https://api.github.com/users/Elijahrane/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/Elijahrane/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/Elijahrane/subscriptions",
#             "organizations_url": "https://api.github.com/users/Elijahrane/orgs",
#             "repos_url": "https://api.github.com/users/Elijahrane/repos",
#             "events_url": "https://api.github.com/users/Elijahrane/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/Elijahrane/received_events",
#             "type": "User",
#             "site_admin": false
#           },
#           "repo": {
#             "id": 485986475,
#             "node_id": "R_kgDOHPeQqw",
#             "name": "arcadia-station",
#             "full_name": "Elijahrane/arcadia-station",
#             "private": false,
#             "owner": {
#               "login": "Elijahrane",
#               "id": 60792108,
#               "node_id": "MDQ6VXNlcjYwNzkyMTA4",
#               "avatar_url": "https://avatars.githubusercontent.com/u/60792108?v=4",
#               "gravatar_id": "",
#               "url": "https://api.github.com/users/Elijahrane",
#               "html_url": "https://github.com/Elijahrane",
#               "followers_url": "https://api.github.com/users/Elijahrane/followers",
#               "following_url": "https://api.github.com/users/Elijahrane/following{/other_user}",
#               "gists_url": "https://api.github.com/users/Elijahrane/gists{/gist_id}",
#               "starred_url": "https://api.github.com/users/Elijahrane/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/Elijahrane/subscriptions",
#               "organizations_url": "https://api.github.com/users/Elijahrane/orgs",
#               "repos_url": "https://api.github.com/users/Elijahrane/repos",
#               "events_url": "https://api.github.com/users/Elijahrane/events{/privacy}",
#               "received_events_url": "https://api.github.com/users/Elijahrane/received_events",
#               "type": "User",
#               "site_admin": false
#             },
#             "html_url": "https://github.com/Elijahrane/arcadia-station",
#             "description": "A multiplayer game about paranoia and chaos on a space station. Remake of the cult-classic Space Station 13.",
#             "fork": true,
#             "url": "https://api.github.com/repos/Elijahrane/arcadia-station",
#             "forks_url": "https://api.github.com/repos/Elijahrane/arcadia-station/forks",
#             "keys_url": "https://api.github.com/repos/Elijahrane/arcadia-station/keys{/key_id}",
#             "collaborators_url": "https://api.github.com/repos/Elijahrane/arcadia-station/collaborators{/collaborator}",
#             "teams_url": "https://api.github.com/repos/Elijahrane/arcadia-station/teams",
#             "hooks_url": "https://api.github.com/repos/Elijahrane/arcadia-station/hooks",
#             "issue_events_url": "https://api.github.com/repos/Elijahrane/arcadia-station/issues/events{/number}",
#             "events_url": "https://api.github.com/repos/Elijahrane/arcadia-station/events",
#             "assignees_url": "https://api.github.com/repos/Elijahrane/arcadia-station/assignees{/user}",
#             "branches_url": "https://api.github.com/repos/Elijahrane/arcadia-station/branches{/branch}",
#             "tags_url": "https://api.github.com/repos/Elijahrane/arcadia-station/tags",
#             "blobs_url": "https://api.github.com/repos/Elijahrane/arcadia-station/git/blobs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/Elijahrane/arcadia-station/git/tags{/sha}",
#             "git_refs_url": "https://api.github.com/repos/Elijahrane/arcadia-station/git/refs{/sha}",
#             "trees_url": "https://api.github.com/repos/Elijahrane/arcadia-station/git/trees{/sha}",
#             "statuses_url": "https://api.github.com/repos/Elijahrane/arcadia-station/statuses/{sha}",
#             "languages_url": "https://api.github.com/repos/Elijahrane/arcadia-station/languages",
#             "stargazers_url": "https://api.github.com/repos/Elijahrane/arcadia-station/stargazers",
#             "contributors_url": "https://api.github.com/repos/Elijahrane/arcadia-station/contributors",
#             "subscribers_url": "https://api.github.com/repos/Elijahrane/arcadia-station/subscribers",
#             "subscription_url": "https://api.github.com/repos/Elijahrane/arcadia-station/subscription",
#             "commits_url": "https://api.github.com/repos/Elijahrane/arcadia-station/commits{/sha}",
#             "git_commits_url": "https://api.github.com/repos/Elijahrane/arcadia-station/git/commits{/sha}",
#             "comments_url": "https://api.github.com/repos/Elijahrane/arcadia-station/comments{/number}",
#             "issue_comment_url": "https://api.github.com/repos/Elijahrane/arcadia-station/issues/comments{/number}",
#             "contents_url": "https://api.github.com/repos/Elijahrane/arcadia-station/contents/{+path}",
#             "compare_url": "https://api.github.com/repos/Elijahrane/arcadia-station/compare/{base}...{head}",
#             "merges_url": "https://api.github.com/repos/Elijahrane/arcadia-station/merges",
#             "archive_url": "https://api.github.com/repos/Elijahrane/arcadia-station/{archive_format}{/ref}",
#             "downloads_url": "https://api.github.com/repos/Elijahrane/arcadia-station/downloads",
#             "issues_url": "https://api.github.com/repos/Elijahrane/arcadia-station/issues{/number}",
#             "pulls_url": "https://api.github.com/repos/Elijahrane/arcadia-station/pulls{/number}",
#             "milestones_url": "https://api.github.com/repos/Elijahrane/arcadia-station/milestones{/number}",
#             "notifications_url": "https://api.github.com/repos/Elijahrane/arcadia-station/notifications{?since,all,participating}",
#             "labels_url": "https://api.github.com/repos/Elijahrane/arcadia-station/labels{/name}",
#             "releases_url": "https://api.github.com/repos/Elijahrane/arcadia-station/releases{/id}",
#             "deployments_url": "https://api.github.com/repos/Elijahrane/arcadia-station/deployments",
#             "created_at": "2022-04-27T00:04:28Z",
#             "updated_at": "2022-09-07T09:50:18Z",
#             "pushed_at": "2022-12-01T18:57:57Z",
#             "git_url": "git://github.com/Elijahrane/arcadia-station.git",
#             "ssh_url": "git@github.com:Elijahrane/arcadia-station.git",
#             "clone_url": "https://github.com/Elijahrane/arcadia-station.git",
#             "svn_url": "https://github.com/Elijahrane/arcadia-station",
#             "homepage": "https://spacestation14.io",
#             "size": 356141,
#             "stargazers_count": 0,
#             "watchers_count": 0,
#             "language": "C#",
#             "has_issues": false,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": false,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 0,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 0,
#             "license": {
#               "key": "mit",
#               "name": "MIT License",
#               "spdx_id": "MIT",
#               "url": "https://api.github.com/licenses/mit",
#               "node_id": "MDc6TGljZW5zZTEz"
#             },
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [
#
#             ],
#             "visibility": "public",
#             "forks": 0,
#             "open_issues": 0,
#             "watchers": 0,
#             "default_branch": "master"
#           }
#         },
#         "base": {
#           "label": "Nyanotrasen:master",
#           "ref": "master",
#           "sha": "76a5d62a3e0ce83e5e6dbbea236dfbe216e88cd9",
#           "user": {
#             "login": "Nyanotrasen",
#             "id": 96618363,
#             "node_id": "O_kgDOBcJHew",
#             "avatar_url": "https://avatars.githubusercontent.com/u/96618363?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/Nyanotrasen",
#             "html_url": "https://github.com/Nyanotrasen",
#             "followers_url": "https://api.github.com/users/Nyanotrasen/followers",
#             "following_url": "https://api.github.com/users/Nyanotrasen/following{/other_user}",
#             "gists_url": "https://api.github.com/users/Nyanotrasen/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/Nyanotrasen/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/Nyanotrasen/subscriptions",
#             "organizations_url": "https://api.github.com/users/Nyanotrasen/orgs",
#             "repos_url": "https://api.github.com/users/Nyanotrasen/repos",
#             "events_url": "https://api.github.com/users/Nyanotrasen/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/Nyanotrasen/received_events",
#             "type": "Organization",
#             "site_admin": false
#           },
#           "repo": {
#             "id": 454301866,
#             "node_id": "R_kgDOGxQYqg",
#             "name": "Nyanotrasen",
#             "full_name": "Nyanotrasen/Nyanotrasen",
#             "private": false,
#             "owner": {
#               "login": "Nyanotrasen",
#               "id": 96618363,
#               "node_id": "O_kgDOBcJHew",
#               "avatar_url": "https://avatars.githubusercontent.com/u/96618363?v=4",
#               "gravatar_id": "",
#               "url": "https://api.github.com/users/Nyanotrasen",
#               "html_url": "https://github.com/Nyanotrasen",
#               "followers_url": "https://api.github.com/users/Nyanotrasen/followers",
#               "following_url": "https://api.github.com/users/Nyanotrasen/following{/other_user}",
#               "gists_url": "https://api.github.com/users/Nyanotrasen/gists{/gist_id}",
#               "starred_url": "https://api.github.com/users/Nyanotrasen/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/Nyanotrasen/subscriptions",
#               "organizations_url": "https://api.github.com/users/Nyanotrasen/orgs",
#               "repos_url": "https://api.github.com/users/Nyanotrasen/repos",
#               "events_url": "https://api.github.com/users/Nyanotrasen/events{/privacy}",
#               "received_events_url": "https://api.github.com/users/Nyanotrasen/received_events",
#               "type": "Organization",
#               "site_admin": false
#             },
#             "html_url": "https://github.com/Nyanotrasen/Nyanotrasen",
#             "description": "A fork of Space Station 14, embracing a mixture of classic SS13 chaos and experimentation only possibly with the new engine",
#             "fork": false,
#             "url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen",
#             "forks_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/forks",
#             "keys_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/keys{/key_id}",
#             "collaborators_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/collaborators{/collaborator}",
#             "teams_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/teams",
#             "hooks_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/hooks",
#             "issue_events_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/issues/events{/number}",
#             "events_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/events",
#             "assignees_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/assignees{/user}",
#             "branches_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/branches{/branch}",
#             "tags_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/tags",
#             "blobs_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/git/blobs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/git/tags{/sha}",
#             "git_refs_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/git/refs{/sha}",
#             "trees_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/git/trees{/sha}",
#             "statuses_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/statuses/{sha}",
#             "languages_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/languages",
#             "stargazers_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/stargazers",
#             "contributors_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/contributors",
#             "subscribers_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/subscribers",
#             "subscription_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/subscription",
#             "commits_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/commits{/sha}",
#             "git_commits_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/git/commits{/sha}",
#             "comments_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/comments{/number}",
#             "issue_comment_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/issues/comments{/number}",
#             "contents_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/contents/{+path}",
#             "compare_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/compare/{base}...{head}",
#             "merges_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/merges",
#             "archive_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/{archive_format}{/ref}",
#             "downloads_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/downloads",
#             "issues_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/issues{/number}",
#             "pulls_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/pulls{/number}",
#             "milestones_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/milestones{/number}",
#             "notifications_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/notifications{?since,all,participating}",
#             "labels_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/labels{/name}",
#             "releases_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/releases{/id}",
#             "deployments_url": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/deployments",
#             "created_at": "2022-02-01T07:49:39Z",
#             "updated_at": "2022-11-28T17:57:59Z",
#             "pushed_at": "2022-12-01T06:03:17Z",
#             "git_url": "git://github.com/Nyanotrasen/Nyanotrasen.git",
#             "ssh_url": "git@github.com:Nyanotrasen/Nyanotrasen.git",
#             "clone_url": "https://github.com/Nyanotrasen/Nyanotrasen.git",
#             "svn_url": "https://github.com/Nyanotrasen/Nyanotrasen",
#             "homepage": "https://www.nyanotrasen.moe",
#             "size": 355028,
#             "stargazers_count": 11,
#             "watchers_count": 11,
#             "language": "C#",
#             "has_issues": true,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": false,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 52,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 12,
#             "license": {
#               "key": "mit",
#               "name": "MIT License",
#               "spdx_id": "MIT",
#               "url": "https://api.github.com/licenses/mit",
#               "node_id": "MDc6TGljZW5zZTEz"
#             },
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [
#
#             ],
#             "visibility": "public",
#             "forks": 52,
#             "open_issues": 12,
#             "watchers": 11,
#             "default_branch": "master"
#           }
#         },
#         "_links": {
#           "self": {
#             "href": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/pulls/740"
#           },
#           "html": {
#             "href": "https://github.com/Nyanotrasen/Nyanotrasen/pull/740"
#           },
#           "issue": {
#             "href": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/issues/740"
#           },
#           "comments": {
#             "href": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/issues/740/comments"
#           },
#           "review_comments": {
#             "href": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/pulls/740/comments"
#           },
#           "review_comment": {
#             "href": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/pulls/comments{/number}"
#           },
#           "commits": {
#             "href": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/pulls/740/commits"
#           },
#           "statuses": {
#             "href": "https://api.github.com/repos/Nyanotrasen/Nyanotrasen/statuses/3fd8281985516b9661165cfa0f77b237973c4990"
#           }
#         },
#         "author_association": "CONTRIBUTOR",
#         "auto_merge": null,
#         "active_lock_reason": null,
#         "merged": false,
#         "mergeable": null,
#         "rebaseable": null,
#         "mergeable_state": "unknown",
#         "merged_by": null,
#         "comments": 0,
#         "review_comments": 0,
#         "maintainer_can_modify": true,
#         "commits": 1,
#         "additions": 55,
#         "deletions": 0,
#         "changed_files": 4
#       }
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z",
#     "org": {
#       "id": 96618363,
#       "login": "Nyanotrasen",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/Nyanotrasen",
#       "avatar_url": "https://avatars.githubusercontent.com/u/96618363?"
#     }
#   },
#   {
#     "id": "25599598143",
#     "type": "PushEvent",
#     "actor": {
#       "id": 117247930,
#       "login": "rahulratan12",
#       "display_login": "rahulratan12",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/rahulratan12",
#       "avatar_url": "https://avatars.githubusercontent.com/u/117247930?"
#     },
#     "repo": {
#       "id": 573123093,
#       "name": "rahulratan12/class2-Basics-of-Python-Primitive-Data-Types-Comments-Variables--CipherSchools.py",
#       "url": "https://api.github.com/repos/rahulratan12/class2-Basics-of-Python-Primitive-Data-Types-Comments-Variables--CipherSchools.py"
#     },
#     "payload": {
#       "push_id": 11852249360,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "aa9ad1d5315e0bcbfae3378f76f77a285e480c00",
#       "before": "e9a32b0f05fa62aefb0f89aba2cd295bc9541374",
#       "commits": [
#         {
#           "sha": "aa9ad1d5315e0bcbfae3378f76f77a285e480c00",
#           "author": {
#             "email": "117247930+rahulratan12@users.noreply.github.com",
#             "name": "Rahul Ratan"
#           },
#           "message": "Create class5-Operators and Expressions-CipherSchools.py",
#           "distinct": true,
#           "url": "https://api.github.com/repos/rahulratan12/class2-Basics-of-Python-Primitive-Data-Types-Comments-Variables--CipherSchools.py/commits/aa9ad1d5315e0bcbfae3378f76f77a285e480c00"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z"
#   },
#   {
#     "id": "25599598185",
#     "type": "PushEvent",
#     "actor": {
#       "id": 117497949,
#       "login": "fahmemoh",
#       "display_login": "fahmemoh",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/fahmemoh",
#       "avatar_url": "https://avatars.githubusercontent.com/u/117497949?"
#     },
#     "repo": {
#       "id": 572743889,
#       "name": "fahmemoh/alx-system_engineering-devops",
#       "url": "https://api.github.com/repos/fahmemoh/alx-system_engineering-devops"
#     },
#     "payload": {
#       "push_id": 11852249391,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/master",
#       "head": "1b02a65f2b88c8d3bf6dffe9376352d8848913ee",
#       "before": "b9d7f40f4829c1051dda2c72b300d4392537ed95",
#       "commits": [
#         {
#           "sha": "1b02a65f2b88c8d3bf6dffe9376352d8848913ee",
#           "author": {
#             "email": "fahmenuri@yahoo.com",
#             "name": "fahmemoh"
#           },
#           "message": "John doe",
#           "distinct": true,
#           "url": "https://api.github.com/repos/fahmemoh/alx-system_engineering-devops/commits/1b02a65f2b88c8d3bf6dffe9376352d8848913ee"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z"
#   },
#   {
#     "id": "25599598153",
#     "type": "PullRequestEvent",
#     "actor": {
#       "id": 113173044,
#       "login": "Bojo856",
#       "display_login": "Bojo856",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Bojo856",
#       "avatar_url": "https://avatars.githubusercontent.com/u/113173044?"
#     },
#     "repo": {
#       "id": 572194341,
#       "name": "JedrzejRy/serwis-aukcyjny",
#       "url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny"
#     },
#     "payload": {
#       "action": "opened",
#       "number": 9,
#       "pull_request": {
#         "url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/pulls/9",
#         "id": 1142279119,
#         "node_id": "PR_kwDOIhr-Jc5EFcvP",
#         "html_url": "https://github.com/JedrzejRy/serwis-aukcyjny/pull/9",
#         "diff_url": "https://github.com/JedrzejRy/serwis-aukcyjny/pull/9.diff",
#         "patch_url": "https://github.com/JedrzejRy/serwis-aukcyjny/pull/9.patch",
#         "issue_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/issues/9",
#         "number": 9,
#         "state": "open",
#         "locked": false,
#         "title": "UserService",
#         "user": {
#           "login": "Bojo856",
#           "id": 113173044,
#           "node_id": "U_kgDOBr7iNA",
#           "avatar_url": "https://avatars.githubusercontent.com/u/113173044?v=4",
#           "gravatar_id": "",
#           "url": "https://api.github.com/users/Bojo856",
#           "html_url": "https://github.com/Bojo856",
#           "followers_url": "https://api.github.com/users/Bojo856/followers",
#           "following_url": "https://api.github.com/users/Bojo856/following{/other_user}",
#           "gists_url": "https://api.github.com/users/Bojo856/gists{/gist_id}",
#           "starred_url": "https://api.github.com/users/Bojo856/starred{/owner}{/repo}",
#           "subscriptions_url": "https://api.github.com/users/Bojo856/subscriptions",
#           "organizations_url": "https://api.github.com/users/Bojo856/orgs",
#           "repos_url": "https://api.github.com/users/Bojo856/repos",
#           "events_url": "https://api.github.com/users/Bojo856/events{/privacy}",
#           "received_events_url": "https://api.github.com/users/Bojo856/received_events",
#           "type": "User",
#           "site_admin": false
#         },
#         "body": null,
#         "created_at": "2022-12-01T18:58:23Z",
#         "updated_at": "2022-12-01T18:58:23Z",
#         "closed_at": null,
#         "merged_at": null,
#         "merge_commit_sha": null,
#         "assignee": null,
#         "assignees": [
#
#         ],
#         "requested_reviewers": [
#
#         ],
#         "requested_teams": [
#
#         ],
#         "labels": [
#
#         ],
#         "milestone": null,
#         "draft": false,
#         "commits_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/pulls/9/commits",
#         "review_comments_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/pulls/9/comments",
#         "review_comment_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/pulls/comments{/number}",
#         "comments_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/issues/9/comments",
#         "statuses_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/statuses/34bfb9dc19f4e9346d47d19de1cbd795ef6b45e6",
#         "head": {
#           "label": "JedrzejRy:userService",
#           "ref": "userService",
#           "sha": "34bfb9dc19f4e9346d47d19de1cbd795ef6b45e6",
#           "user": {
#             "login": "JedrzejRy",
#             "id": 107132992,
#             "node_id": "U_kgDOBmK4QA",
#             "avatar_url": "https://avatars.githubusercontent.com/u/107132992?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/JedrzejRy",
#             "html_url": "https://github.com/JedrzejRy",
#             "followers_url": "https://api.github.com/users/JedrzejRy/followers",
#             "following_url": "https://api.github.com/users/JedrzejRy/following{/other_user}",
#             "gists_url": "https://api.github.com/users/JedrzejRy/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/JedrzejRy/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/JedrzejRy/subscriptions",
#             "organizations_url": "https://api.github.com/users/JedrzejRy/orgs",
#             "repos_url": "https://api.github.com/users/JedrzejRy/repos",
#             "events_url": "https://api.github.com/users/JedrzejRy/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/JedrzejRy/received_events",
#             "type": "User",
#             "site_admin": false
#           },
#           "repo": {
#             "id": 572194341,
#             "node_id": "R_kgDOIhr-JQ",
#             "name": "serwis-aukcyjny",
#             "full_name": "JedrzejRy/serwis-aukcyjny",
#             "private": false,
#             "owner": {
#               "login": "JedrzejRy",
#               "id": 107132992,
#               "node_id": "U_kgDOBmK4QA",
#               "avatar_url": "https://avatars.githubusercontent.com/u/107132992?v=4",
#               "gravatar_id": "",
#               "url": "https://api.github.com/users/JedrzejRy",
#               "html_url": "https://github.com/JedrzejRy",
#               "followers_url": "https://api.github.com/users/JedrzejRy/followers",
#               "following_url": "https://api.github.com/users/JedrzejRy/following{/other_user}",
#               "gists_url": "https://api.github.com/users/JedrzejRy/gists{/gist_id}",
#               "starred_url": "https://api.github.com/users/JedrzejRy/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/JedrzejRy/subscriptions",
#               "organizations_url": "https://api.github.com/users/JedrzejRy/orgs",
#               "repos_url": "https://api.github.com/users/JedrzejRy/repos",
#               "events_url": "https://api.github.com/users/JedrzejRy/events{/privacy}",
#               "received_events_url": "https://api.github.com/users/JedrzejRy/received_events",
#               "type": "User",
#               "site_admin": false
#             },
#             "html_url": "https://github.com/JedrzejRy/serwis-aukcyjny",
#             "description": null,
#             "fork": false,
#             "url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny",
#             "forks_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/forks",
#             "keys_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/keys{/key_id}",
#             "collaborators_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/collaborators{/collaborator}",
#             "teams_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/teams",
#             "hooks_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/hooks",
#             "issue_events_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/issues/events{/number}",
#             "events_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/events",
#             "assignees_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/assignees{/user}",
#             "branches_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/branches{/branch}",
#             "tags_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/tags",
#             "blobs_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/git/blobs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/git/tags{/sha}",
#             "git_refs_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/git/refs{/sha}",
#             "trees_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/git/trees{/sha}",
#             "statuses_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/statuses/{sha}",
#             "languages_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/languages",
#             "stargazers_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/stargazers",
#             "contributors_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/contributors",
#             "subscribers_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/subscribers",
#             "subscription_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/subscription",
#             "commits_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/commits{/sha}",
#             "git_commits_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/git/commits{/sha}",
#             "comments_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/comments{/number}",
#             "issue_comment_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/issues/comments{/number}",
#             "contents_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/contents/{+path}",
#             "compare_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/compare/{base}...{head}",
#             "merges_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/merges",
#             "archive_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/{archive_format}{/ref}",
#             "downloads_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/downloads",
#             "issues_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/issues{/number}",
#             "pulls_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/pulls{/number}",
#             "milestones_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/milestones{/number}",
#             "notifications_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/notifications{?since,all,participating}",
#             "labels_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/labels{/name}",
#             "releases_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/releases{/id}",
#             "deployments_url": "https://api.github.com/repos/JedrzejRy/serwis-aukcyjny/deployments",
#             "created_at": "2022-11-29T18:48:57Z",
#             "updated_at": "2022-11-29T18:51:09Z",
#             "pushed_at": "2022-12-01T18:58:24Z",
#             "git_url": "git://github.com/JedrzejRy/serwis-aukcyjny.git",
#             "ssh_url": "git@github.com:JedrzejRy/serwis-aukcyjny.git",
#             "clone_url": "https://github.com/JedrzejRy/serwis-aukcyjny.git",
#             "svn_url": "https://github.com/JedrzejRy/serwis-aukcyjny",
#             "homepage": null,
#             "size": 76,
#             "stargazers_count": 1,
#             "watchers_count": 1,
#             "language": "Java",
#             "has_issues": true,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": true,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 0,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 1,
#             "license": null,
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [
#
#             ],
#             "visibility": "public",
#             "forks": 0,
#             "open_issues": 1,
#             "watchers": 1,
#             "default_branch": "master"
#           }
#         },
#         "base": {
#           "label": "JedrzejRy:master",
#           "ref": "master",
#           "sha": "994e386703235b4906f55067098e3228ce8a34f9",
#           "user": {
#             "login": "JedrzejRy",
#             "id": 107132992,
#             "node_id": "U_kgDOBmK4QA",
#             "avatar_url": "https://avatars.githubusercontent.com/u/107132992?v=4",
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/JedrzejRy",
#             "html_url": "https://github.com/JedrzejRy",
#             "followers_url": "https://api.github.com/users/JedrzejRy/followers",
# ...
#             "gravatar_id": "",
#             "url": "https://api.github.com/users/AudiusProject",
#             "html_url": "https://github.com/AudiusProject",
#             "followers_url": "https://api.github.com/users/AudiusProject/followers",
#             "following_url": "https://api.github.com/users/AudiusProject/following{/other_user}",
#             "gists_url": "https://api.github.com/users/AudiusProject/gists{/gist_id}",
#             "starred_url": "https://api.github.com/users/AudiusProject/starred{/owner}{/repo}",
#             "subscriptions_url": "https://api.github.com/users/AudiusProject/subscriptions",
#             "organizations_url": "https://api.github.com/users/AudiusProject/orgs",
#             "repos_url": "https://api.github.com/users/AudiusProject/repos",
#             "events_url": "https://api.github.com/users/AudiusProject/events{/privacy}",
#             "received_events_url": "https://api.github.com/users/AudiusProject/received_events",
#             "type": "Organization",
#             "site_admin": false
#           },
#           "repo": {
#             "id": 288249709,
#             "node_id": "MDEwOlJlcG9zaXRvcnkyODgyNDk3MDk=",
#             "name": "audius-client",
#             "full_name": "AudiusProject/audius-client",
#             "private": false,
#             "owner": {
#               "login": "AudiusProject",
#               "id": 38231615,
#               "node_id": "MDEyOk9yZ2FuaXphdGlvbjM4MjMxNjE1",
#               "avatar_url": "https://avatars.githubusercontent.com/u/38231615?v=4",
#               "gravatar_id": "",
#               "url": "https://api.github.com/users/AudiusProject",
#               "html_url": "https://github.com/AudiusProject",
#               "followers_url": "https://api.github.com/users/AudiusProject/followers",
#               "following_url": "https://api.github.com/users/AudiusProject/following{/other_user}",
#               "gists_url": "https://api.github.com/users/AudiusProject/gists{/gist_id}",
#               "starred_url": "https://api.github.com/users/AudiusProject/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/AudiusProject/subscriptions",
#               "organizations_url": "https://api.github.com/users/AudiusProject/orgs",
#               "repos_url": "https://api.github.com/users/AudiusProject/repos",
#               "events_url": "https://api.github.com/users/AudiusProject/events{/privacy}",
#               "received_events_url": "https://api.github.com/users/AudiusProject/received_events",
#               "type": "Organization",
#               "site_admin": false
#             },
#             "html_url": "https://github.com/AudiusProject/audius-client",
#             "description": "The Audius client monorepo",
#             "fork": false,
#             "url": "https://api.github.com/repos/AudiusProject/audius-client",
#             "forks_url": "https://api.github.com/repos/AudiusProject/audius-client/forks",
#             "keys_url": "https://api.github.com/repos/AudiusProject/audius-client/keys{/key_id}",
#             "collaborators_url": "https://api.github.com/repos/AudiusProject/audius-client/collaborators{/collaborator}",
#             "teams_url": "https://api.github.com/repos/AudiusProject/audius-client/teams",
#             "hooks_url": "https://api.github.com/repos/AudiusProject/audius-client/hooks",
#             "issue_events_url": "https://api.github.com/repos/AudiusProject/audius-client/issues/events{/number}",
#             "events_url": "https://api.github.com/repos/AudiusProject/audius-client/events",
#             "assignees_url": "https://api.github.com/repos/AudiusProject/audius-client/assignees{/user}",
#             "branches_url": "https://api.github.com/repos/AudiusProject/audius-client/branches{/branch}",
#             "tags_url": "https://api.github.com/repos/AudiusProject/audius-client/tags",
#             "blobs_url": "https://api.github.com/repos/AudiusProject/audius-client/git/blobs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/AudiusProject/audius-client/git/tags{/sha}",
#             "git_refs_url": "https://api.github.com/repos/AudiusProject/audius-client/git/refs{/sha}",
#             "trees_url": "https://api.github.com/repos/AudiusProject/audius-client/git/trees{/sha}",
#             "statuses_url": "https://api.github.com/repos/AudiusProject/audius-client/statuses/{sha}",
#             "languages_url": "https://api.github.com/repos/AudiusProject/audius-client/languages",
#             "stargazers_url": "https://api.github.com/repos/AudiusProject/audius-client/stargazers",
#             "contributors_url": "https://api.github.com/repos/AudiusProject/audius-client/contributors",
#             "subscribers_url": "https://api.github.com/repos/AudiusProject/audius-client/subscribers",
#             "subscription_url": "https://api.github.com/repos/AudiusProject/audius-client/subscription",
#             "commits_url": "https://api.github.com/repos/AudiusProject/audius-client/commits{/sha}",
#             "git_commits_url": "https://api.github.com/repos/AudiusProject/audius-client/git/commits{/sha}",
#             "comments_url": "https://api.github.com/repos/AudiusProject/audius-client/comments{/number}",
#             "issue_comment_url": "https://api.github.com/repos/AudiusProject/audius-client/issues/comments{/number}",
#             "contents_url": "https://api.github.com/repos/AudiusProject/audius-client/contents/{+path}",
#             "compare_url": "https://api.github.com/repos/AudiusProject/audius-client/compare/{base}...{head}",
#             "merges_url": "https://api.github.com/repos/AudiusProject/audius-client/merges",
#             "archive_url": "https://api.github.com/repos/AudiusProject/audius-client/{archive_format}{/ref}",
#             "downloads_url": "https://api.github.com/repos/AudiusProject/audius-client/downloads",
#             "issues_url": "https://api.github.com/repos/AudiusProject/audius-client/issues{/number}",
#             "pulls_url": "https://api.github.com/repos/AudiusProject/audius-client/pulls{/number}",
#             "milestones_url": "https://api.github.com/repos/AudiusProject/audius-client/milestones{/number}",
#             "notifications_url": "https://api.github.com/repos/AudiusProject/audius-client/notifications{?since,all,participating}",
#             "labels_url": "https://api.github.com/repos/AudiusProject/audius-client/labels{/name}",
#             "releases_url": "https://api.github.com/repos/AudiusProject/audius-client/releases{/id}",
#             "deployments_url": "https://api.github.com/repos/AudiusProject/audius-client/deployments",
#             "created_at": "2020-08-17T17:56:52Z",
#             "updated_at": "2022-12-01T18:00:54Z",
#             "pushed_at": "2022-12-01T18:57:44Z",
#             "git_url": "git://github.com/AudiusProject/audius-client.git",
#             "ssh_url": "git@github.com:AudiusProject/audius-client.git",
#             "clone_url": "https://github.com/AudiusProject/audius-client.git",
#             "svn_url": "https://github.com/AudiusProject/audius-client",
#             "homepage": "https://audius.co",
#             "size": 160616,
#             "stargazers_count": 177,
#             "watchers_count": 177,
#             "language": "TypeScript",
#             "has_issues": true,
#             "has_projects": true,
#             "has_downloads": true,
#             "has_wiki": true,
#             "has_pages": false,
#             "has_discussions": false,
#             "forks_count": 40,
#             "mirror_url": null,
#             "archived": false,
#             "disabled": false,
#             "open_issues_count": 36,
#             "license": null,
#             "allow_forking": true,
#             "is_template": false,
#             "web_commit_signoff_required": false,
#             "topics": [
#
#             ],
#             "visibility": "public",
#             "forks": 40,
#             "open_issues": 36,
#             "watchers": 177,
#             "default_branch": "main"
#           }
#         },
#         "_links": {
#           "self": {
#             "href": "https://api.github.com/repos/AudiusProject/audius-client/pulls/2335"
#           },
#           "html": {
#             "href": "https://github.com/AudiusProject/audius-client/pull/2335"
#           },
#           "issue": {
#             "href": "https://api.github.com/repos/AudiusProject/audius-client/issues/2335"
#           },
#           "comments": {
#             "href": "https://api.github.com/repos/AudiusProject/audius-client/issues/2335/comments"
#           },
#           "review_comments": {
#             "href": "https://api.github.com/repos/AudiusProject/audius-client/pulls/2335/comments"
#           },
#           "review_comment": {
#             "href": "https://api.github.com/repos/AudiusProject/audius-client/pulls/comments{/number}"
#           },
#           "commits": {
#             "href": "https://api.github.com/repos/AudiusProject/audius-client/pulls/2335/commits"
#           },
#           "statuses": {
#             "href": "https://api.github.com/repos/AudiusProject/audius-client/statuses/20e87dcfc913647636b06cca176279c9bff25b3d"
#           }
#         },
#         "author_association": "CONTRIBUTOR",
#         "auto_merge": null,
#         "active_lock_reason": null
#       }
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z",
#     "org": {
#       "id": 38231615,
#       "login": "AudiusProject",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/AudiusProject",
#       "avatar_url": "https://avatars.githubusercontent.com/u/38231615?"
#     }
#   },
#   {
#     "id": "25599598064",
#     "type": "PushEvent",
#     "actor": {
#       "id": 1334561,
#       "login": "eweitz",
#       "display_login": "eweitz",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/eweitz",
#       "avatar_url": "https://avatars.githubusercontent.com/u/1334561?"
#     },
#     "repo": {
#       "id": 54125413,
#       "name": "broadinstitute/single_cell_portal_core",
#       "url": "https://api.github.com/repos/broadinstitute/single_cell_portal_core"
#     },
#     "payload": {
#       "push_id": 11852249300,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/ew-fix-image-pipeline",
#       "head": "f2ec205d98779950c05425ee13b8a046822e3501",
#       "before": "c2b09004304e09495f535573c2fafda40ba940f3",
#       "commits": [
#         {
#           "sha": "f2ec205d98779950c05425ee13b8a046822e3501",
#           "author": {
#             "email": "eweitz@broadinstitute.org",
#             "name": "Eric Weitz"
#           },
#           "message": "Update Image Pipeline build",
#           "distinct": true,
#           "url": "https://api.github.com/repos/broadinstitute/single_cell_portal_core/commits/f2ec205d98779950c05425ee13b8a046822e3501"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z",
#     "org": {
#       "id": 393552,
#       "login": "broadinstitute",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/broadinstitute",
#       "avatar_url": "https://avatars.githubusercontent.com/u/393552?"
#     }
#   },
#   {
#     "id": "25599598100",
#     "type": "PushEvent",
#     "actor": {
#       "id": 90176376,
#       "login": "Ozirska",
#       "display_login": "Ozirska",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/Ozirska",
#       "avatar_url": "https://avatars.githubusercontent.com/u/90176376?"
#     },
#     "repo": {
#       "id": 435880643,
#       "name": "Ozirska/JSlessons",
#       "url": "https://api.github.com/repos/Ozirska/JSlessons"
#     },
#     "payload": {
#       "push_id": 11852249333,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/master",
#       "head": "6c1c86d55ecfa84d31e2273a0c2efb715024471b",
#       "before": "a68d2a71820bdaa30aecfcc294618014d0354314",
#       "commits": [
#         {
#           "sha": "6c1c86d55ecfa84d31e2273a0c2efb715024471b",
#           "author": {
#             "email": "m.ozirska2000@gmail.com",
#             "name": "Ozirska"
#           },
#           "message": "c",
#           "distinct": true,
#           "url": "https://api.github.com/repos/Ozirska/JSlessons/commits/6c1c86d55ecfa84d31e2273a0c2efb715024471b"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z"
#   },
#   {
#     "id": "25599598028",
#     "type": "PushEvent",
#     "actor": {
#       "id": 56741989,
#       "login": "copybara-service[bot]",
#       "display_login": "copybara-service",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/copybara-service[bot]",
#       "avatar_url": "https://avatars.githubusercontent.com/u/56741989?"
#     },
#     "repo": {
#       "id": 35726310,
#       "name": "dart-lang/sdk",
#       "url": "https://api.github.com/repos/dart-lang/sdk"
#     },
#     "payload": {
#       "push_id": 11852249276,
#       "size": 1,
#       "distinct_size": 0,
#       "ref": "refs/heads/main",
#       "head": "b0c705e4bdb2af5511f254c5c65e6fcfed9e9ac7",
#       "before": "1f42c2a6f3e03d787d1a96658f85c9a29419151e",
#       "commits": [
#         {
#           "sha": "b0c705e4bdb2af5511f254c5c65e6fcfed9e9ac7",
#           "author": {
#             "email": "paulberry@google.com",
#             "name": "Paul Berry"
#           },
#           "message": "Set mayParseFunctionExpressions properly during switch expression parsing.\n\nWe need to prohibit function expressions during guard clauses in\nswitch expressions, otherwise the `=>` might be misinterpreted.\n\nFixes #50591.\n\nBug: https://github.com/dart-lang/sdk/issues/50591, https://github.com/dart-lang/language/issues/2672\nChange-Id: Ie5703ac7049557798b19778281429e8a591cf09f\nReviewed-on: https://dart-review.googlesource.com/c/sdk/+/273020\nReviewed-by: Konstantin Shcheglov <scheglov@google.com>\nCommit-Queue: Paul Berry <paulberry@google.com>",
#           "distinct": false,
#           "url": "https://api.github.com/repos/dart-lang/sdk/commits/b0c705e4bdb2af5511f254c5c65e6fcfed9e9ac7"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z",
#     "org": {
#       "id": 1609975,
#       "login": "dart-lang",
#       "gravatar_id": "",
#       "url": "https://api.github.com/orgs/dart-lang",
#       "avatar_url": "https://avatars.githubusercontent.com/u/1609975?"
#     }
#   },
#   {
#     "id": "25599598098",
#     "type": "PushEvent",
#     "actor": {
#       "id": 110097131,
#       "login": "stepansaint",
#       "display_login": "stepansaint",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/stepansaint",
#       "avatar_url": "https://avatars.githubusercontent.com/u/110097131?"
#     },
#     "repo": {
#       "id": 570195036,
#       "name": "stepansaint/Harvard-CS50x",
#       "url": "https://api.github.com/repos/stepansaint/Harvard-CS50x"
#     },
#     "payload": {
#       "push_id": 11852249353,
#       "size": 1,
#       "distinct_size": 1,
#       "ref": "refs/heads/main",
#       "head": "f2bb85cfbef7449ba8118ebdc4fb8ac1e25d0f23",
#       "before": "2921ac2b29709ca6ef084eaa48cc4bb1469027f7",
#       "commits": [
#         {
#           "sha": "f2bb85cfbef7449ba8118ebdc4fb8ac1e25d0f23",
#           "author": {
#             "email": "110097131+stepansaint@users.noreply.github.com",
#             "name": "Ermakov Stepan"
#           },
#           "message": "Update README",
#           "distinct": true,
#           "url": "https://api.github.com/repos/stepansaint/Harvard-CS50x/commits/f2bb85cfbef7449ba8118ebdc4fb8ac1e25d0f23"
#         }
#       ]
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z"
#   },
#   {
#     "id": "25599598067",
#     "type": "CreateEvent",
#     "actor": {
#       "id": 1357325,
#       "login": "xPiwel",
#       "display_login": "xPiwel",
#       "gravatar_id": "",
#       "url": "https://api.github.com/users/xPiwel",
#       "avatar_url": "https://avatars.githubusercontent.com/u/1357325?"
#     },
#     "repo": {
#       "id": 573127712,
#       "name": "xPiwel/Testrepo",
#       "url": "https://api.github.com/repos/xPiwel/Testrepo"
#     },
#     "payload": {
#       "ref": "main",
#       "ref_type": "branch",
#       "master_branch": "main",
#       "description": null,
#       "pusher_type": "user"
#     },
#     "public": true,
#     "created_at": "2022-12-01T18:58:24Z"
#   }
# ]

# %%
# %%!
#
# docker-compose pull
# docker-compose up web

# %% [markdown]
# #### 导入历史数据
#
# 由于通过 `/events` API 我们无法完全获取到所有的历史数据, 在 OSS Insight 的数据准备阶段，我们利用了 [GH Archive](https://gharchive.org) 上归档数据，将其导入数据库当中.
#
# | Query | Downloadable Files |
# | ---- | ---- |
# | Activity for 1/1/2015 @ 3PM UTC |	`https://data.gharchive.org/2015-01-01-15.json.gz` |
# | Activity for 1/1/2015 | `https://data.gharchive.org/2015-01-01-{0..23}.json.gz` |
# | Activity for all of January 2015 | `https://data.gharchive.org/2015-01-{01..31}-{0..23}.json.gz` |
#
# 为了方便演示我们在 AWS S3 上保存了一份示例数据，你可以使用 TiDB Cloud 的 Import 功能将其导入数据库当中：
#
# S3 URI:
#
# ```
# s3://ossinsight/workshop/oss_database_sample/
# ```
#
# Role ARN:
#
# ```
# arn:aws:iam::494090988690:role/tidb-cloud-reader
# ```

# %% [markdown]
# ## 一些背景知识

# %% [markdown]
# #### 优化器
#
# SQL 是一种声明式语言，而非过程性的语言。也就是说，它描述的是最终结果应该如何，而非按顺序执行的步骤。因此在 TiDB 在处理 SQL 语句的过程中，除了要确保能够正确返回语句所描述的最终结果，还要确定 SQL 语句的执行过程，并且尽可能的对 SQL 语句进行性能优化，从而得到最佳的执行计划。
#
# SQL 性能优化的过程，可以理解为 GPS 导航的过程。你提供地址后，GPS 软件利用各种统计信息（例如以前的行程、速度限制等元数据，以及实时交通信息）规划出一条最省时的路线。这与 TiDB 中的 SQL 性能优化过程相对应。
#
# 我们通常会把负责这部分 SQL 优化工作的组件成为**优化器（Optimizer）**。
#
# 如下图所示，一条 SQL 语句在经过语法解析和校验之后，经过优化器的逻辑优化和物理优化来制定最终的执行计划，交给执行器（Executor）去执行。和 GPS 软件一样，优化器在进行执行计划规划的时候也会利用到一些统计信息来进行评估。
#
# <center>
#   <img width="640" alt="The Cluster Modify Menu" src="https://user-images.githubusercontent.com/85985765/205136445-3d9dd676-56bc-4f75-bf6d-cdb1af8c1b79.png">
#   <p><i>SQL 优化流程图</i></p>
# </center>
#
# 上图其实是一个简化的示意图，因为它只描述了以 TiKV 为存储引擎的情况。但是在 TiDB 支持 HTAP 能力后，引进了负责分析负载的 TiFlash 存储引擎。这给优化器带来了新的挑战，优化器需要在制定执行计划和进行物理
# 优化时需要考虑：
#
# > 这条 SQL 应该使用哪个存储引擎执行性能会更好，选 TiKV 还是 TiFlash？

# %% [markdown]
# #### Optimizer Hints
#
# > 如果优化器难以抉择，那我们不妨给它一点提示，告诉它我们希望使用哪种存储引擎执行?
#
# TiDB 的优化器提供了 `READ_FROM_STORAGE` Hint 来允许开发者在 SQL 语句级别来控制哪一张表应该使用哪个执行引擎去执行。例如，下在面这条 SQL 语句当中，TiDB 从 TiFlash 上读取 t1 表的数据，在 TiKV 上读取 t2 的数据。
#
# ```sql
# SELECT /*+ READ_FROM_STORAGE(TIFLASH[t1], TIKV[t2]) */ t1.a FROM t t1, t t2 WHERE t1.a = t2.a;
# ```

# %% [markdown]
# #### 代价模型
#
# > 使用 Optimizer Hints 很简单，但是有没有更智能的方法，特别是在做临时查询时，优化器能否智能的选择应该使用哪种引擎查询效率最高？
#
# <center>
#   <img width="640" alt="物理优化中的代码模型" src="https://user-images.githubusercontent.com/85985765/205192450-c23f2199-1ab1-41d2-90f3-c17c5d6e252e.png">
#   <p><i>SQL 优化流程图</i></p>
# </center>
#
# TiDB v6.2.0 引入了新的代价模型 Cost Model Version 2。
#
# Cost Model Version 2 对代价公式进行了更精确的回归校准，调整了部分代价公式，比此前版本的代价公式更加准确。
#
# OSS Insight 使用了该版本的 Cost Model, 但是因为目前 Cost Model Version 2 还处于实验阶段，需要通过执行以下 SQL 语句进行启用：

# %%
set global tidb_enable_new_cost_interface = 'ON';
set global tidb_cost_model_version = 2;

# %% [markdown]
# 在后续版本当中，Cost Model Version 2 会替代掉原有的 Cost Model 作为默认的代码模型。

# %% [markdown]
# ## Demo SQL

# %% [markdown]
# #### Example 1

# %%
SELECT * FROM github_events WHERE actor_login = 'ti-chi-bot' LIMIT 1;

# %%
EXPLAIN SELECT * FROM github_events WHERE actor_login = 'ti-chi-bot' LIMIT 1;

# %% [markdown]
# #### Example 2

# %%
SELECT
  event_month, stars
FROM (
  SELECT
    date_format(created_at, '%Y-%m-01') as event_month,
    COUNT(1) OVER (ORDER BY date_format(created_at, '%Y-%m-01')) AS stars,
    ROW_NUMBER() OVER (PARTITION BY date_format(created_at, '%Y-%m-01')) AS row_num
  FROM
    github_events
  WHERE
    type = 'WatchEvent'
    AND repo_id = 41986369
  ORDER BY 1
) sub
WHERE row_num = 1
;

# %% [markdown]
# #### Example 3

# %%
WITH bots_with_first_seen AS (
    SELECT
        actor_login, MIN(YEAR(created_at)) AS first_seen_at
    FROM github_events ge
    WHERE
        actor_login REGEXP '^(bot-.+|.+bot|.+\\[bot\\]|.+-bot-.+|robot-.+|.+-ci-.+|.+-ci|.+-testing|.+clabot.+|.+-gerrit|k8s-.+|.+-machine|.+-automation|github-.+|.+-github|.+-service|.+-builds|codecov-.+|.+teamcity.+|jenkins-.+|.+-jira-.+)$'
    GROUP BY actor_login
    ORDER BY first_seen_at
),  acc AS (
    SELECT
        COUNT(actor_login) OVER (ORDER BY first_seen_at) AS cnt,
        first_seen_at AS event_year
    FROM
        bots_with_first_seen AS bwfs
    ORDER BY event_year
)
SELECT ANY_VALUE(cnt) AS bots_total, event_year
FROM acc
GROUP BY event_year
ORDER BY event_year;

# %% [markdown]
# 开启 TiFlash 副本

# %%
ALTER TABLE gharchive_dev.github_events SET TIFLASH REPLICA 1;

# %%
SELECT * FROM information_schema.tiflash_replica WHERE TABLE_SCHEMA = 'ossinsight' and TABLE_NAME = 'github_events';

# %% [markdown]
# 再次执行 Example 3 中的查询语句：

# %%
WITH bots_with_first_seen AS (
    SELECT
        actor_login, MIN(event_year) AS first_seen_at
    FROM github_events ge
    WHERE
        actor_login REGEXP '^(bot-.+|.+bot|.+\\[bot\\]|.+-bot-.+|robot-.+|.+-ci-.+|.+-ci|.+-testing|.+clabot.+|.+-gerrit|k8s-.+|.+-machine|.+-automation|github-.+|.+-github|.+-service|.+-builds|codecov-.+|.+teamcity.+|jenkins-.+|.+-jira-.+)$'
    GROUP BY actor_login
    ORDER BY first_seen_at
),  acc AS (
    SELECT
        COUNT(actor_login) OVER (ORDER BY first_seen_at) AS cnt,
        first_seen_at AS event_year
    FROM
        bots_with_first_seen AS bwfs
    ORDER BY event_year
)
SELECT ANY_VALUE(cnt) AS bots_total, event_year
FROM acc
GROUP BY event_year
ORDER BY event_year;

# %% [markdown]
# #### Example 4

# %%
TODO:
